# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aarondomenzain/tracking-softmatter-aarond/blob/tracking-softmatter-aarond-dev/tutorial/detection/detection_ellipses.ipynb)

# %% [markdown]
# # Particle Tracking Tutorial: Particle Detection and Localization
#
# In this tutorial, you’ll explore different methods to detect and localize particles in microscopy images using both simulated data and real experimental images.
#
# You’ll start by generating a simulated image of microscopic particles, mimicking what you might see in a soft matter or biophysics experiment. Since you know the true particle positions in the simulation (i.e., the 'ground truth'), you can directly evaluate how well each detection method performs.
#
# Here’s what you’ll test and compare:
#
# - Thresholding and Connected Components
#
# - Crocker and Grier (using TrackPy — a classic in particle tracking)
#
# - U-Net (a neural network for image segmentation)
#
# - LodeSTAR (a self-supervised deep learning method)
#
# You’ll be using Python libraries like NumPy, SciPy, Matplotlib, scikit-image, PyTorch, DeepTrack, and Deeplay.

# %% [markdown]
# ## Table of Contents
#
# 0. [Import the Required Libraries and Load Utility Functions](#import-the-required-libraries-and-load-utility-functions)
# 1. [Load and Visualize Experimental Images](#load-and-visualize-experimental-images)
# 2. [Simulate Realistic Images with DeepTrack](#simulate-realistic-images-with-deeptrack)
#     - [Simulate a Single Particle](#simulate-a-single-particle)
#     - [Simulate a Test Image to Benchmark Detection Methods](#simulate-a-test-image-to-benchmark-detection-methods)
# 3. [Method 1: Thresholding and Connected Components](#3-method-1-thresholding-and-connected-components)
#     - [Apply Intensity Thresholding](#apply-intensity-thresholding)
#     - [Determine Centroids with Connected Components Analysis](#determine-centroids-with-connected-components-analysis)
#     - [Evaluate the Performance of the Method](#evaluate-the-performance-of-the-method)
#     - [Apply the Method to Experiments](#apply-the-method-to-experiments)
#
# 4. [Method 2: Crocker and Grier](#method-2-crocker-and-grier)
#     - [Estimate Particle Size from Simulations](#estimate-particle-size-from-simulations)
#     - [Apply the Crocker and Grier Method to Simulations](#apply-the-crocker-and-grier-method-to-simulations)
#     - [Apply the Crocker and Grier Method to Experiments](#apply-the-crocker-and-grier-method-to-experiments)
#
# 5. [Method 3: U-Net](#method-3-u-net)
#     - [Create a Training Dataset](#create-a-training-dataset)
#     - [Define a U-Net Model with Deeplay](#define-a-u-net-model-with-deeplay)
#     - [Train the U-Net model](#train-the-u-net-model)
#     - [Apply the Trained U-Net to the Simulations](#apply-the-trained-u-net-to-simulations)
#     - [Apply the Trained U-Net to the Experiments](#apply-the-trained-u-net-to-experiments)
#
# 6. [Method 4: LodeSTAR](#method-4-lodestar)
#     - [Simulate Training Data for LodeSTAR](#simulate-training-data-for-lodestar)
#     - [Train LodeSTAR and Apply it to Simulations](#train-lodestar-and-apply-it-to-simulations)
#     - [Apply the Trained LodeSTAR to Experiments](#apply-the-trained-lodestar-to-experiments)
#     - [Train LodeSTAR with Experiments](#train-lodestar-with-experimentas)

# %% [markdown]
# ## Import the Required Libraries and Load Utility Functions

# %% [markdown]
# Uncomment the next cell if running on Google Colab/Kaggle.

# %%
# !pip install deeplay deeptrack trackpy  -q

# %% [markdown]
# Import required libraries.

# %%
# Standard libraries
import os
import random
import sys

# Core Scientific Stack
import numpy as np
import scipy

# Plotting and Display
import matplotlib.pyplot as plt

# Machine Learning
import deeplay as dl
import torch

# Particle Tracking and Simulation
import deeptrack as dt
import trackpy as tp

# Image Analysis
import skimage  # Image analysis (scikit)

# %% [markdown]
# Load a set of custom functions defined specifically for this notebook from the `utils` directory. For detailed documentation of each function, refer to the comments and docstrings within the files.

# %%
# Load functions and utilities for dataset generation and visualization.
# Sys append a folder to the path.
sys.path.append(os.path.abspath(os.path.join("..", "..")))

# Import all the functions contained in the folder utils.
import utils

# %% [markdown]
# Set random seeds to make results reproducible across runs, especially during training and data simulation.

# %%
# Set a fixed seed value.
seed = 89

# Python, NumPy, and PyTorch (CPU).
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# Only set CUDA seeds if a GPU is available.
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

print(f"Seeds set to {seed} (with CUDA: {torch.cuda.is_available()})")

# Get the best available device for Torch computation.
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using CUDA GPU: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple GPU (MPS)")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Seeds set to 89 (with CUDA: False)
# Using Apple GPU (MPS)

# %% [markdown]
# ## Load and Visualize Experimental Images

# %% [markdown]
# Load a `.bmp` image from the `images/` folder and display it using scikit-image.

# %%
# Define the folder and image file name.
image_folder = "images"
image_file_name =  "vi_5.5_f.bmp"

# Construct the full path.
image_path = os.path.join(image_folder, image_file_name)

# Create an instance of the loaded file using SciKit.
exp_image = skimage.io.imread(image_path)

# Crop the image to a square.
exp_image = exp_image[:640, :640]

# Get the shape of the image.
assert exp_image.shape[0] == exp_image.shape[1], "Warning: Image not square!"
exp_image_size = exp_image.shape[0]

# Print the name of the selected file.
print("Selected file:", image_path)

# Open a figure instance.
plt.figure()

# Plot the image in grayscale.
plt.imshow(exp_image, cmap="gray")
plt.axis("off")
plt.title("Experimental Image")
plt.tight_layout()
plt.show()

# Print the image size in pixels.
print(f"Size of imported image in pixels: {exp_image_size}")
# Out:
# Selected file: images/vi_5.5_f.bmp
# Size of imported image in pixels: 640

# %% [markdown]
# Manually select and display a single particle by specifying its centroid coordinates (x,y) and a box width.
#
# **Note:** Images in NumPy are indexed as `(columnd, row)`, which corresponds to (y, x) in Cartesian coordinates.

# %%
from matplotlib.patches import Rectangle

# Window size to zoom in an individual particle.
exp_crop_size = 23

# Coordinates of the center of the particle.
x_center, y_center = 439, 412 # (column, row)

# Compute crop bounds.
x_min = x_center - exp_crop_size // 2
x_max = x_center + exp_crop_size // 2
y_min = y_center - exp_crop_size // 2
y_max = y_center + exp_crop_size // 2

# Extract crop (note: rows = y, cols = x).
exp_crop = exp_image[y_min:y_max, x_min:x_max]

# Create a single figure with two panels.
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Left panel: full image with square window.
axes[0].imshow(exp_image, cmap="gray")
axes[0].set_title("Experimental Image", fontsize=13)
axes[0].add_patch(
    Rectangle(
        (x_min, y_min), exp_crop_size, exp_crop_size,
        edgecolor='red', facecolor='none', linewidth=2,
    )
)
axes[0].axis("off")

# Right panel: zoomed-in crop.
axes[1].imshow(exp_crop, cmap="gray")
axes[1].set_title("Zoomed Crop", fontsize=13)
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Simulate Realistic Images with DeepTrack

# %% [markdown]
# DeepTrack allows you to simulate physically realistic microscopy images, enabling precise control over imaging parameters and particle properties. These simulations provide ground-truth data, making them ideal for benchmarking classical and AI-based tracking methods, as well as for training neural networks in a controlled environment.

# %% [markdown]
# ### Simulate a Single Particle

# %% [markdown]
# Adjust the simulation parameters to accurately replicate the features observed in the cropped region of the experimental image.

# %% [markdown]
# **Note:** You will need to use `Upscale` to improve the sampling accuracy of the object shape and intensity distribution, reducing aliasing artifacts and ensuring the optical transformation (e.g., Darkfield or Fluorescence) produces physically consistent results. After upscaling and optical simulation, the image is automatically downsampled to match the camera resolution.

# %%
# Same as when selecting a single object.
sim_crop_size = exp_crop_size

# Size of a pixel in nanometers in the output image.
pixel_size_nm = 100  # In nm

# Size of the long ellipsoid semiaxis in nm.
major_axis_length = 1000  # In nm

# Eccentricity of ellipsoid.
eccentricity = 0.185

ellipse = dt.Ellipsoid(
    position=0.5 * np.array([sim_crop_size, sim_crop_size]),
    z=-10 * dt.units.nm,  # Particle in focus
    radius=((major_axis_length, eccentricity * major_axis_length)
            * dt.units.nm),  # Axes in nm
    # intensity=0.35,  # Field magnitude squared
    rotation=0.225 * np.pi,
)

# Set the optical properties of the microscope.
optics = dt.Darkfield(
    NA=1.0,  # Numerical aperture
    wavelength=532 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, sim_crop_size, sim_crop_size],
    magnification=1,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
    upscale=2
)

# Apply transformations. Use `Upscale` to improve simulations rendering.
sim_crop = (
    optics(ellipse) # Upscale the image to original size
    >> dt.Background(0)
    >> dt.Poisson(snr=60)
    >> dt.Multiply(15)
)

# Convert crop into NumPy array.
sim_crop = np.squeeze(sim_crop())

# Plot the simulated and experimental crops.
fig, axes = plt.subplots(1, 2)

# Simulated crop.
axes[0].imshow(sim_crop, cmap="gray")
axes[0].axis("off")
axes[0].set_title("Simulated Crop")

# Experimental crop.
axes[1].imshow(exp_crop, cmap="gray")
axes[1].axis("off")
axes[1].set_title("Experimental Crop")

# Adjust layout and show plot.
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:2312: UserWarning: Darkfield imaging from ScatteredVolume is a very rough approximation. Use ScatteredField for physically meaningful darkfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:2353: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical darkfield scattering strength. Results are qualitative only.
#   warnings.warn(

# %% [markdown]
# Extract and visualize the raw intensity profiles along the central horizontal line of both the simulated and experimental crops. This comparison helps evaluate how well the simulation reproduces the intensity distribution observed in real microscopy images.

# %%
# Compute the center index.
center = sim_crop_size // 2

# Extract horizontal (row) profiles.
sim_horiz = sim_crop[center, :]
exp_horiz = exp_crop[center, :]

# Extract vertical (column) profiles.
sim_vert = sim_crop[:, center]
exp_vert = exp_crop[:, center]

# Create a 1×2 subplot.
fig, axes = plt.subplots(1, 2, figsize=(12, 4), tight_layout=True)

# --- Horizontal profile ---
axes[0].plot(sim_horiz, label="Simulated Crop", color="orange")
axes[0].plot(exp_horiz, label="Experimental Crop", color="blue")
axes[0].set_xlabel("Pixel (x)")
axes[0].set_ylabel("Intensity")
axes[0].set_title("Horizontal Intensity Profile (Center Row)")
axes[0].legend()
axes[0].grid(True, linestyle="--", alpha=0.5)

# --- Vertical profile ---
axes[1].plot(sim_vert, label="Simulated Crop", color="orange")
axes[1].plot(exp_vert, label="Experimental Crop", color="blue")
axes[1].set_xlabel("Pixel (y)")
axes[1].set_ylabel("Intensity")
axes[1].set_title("Vertical Intensity Profile (Center Column)")
axes[1].legend()
axes[1].grid(True, linestyle="--", alpha=0.5)

# %% [markdown]
# ### Simulate a Test Image to Benchmark Detection Methods

# %% [markdown]
# Create a simulated image containing non-overlapping elliptical particles. Begin by generating their coordinates—these will serve as the ground-truth positions. Then, use DeepTrack to render optically realistic particles at these coordinates, resulting in a physically plausible microscopy image.

# %%
# Same as when selecting a single object.
sim_crop_size = exp_crop_size

# Size of a pixel in nanometers in the output image.
pixel_size_nm = 100  # In nm

# Size of the long ellipsoid semiaxis in nm.
major_axis_length = 1000  # In nm

# Eccentricity of ellipsoid.
eccentricity = 0.185

ellipse = dt.Ellipsoid(
    position=0.5 * np.array([sim_crop_size, sim_crop_size]),
    z=-10 * dt.units.nm,  # Particle in focus
    radius=((major_axis_length, eccentricity * major_axis_length)
            * dt.units.nm),  # Axes in nm
    # intensity=0.35,  # Field magnitude squared
    rotation=0.225 * np.pi,
)

# Set the optical properties of the microscope.
optics = dt.Darkfield(
    NA=1.0,  # Numerical aperture
    wavelength=532 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, sim_crop_size, sim_crop_size],
    magnification=1,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
    upscale=2
)

# Apply transformations. Use `Upscale` to improve simulations rendering.
sim_crop = (
    optics(ellipse) # Upscale the image to original size
    >> dt.Background(0)
    >> dt.Poisson(snr=60)
    >> dt.Multiply(15)
)

# Convert crop into NumPy array.
sim_crop = np.squeeze(sim_crop())

# Plot the simulated and experimental crops.
fig, axes = plt.subplots(1, 2)

# Simulated crop.
axes[0].imshow(sim_crop, cmap="gray")
axes[0].axis("off")
axes[0].set_title("Simulated Crop")

# Experimental crop.
axes[1].imshow(exp_crop, cmap="gray")
axes[1].axis("off")
axes[1].set_title("Experimental Crop")

# Adjust layout and show plot.
plt.tight_layout()
plt.show()

# %%
# Parameters of the simulation. 
sim_image_size = 640
N_particles = 200  # Number of particles in the image
major_axis_length = 1000  # Size of the long ellipsoid semiaxis in nm
eccentricity = 0.185  # Eccentricity of the ellipsoidal particle

# Dictionary for particle properties. Dimensions are set with lambda functions
# to introduce variety to the dataset.
ellipse_properties = {
    "radius": lambda: (
        major_axis_length * np.random.normal(1, 0.1),
        eccentricity * major_axis_length
    ) * dt.units.nm,
    "intensity": lambda: np.random.uniform(0.9, 1.1) * 0.35,
    "upscale_factor": 2,
}

# Set the optical properties of the microscope.
optics_properties = dt.Brightfield(
    NA=0.9,  # Numerical aperture
    wavelength=500 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, sim_image_size, sim_image_size],
    magnification=1,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
)

# Generate ground truth positions.
sim_locs_gt = utils.generate_centroids(
    num_particles=N_particles,
    fov_size=sim_image_size,
    particle_radius=major_axis_length,
)

# Simulate image.
sim_image = utils.transform_to_video(
    sim_locs_gt,
    fov_size=sim_image_size,
    core_particle_props=ellipse_properties,
    optics_props=optics_properties,
    background_props={"poisson_snr": 100, "background_mean":5},
)

# Generate the ground truth as Gaussian clouds centered at the position of the
# ellipsoids. The standard deviation of the Gaussians are set to be
# proportional to the semiaxes of the corresponding particles.
gt_cloud_size = np.array(
    [major_axis_length, eccentricity * major_axis_length]
) / 3

# Generate ground truth map using the positions, orientations and size of 
# particles.
sim_map = utils.create_ground_truth_map(
    sim_locs_gt, 
    fov_size=sim_image_size, 
    sigma=gt_cloud_size
)
# Out:
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(

# %% [markdown]
# Visualize the simulated image and compare it with the experimental one.

# %%
# Plot the simulated and experimental images.
fig, axes = plt.subplots(1, 2)

# Simulated image.
plot = axes[0].imshow(sim_image, cmap="gray")
axes[0].axis("off")
axes[0].set_title("Simulated Image")

# Experimental image.
axes[1].imshow(exp_image, cmap="gray")  
axes[1].axis("off")
axes[1].set_title("Experimental Image")

# Adjust layout and show plot.
plt.tight_layout()
plt.show()

# %% [markdown]
# Perform a more quantitative comparison by plotting the intensity histograms.

# %%
# Flatten the arrays to 1D.
sim_vals = 32*sim_image.ravel()
exp_vals = exp_image.ravel()

# Create figure with two subplots sharing the y-axis.
fig, axes = plt.subplots(
    1, 2, figsize=(10, 4), sharey=True, sharex=True, tight_layout=True,
)

# Histogram for simulated image.
axes[0].hist(sim_vals, bins=80, alpha=0.7, edgecolor="black", density=True)
axes[0].set_title("Simulated Image Histogram")
axes[0].set_xlabel("Normalized Intensity")
axes[0].set_ylabel("Probability Density")

# Histogram for experimental image.
axes[1].hist(exp_vals, bins=80,  alpha=0.7, edgecolor="black", density=True)
axes[1].set_title("Experimental Image Histogram")
axes[1].set_xlabel("Normalized Intensity")
# No need to set ylabel on the second axes when sharing.

plt.show()

# %% [markdown]
# Visualize the simulated image and the corresponding ground truth map. Each particle has an associated ground truth cloud with a Gaussian profile, whose standard deviation is each direction proportional to the semiaxes of the particle in each direction.

# %%
# Create a subfigure instance to plot the image and the probability map.
fig, ax = plt.subplots(1, 2)

# Instance for the simulated experimental image. 
img1 = ax[0].imshow(sim_image, cmap="gray")
ax[0].axis("off")
ax[0].set_title("Simulated Image")  

# Instance for the probability map.
img2 = ax[1].imshow(sim_map, cmap="gray")
ax[1].axis("off")
ax[1].set_title("Simulated Probability Map (Gaussian)") 

# Adjust layout to avoid overlap.
plt.tight_layout()

# Show the plot.
plt.show()

# %% [markdown]
# From now on, you'll use normalized images.

# %%
# Normalize the images to the range [0, 1].
exp_image = utils.normalize_min_max(
    exp_image, minimum_value=0.0, maximum_value=1.0,
)
sim_image = utils.normalize_min_max(
    sim_image, minimum_value=0.0, maximum_value=1.0,
)

# %% [markdown]
# ## Method 1: Thresholding and Connected Components

# %% [markdown]
# In a grayscale image, each pixel has an intensity value, where higher values typically indicate the presence of particles while lower values represent the background (but it can also be the other way around).
#
# A simple and effective method for particle detection is **intensity thresholding**, which converts the grayscale image into a binary mask. Pixels with intensities above a chosen threshold are marked as foreground (set to 1, corresponding to white), and the rest as background (set to 0, corresponding to black).
#
# If particles appear darker than the background—as in absorption-based or negative stain imaging—the threshold should instead be applied to the lower end of the intensity distribution.
#
# After thresholding, **connected component analysis** can be used to label and isolate individual foreground regions. Each connected component represents a candidate particle, enabling basic localization by computing properties such as the centroid (position), area (size), or bounding box (extent) of each region.

# %% [markdown]
# ### Apply Intensity Thresholding

# %% [markdown]
# A robust way to choose the threshold is to use the **intensity quantile**. For example, setting the threshold at the 90th percentile selects the brightest 10% of pixels, which often correspond to particles. This method is more reliable than using the image mean and standard deviation, which can be biased by background-dominated images.
#
# Before thresholding, it’s a good idea to smooth the image with a Gaussian filter. This helps suppress noise and small fluctuations that aren’t real particles.

# %%
# Apply a Gaussian filter to the image to smooth out noise.
filtered_sim_image = scipy.ndimage.gaussian_filter(sim_image, sigma=1.0)

# %% [markdown]
# Plot the intensity histogram of the simulated image before and after Gaussian filtering.

# %%
# Define the quantile level (e.g., 90% selects the top 10% brightest pixels).
quantile_level = 0.1

# Compute statistics
median_intensity_sim = np.median(sim_image)
quantile_threshold_sim = np.quantile(sim_image, quantile_level)

median_intensity_filtered_sim = np.median(filtered_sim_image)
quantile_threshold_filtered_sim = np.quantile(filtered_sim_image, quantile_level)

print(f"Intensity threshold (quantile={quantile_level*100:.0f}%): "
      f"{quantile_threshold_filtered_sim}")

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 3))

# Histogram for simulated image
axes[0].hist(sim_image.flatten(), bins=128, range=(0, 1), color="gray",
             alpha=0.75, density=True)
axes[0].axvline(median_intensity_sim, color="red", linestyle="dashed",
                linewidth=1.5, label="Median")
axes[0].axvline(quantile_threshold_sim, color="green", linestyle="dashed",
                linewidth=1.5, label=f"{int(quantile_level*100)}th Percentile")
axes[0].set_title("Simulated Image", fontsize=14)
axes[0].set_yticklabels([])  # Remove y labels
axes[0].legend()
axes[0].grid(True)

# Histogram for filtered image
axes[1].hist(filtered_sim_image.flatten(), bins=128, range=(0, 1),
             color="gray", alpha=0.75)
axes[1].axvline(median_intensity_filtered_sim, color="red", linestyle="dashed",
                linewidth=1.5, label="Median")
axes[1].axvline(quantile_threshold_filtered_sim, color="green",
                linestyle="dashed", linewidth=1.5,
                label=f"{int(quantile_level*100)}th Percentile")
axes[1].set_title("Simulated Image + Gaussian Filter", fontsize=14)
axes[1].set_yticklabels([])
axes[1].legend()
axes[1].grid(True)

# Set common x and y labels
fig.supxlabel("Normalized Intensity", fontsize=12)
fig.supylabel("Normalized Frequency [counts]", fontsize=12)

# Adjust layout and display
plt.tight_layout()
plt.show()
# Out:
# Intensity threshold (quantile=10%): 0.574310080984713

# %% [markdown]
# Apply the threshold to generate a binary mask, then display it together with the original image for visual validation.

# %%
# Create the binary mask by applying the threshold.
sim_mask = filtered_sim_image < quantile_threshold_filtered_sim

# Ensure the mask is a 2D array.
sim_mask = np.squeeze(sim_mask)

# Plot the image with the calculated mask.
utils.plot_image_mask_ground_truth_map(
    image=sim_image, 
    mask=sim_mask, 
    title="Mask with Intensity Thresholding",
)

# %% [markdown]
# ### Determine Centroids with Connected Components Analysis

# %% [markdown]
# Detect objects from the binary mask and extract their centroids using the scikit-image library. This is typically done by identifying connected components and computing their center of mass, which provides an estimate of each particle’s position.

# %%
# Use the function to extract positions from mask.
sim_locs_pred_method1 = utils.mask_to_positions(sim_mask)
print(f"Found {len(sim_locs_pred_method1[:,1])} detections.")
# Out:
# Found 2134 detections.

# %% [markdown]
# Plot the extracted centroids on top of the image.

# %%
# Use the plotting function to compare the detection with the ground truth.
utils.plot_predicted_positions(
    image=sim_image, 
    pred_positions=sim_locs_pred_method1, 
    gt_positions=sim_locs_gt, 
    title="Method 1 - Simulated Image",
)

# %% [markdown]
# ### Evaluate the Performance of the Method

# %% [markdown]
# Apply the `evaluate_locs` function that calculates evaluation metrics and print them. It calculates True Positives (TP), False Positives (FP), False Negatives (FN), F1 score (F1), and Root Mean Square Error (MSE).

# %%
TP, FP, FN, F1, RMSE = utils.evaluate_locs(
    sim_locs_pred_method1, sim_locs_gt, distance_th=major_axis_length,
)
# Out:
# True Positives: 199/200
# False Positives: 1935
# False Negatives: 1
# F1 Score: 0.1705
# RMSE: 1.4810

# %% [markdown]
# ### Apply the Method to Experiments

# %% [markdown]
# Apply the same method to the experimental image:
#
# - Smooth the image using a Gaussian filter.
# - Choose a threshold.
# - Create a binary mask where pixels above the threshold are marked as potential particles.
# - Extract positions from the mask.
# - Plot both the predicted positions and the mask for visual inspection.
# - Print the number of detections found.
#
# This gives us a first estimate of particle positions using just thresholding—no machine learning needed!

# %%
# Apply a Gaussian filter to the image to smooth out noise.
filtered_exp_image = scipy.ndimage.gaussian_filter(exp_image, sigma=2.0)

# quantile level for thresholding.
quantile_level = 0.10

# Intensity threshold for the experimental image.
quantile_threshold_filtered_exp = \
    np.quantile(filtered_exp_image, quantile_level)

# Create the binary mask by applying the threshold.
exp_mask = filtered_exp_image < quantile_threshold_filtered_exp

# Get predicted positions from the mask.
exp_locs_pred_method1 = utils.mask_to_positions(exp_mask)

# Plot the experimental image with the predicted positions.
utils.plot_predicted_positions(
    image=exp_image,
    pred_positions=exp_locs_pred_method1,
    title="Method 1 - Experimental Image",
)

# Plot the experimental image and the mask.
utils.plot_image_mask_ground_truth_map(
    image=exp_image, 
    mask=exp_mask, 
    title="Method 1 - Experimental Image",
)

# Print the number of detections.
print(f"Found {len(exp_locs_pred_method1[:,1])} detections.")
# Out:
# No ground truth positions were passed
# Found 302 detections.

# %% [markdown]
# ## Method 2: Crocker and Grier (TrackPy)

# %% [markdown]
# A refined approach for particle detection and localization is the Crocker and Grier method. This method identifies local intensity maxima and refines their positions by fitting the surrounding region to a Gaussian-like profile. It offers subpixel accuracy and performs well even in moderately noisy conditions or crowded images.
#
# TrackPy provides a built-in implementation of the Crocker and Grier particle detection method.

# %% [markdown]
# ### Estimate Particle Size from Simulations

# %% [markdown]
# In the TrackPy implementation of the Crocker and Grier method, the primary parameter you need to set is the estimated particle size, which must be an odd number.
#
# To estimate this value, inspect the simulated image interactively: click on both edges of a representative particle to measure its approximate width. Keep in mind that particle sizes may vary across the image, so this should be treated as an initial guess. You can refine the diameter later by evaluating the quality of the detections.

# %% [markdown]
# **Note:** For the interactive widget to work correctly, you might need to install `ipykernel` manually, for example using:
# ```bash
# pip install ipykernel
# ```

# %% [markdown]
# **Note:** The Crocker and Grier particle detection method, as implemented in `trackpy.locate()`, was originally designed for approximately circular, symmetric particles. It can also be used to detect elliptical particles, but this requires careful configuration. For axis-aligned ellipses, you can pass a tuple to the diameter argument (e.g., `diameter=(21, 11)`) to define an elliptical search window. Note that this tuple is interpreted as `(diameter_x, diameter_y)` — and crucially, the detection kernel is not rotation-aware. TrackPy assumes that all features are aligned with the image axes, so particles at arbitrary orientations may be poorly localized or even missed.
#
# In our case, where particles can be rotated in any direction, we use a square kernel and manually tune the estimated diameter to balance detection performance. While this approach works to some extent, it remains a suboptimal solution for anisotropic or rotated features.

# %%
# Set the matplotlib interactive backend .
# %matplotlib widget
utils.interactive_ruler(sim_image[250:350, 250:350])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Switch the backend back to the default, where plots are rendered as static images in the notebook cells.

# %%
# Close the figure so it doesn't re-render
plt.close("all")

# Switch back to static plots
# %matplotlib inline

# %% [markdown]
# ### Apply the Crocker and Grier Method to Simulations

# %% [markdown]
# Use `trackpy.locate()` to detect particles in the image. This function returns a DataFrame object containing the coordinates of the detected particles along with various feature properties.
#
# Extract the (x, y) positions from the DataFrame and compare them to the ground truth coordinates to assess the accuracy of the detection.

# %%
# Estimate and tune the diameter of particles in pixels, ensuring it is an
# odd number. Adjust if necessary.
estimated_size_sim = 23

# Use the locate built-in function from TrackPy.
# Output is type DataFrame([x, y, mass, size, ecc, signal, raw_mass]).
df_sim_locs_pred_method2 = tp.locate(
    sim_image, 
    diameter=estimated_size_sim,
    invert=True,  # Invert the image
    noise_size=5,  # Setting for denoising image
    separation=10 # Minimum separation distabce between particles, in px.
)

# Extract the predicted positions from DataFrame["x","y"] into a NumPy array.
sim_locs_pred_method2 = np.array(df_sim_locs_pred_method2)[:,:2]

# Plot the prediction and the ground truth.
utils.plot_predicted_positions(
    image=sim_image,
    pred_positions=sim_locs_pred_method2,
    gt_positions=sim_locs_gt,
    title="Method 2 - Simulated Image",
)

# Evaluate the performance of tp.locate.
utils.evaluate_locs(
    sim_locs_pred_method2,
    sim_locs_gt,
    distance_th=major_axis_length,
);
# Out:
# True Positives: 200/200
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5214

# %% [markdown]
# ###

# %% [markdown]
# ### Apply the Crocker and Grier Method to Experiments

# %% [markdown]
# Interactively estimate particle size.

# %%
# Set the matplotlib interactive backend .
# %matplotlib widget
# Plot a small ROI of the experimental image.
utils.interactive_ruler(exp_image[370:470, 370:470])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Switch the backend back to the default, where plots are rendered as static images in the notebook cells.

# %%
# Close the figure so it doesn't re-render
plt.close("all")

# Switch back to static plots
# %matplotlib inline

# %% [markdown]
# Detect particles in the image and display the results.

# %%
# Semiaxes of experimental crop. Tuned to improve detections.
estimated_size_exp = 19

# Use trackpy.locate to the pre-filtered experimental image.
df_exp_locs_pred_method2 = tp.locate(
    exp_image, 
    diameter=estimated_size_exp, 
    invert=True,
    noise_size=5,
    separation=10
)
# Extract the predicted positions from DataFrame["x","y"] into a NumPy array.
exp_locs_pred_method2 = np.array(df_exp_locs_pred_method2)[:,:2]

# Plot the experimental image with predicted positions overlaid.
utils.plot_predicted_positions(
    image=exp_image,
    pred_positions=exp_locs_pred_method2,
    title="Method 2 - Experimental Image",
)

print(f"Found {len(exp_locs_pred_method2[:,1])} detections.")
# Out:
# No ground truth positions were passed
# Found 274 detections.

# %% [markdown]
# ## Method 3: U-Net

# %% [markdown]
# The U-Net is a convolutional neural network (CNN) widely used for image segmentation tasks. It performs pixel-wise classification, enabling precise separation between background and objects of interest—ranging from simple particles to complex cells or anatomical structures, depending on the training data.
#
# In the context of particle detection, U-Net can be trained to map input microscopy images directly into **probability distributions** that represent the likelihood of a particle being present at each pixel. Instead of assigning a hard classification (particle or background), the network outputs a **dense probability map**—a soft, continuous prediction indicating how likely each pixel is to belong to a particle. This approach is particularly useful in challenging scenarios, such as overlapping particles—where discrete detection may fail—or small, faint particles that traditional methods might miss.
#
# Once trained, U-Net generalizes to new images, producing smooth probability maps that can be thresholded to create binary masks for downstream connected-component analysis. For localization, these maps enable the calculation of **intensity-weighted centroids**, allowing subpixel resolution of particle positions and improving localization accuracy. Alternatively, the maps can be analyzed using peak detection algorithms or interpreted as confidence scores to filter or rank detections.

# %% [markdown]
# ### Create a training dataset

# %% [markdown]
# U-Net is trained using pairs of input images and corresponding target maps, which represent the expected output distribution. These target maps typically consist of Gaussian blobs centered at the true particle locations, encoding both position and uncertainty.
#
# To generate training data, you can simulate particle images using DeepTrack, along with their associated probability maps to serve as ground truth.
#
# If a dataset has already been generated and saved, you can simply load it and skip the simulation step.

# %%
# Parameters of the simulation. 
sim_image_size = 640
N_particles = 350  # Number of particles in the image
major_axis_length = 1000  # Size of the long ellipsoid semiaxis in nm
eccentricity = 0.185  # Eccentricity of the ellipsoidal particle

# Dictionary for particle properties. Dimensions are set with lambda functions
# to introduce variety to the dataset.
ellipse_properties = {
    "radius": lambda: (
        major_axis_length * np.random.normal(1, 0.1),
        eccentricity * major_axis_length
    ) * dt.units.nm,
    "intensity": lambda: np.random.uniform(0.9, 1.1) * 0.35,
    "upscale_factor": 2,
}

# Set the optical properties of the microscope.
optics_properties = dt.Brightfield(
    NA=0.9,  # Numerical aperture
    wavelength=500 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, sim_image_size, sim_image_size],
    magnification=1,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
)

# Generate ground truth positions.
sim_locs_gt = utils.generate_centroids(
    num_particles=N_particles,
    fov_size=sim_image_size,
    particle_radius=major_axis_length,
)

# Simulate image.
sim_image = utils.transform_to_video(
    sim_locs_gt,
    fov_size=sim_image_size,
    core_particle_props=ellipse_properties,
    optics_props=optics_properties,
    background_props={"poisson_snr": 100, "background_mean":5},
)

# Generate the ground truth as Gaussian clouds centered at the position of the
# ellipsoids. The standard deviation of the Gaussians are set to be
# proportional to the semiaxes of the corresponding particles.
gt_cloud_size = np.array(
    [major_axis_length, eccentricity * major_axis_length]
) / 3

# Generate ground truth map using the positions, orientations and size of 
# particles.
sim_map = utils.create_ground_truth_map(
    sim_locs_gt, 
    fov_size=sim_image_size, 
    sigma=gt_cloud_size
)
# Out:
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(

# %%
# Number of samples, image size, and particles.
num_samples = 128
train_image_size = 64
max_num_particles = 20
force_simulation = False  # Flag to force simulation even if data exists.

# Set the optical properties of the microscope.
optics_properties = dt.Brightfield(
    NA=0.9,  # Numerical aperture
    wavelength=632 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, train_image_size, train_image_size],
    magnification=1,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
)

# Create path to store training dataset.
folder_name = "UNet"
training_dataset_filename = "UNet_training_dataset_ellipsoids.npz"
training_dataset_folder = os.path.join(folder_name, "training_data")
training_dataset_filepath = os.path.join(
    training_dataset_folder, 
    training_dataset_filename,
)

# Create the enclosing directory if not existent already.
if not os.path.exists(training_dataset_folder):
    os.makedirs(training_dataset_folder, exist_ok=True)

# Try to load preexisting simulated data; if not available or forced, generate 
# new data.
try:
    if force_simulation: 
        # Raise the exception error if simulation is forced.
        raise FileNotFoundError("Forced simulation by user request.")
    
    if not os.path.isfile(training_dataset_filepath):
        # If file is not found, start training.    
        raise FileNotFoundError(
            "Training dataset file not found. Starting simulation."
        )
    
    # Load existing data
    data = np.load(training_dataset_filepath)
    print(f"Loaded file: {training_dataset_filepath}")
    images = data["images"]
    maps = data["maps"]
    Nsamples = len(images)
        
# Handle the case of either file not found or forced training.
except FileNotFoundError:
    
    # Perform simulation if file not found or forced.
    images, maps = utils.generate_particle_dataset(
        num_samples = num_samples,
        fov_size = train_image_size,
        max_num_particles = max_num_particles,
        core_particle_dict=ellipse_properties,
        optics_properties=optics_properties,
        background_props={"poisson_snr": 40, "background_mean": 1},
    )
    
    # Save the simulated training dataset.
    np.savez(training_dataset_filepath, images=images, maps=maps)
    print(f"Training dataset saved in: {training_dataset_filepath}.")
# Out:
# Loaded file: UNet/training_data/UNet_training_dataset_ellipsoids.npz

# %% [markdown]
# Before training the U-Net model with Deeplay, ensure that the input dataset has the shape (N, X, Y, C), where:
#
# N: Number of samples (simulated images)\
# X: Width of the image (pixels along the horizontal axis)\
# Y: Height of the image (pixels along the vertical axis)\
# C: Number of channels (use 1 for grayscale images)

# %%
print(f"Image dimensions: {images.shape}")
print(f"Maps dimensions: {maps.shape}")
# Out:
# Image dimensions: (128, 64, 64, 1)
# Maps dimensions: (128, 64, 64, 1)

# %% [markdown]
# Visualize the simulated training dataset

# %%
# Select an image and its corresponding ground truth maps and mask to show.
selected_image_index = np.random.randint(0, len(images))


# Extract the image and probability map from 4D arrays.
selected_image = np.squeeze(images[selected_image_index])
selected_probability_map = np.squeeze(maps[selected_image_index])

# Plot the image as the first subplot.
utils.plot_image_mask_ground_truth_map(
    image=selected_image,
    gt_map=selected_probability_map,
    title=f"Training dataset element: {selected_image_index+1}/{len(images)}",
)

# %% [markdown]
# ### Define a U-Net model using Deeplay

# %% [markdown]
# The name 'U-Net' comes from its characteristic U-shaped architecture, which features a symmetric encoder–decoder structure. The encoder (downsampling path) captures contextual information by progressively reducing spatial resolution, while the decoder (upsampling path) restores spatial detail. Skip connections between corresponding levels of the encoder and decoder help retain fine-grained features, improving segmentation accuracy—especially for small or faint objects.
#
# You'll define a 2D U-Net where both the input and output images have a single channel, corresponding to grayscale intensity. The goal is for the model to learn a mapping from the experimental image to a spatial probability density map that indicates the likelihood of particle presence at each pixel.
#
# As a rule of thumb, stacking N convolutional layers with 3×3 kernels gives a receptive field of about (2N+1)×(2N+1) pixels. For example, three layers correspond to roughly a 7×7 receptive field.
# Downsampling layers (like 2×2 pooling or stride-2 convolutions) expand the receptive field much more quickly, since each subsequent convolution “sees” a larger patch of the original image. This is why U-Nets with multiple downsampling stages can capture both fine details and large-scale context.

# %%
# Input and output channels are set to 1, since both images and probability
# maps only have one color channel.
unet = dl.UNet2d(
    in_channels=1, 
    channels=[8, 16, 24], 
    out_channels=1,
    )

# %% [markdown]
# Compile the model for the task of regressing the masks from the images.

# %%
# A U-Net regressor is defined using a deeplay model. The loss function is Mean
# Squared Error Loss, since the output is a continuous intensity map.
regressor_unet = dl.Regressor(
    model=unet, 
    loss=torch.nn.MSELoss(), 
    optimizer=dl.Adam(lr=1e-3),
).create()

# %% [markdown]
# Define the training pipeline using Deeptrack to generate the training dataset
# The training pipeline is composed of the simulated images and the probability maps, together with instructions of value normalization and a selector of images, all of which are instances of Deeplay.

# %%
# Image selector with a random picker. This is performed in order to properly 
# link an element in maps array with its corresponding element in images 
# array.
selector = dt.Lambda(
    lambda i: lambda x: x[i], i=lambda l: np.random.randint(l), l=len(images)
)

# Apply augmentations of added Gaussian noise only to images.
images_augmentation_pipeline = (
    dt.Value(images)
    >> dt.NormalizeMinMax(0.0, 1.0)
    >> dt.Gaussian(0.0, 0.05)
    >> dt.NormalizeMinMax(
        lambda: np.random.uniform(0.0, 0.1), 
        lambda: np.random.uniform(0.9, 1.0)
    )
)

# Apply normalization to ground truth map.
maps_pipeline = dt.Value(maps) >> dt.NormalizeMinMax(0.0, 1.0)

# Training pipeline consists of two paired lists: images and ground-truth maps.
# Images are augmented and normalized, while maps are only normalized.
# The selector randomly selects an image and its corresponding ground truth.
# The pipeline is then passed to the deeplay model.
pipeline = (
    (images_augmentation_pipeline & maps_pipeline)
    >> dt.FlipUD()
    >> dt.FlipLR()
    >> selector
)

# Create the training dataset instance in PyTorch
train_dataset = dt.pytorch.Dataset(pipeline, length=256)

# %% [markdown]
# Randomly select and display one augmented crop from the training dataset.

# %%
# Sanity check.
sanity_check_pipeline_augmentation = np.squeeze(pipeline.update().resolve())
sanity_check_image_augmentation = sanity_check_pipeline_augmentation[0]
sanity_check_map_augmentation = sanity_check_pipeline_augmentation[1]

# # Plot the image as the first subplot.
utils.plot_image_mask_ground_truth_map(
    image=sanity_check_image_augmentation,
    gt_map=sanity_check_map_augmentation,
    title=f"Random Augmentation from Training Pipeline",
)

# %% [markdown]
# ### Train the U-Net model

# %% [markdown]
# Create a dataloader to iterate over the training dataset in batches ensuring randomized sampling at each epoch. Initialize a Trainer from Deeplay to train the U-Net model for up to 64 epochs.

# %%
from torch.utils.data import DataLoader

# Create a DataLoader for training.
train_loader = DataLoader(
    train_dataset, 
    batch_size=16, 
    shuffle=True,
)

# Initialize UNet trainer with automatic accelerator (e.g., CUDA if available).
trainer_unet = dl.Trainer(max_epochs=64, accelerator="auto")
# Out:
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %% [markdown]
# Attempt to load pre-trained weights for the U-Net model. If the weights file does not exist, train the model from scratch and save the weights for future use.

# %%
# Force training if desired.
force_training = False

# Define the file paths for the model weights.
unet_path = "UNet_model_ellipsoids.pth"
regressor_unet_path = "UNet_reg_ellipsoids.pth"

# Define folder and construct full file paths.
folder_name = "UNet"
unet_path = os.path.join(folder_name, unet_path)
regressor_unet_path = os.path.join(folder_name, regressor_unet_path)

# Load preexisting weights if they exist and training is not forced.
if (not force_training and os.path.exists(unet_path)
    and os.path.exists(regressor_unet_path)):
    unet.load_state_dict(torch.load(unet_path, weights_only=True))
    regressor_unet.load_state_dict(
        torch.load(regressor_unet_path, weights_only=True)
    )
    print(f"Loaded preexisting U-Net weights from '{folder_name}/'.")
else:
    print("Training U-Net model (either forced or weights not found).")
    
    # Ensure the save directory exists.
    os.makedirs(folder_name, exist_ok=True)

    # Train the U-Net model.
    trainer_unet.fit(regressor_unet, train_loader)
    
    # Monitor training history.
    trainer_unet.history.plot()

    # Save the weights.
    torch.save(unet.state_dict(), unet_path)
    torch.save(regressor_unet.state_dict(), regressor_unet_path)
    print(f"Saved trained U-Net weights to '{folder_name}/'.")

# Transfer the model to the best available device (optional).
regressor_unet.to(device);
# Out:
# Loaded preexisting U-Net weights from 'UNet/'.

# %% [markdown]
# ### Apply the Trained U-Net to the Simulations

# %% [markdown]
# Use the trained U-Net to infer the probability map of the simulated image, leveraging the knowledge the model has learned. This output represents the predicted likelihood of particle presence at each pixel.
#
# First, convert the selected image to a PyTorch tensor and pass it through the trained U-Net to infer the probability map of particle locations.

# %%
# Convert the image to analyze into a PyTorch tensor.
formatted_sim_image = utils.format_image(sim_image).to(device)

# Apply the UNet to the loaded image.
sim_image_pred_map_tensor = regressor_unet(formatted_sim_image)

# Convert to NumPy array.
sim_image_pred_map = sim_image_pred_map_tensor[0,0,:,:].cpu().detach().numpy()

# Normalize intensity.
sim_image_pred_map = utils.normalize_min_max(sim_image_pred_map)

# %% [markdown]
# Apply thresholding to the predicted probability map to isolate potential particle regions.
#
# Calculate the centroids of the detected regions using the probability map as a weight. This enables subpixel localization by emphasizing the most confident regions of each detection.

# %%
# Apply thresholding to the predicted ground truth map.
sim_image_pred_mask_unet = sim_image_pred_map > 0.2

# Convert the masked ground truth map to positions.
sim_locs_pred_method3 = \
    utils.mask_to_positions(sim_image_pred_mask_unet, sim_image_pred_map)

# Show the predicted posiions and ground truth on the simulated image.
utils.plot_predicted_positions(
    image=sim_image,
    pred_positions=sim_locs_pred_method3, 
    gt_positions=sim_locs_gt,
    title="Method 3 - Simulated Image",
)
# Print the number of detections.
print(f"Found {len(sim_locs_pred_method3[:,1])} detections.")
# Out:
# Found 350 detections.

# %% [markdown]
# Evaluate performance by comparing the predicted coordinates with ground-truth positions.
#
# Visualize the results by displaying the original image with the localized particle positions overlaid, allowing you to qualitatively assess the accuracy of the prediction.

# %%
# Measure the performance.
utils.evaluate_locs(
    sim_locs_pred_method3, sim_locs_gt, distance_th=major_axis_length,
);

# Plot the predicted ground truth map and its masked version.
utils.plot_image_mask_ground_truth_map(
    mask=sim_image_pred_mask_unet,
    gt_map=sim_image_pred_map,
    title="Method 3 - Simulated Image",
)
# Out:
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3281

# %% [markdown]
# ### Apply the Trained U-Net to the Experiments

# %% [markdown]
# Use the trained U-Net model to predict where particles are in the experimental image:
#
# - Normalize the image so pixel values are between 0 and 1.
# - Reshape the image to match the input format expected by the network: (N, C, X, Y) → where N=1 (batch size), and C=1 (grayscale).
# - Convert the image to a PyTorch tensor and feed it to the U-Net.
# - The model returns a probability map showing where it thinks particles are most likely to be.
# - Normalize the predicted map again to scale between 0 and 1.
# - Apply a threshold to the probability map to create a binary mask.
# - Extract particle positions from this mask.
# - Plot both the experimental image with predicted positions and the model's output map + masked version for inspection.

# %%
# Convert the image to analyze into a PyTorch tensor.
formatted_exp_image = utils.format_image(exp_image[..., np.newaxis])

# Transfer the tensor to the best available device (optional).
formatted_exp_image = formatted_exp_image.to(device)

# Apply the UNet to the loaded image.
exp_image_pred_map_tensor = regressor_unet(formatted_exp_image)

# Convert to NumPy array.
exp_image_pred_map = exp_image_pred_map_tensor[0,0,:,:].cpu().detach().numpy()

# Normalize intensity.
exp_image_pred_map = utils.normalize_min_max(exp_image_pred_map)

# Apply thresholding to the predicted ground truth map.
exp_image_pred_mask_unet = exp_image_pred_map > 0.2

# Convert the masked ground truth map to positions.
exp_locs_pred_method3 = \
    utils.mask_to_positions(exp_image_pred_mask_unet, exp_image_pred_map)

# Plot the experimental image with the positions predicted by U-Net.
utils.plot_predicted_positions(
    image=exp_image, 
    pred_positions=exp_locs_pred_method3, 
    title="Method 3 - Experimental Image",
)

# Plot the predicted ground truth map and its masked version.
utils.plot_image_mask_ground_truth_map(
    mask=exp_image_pred_mask_unet,
    gt_map=exp_image_pred_map,
    title="Method 3 - Experimental Image",
)

# Print the number of detections.
print(f"Found {len(exp_locs_pred_method3[:,1])} detections.")
# Out:
# No ground truth positions were passed
# Found 294 detections.

# %% [markdown]
# ## Method 4: LodeSTAR

# %% [markdown]
# LodeSTAR is a self-supervised method for object detection that doesn’t require labeled data. You can even train it using a single input image—no manual annotations needed!
#
# The idea is simple but powerful: LodeSTAR learns to detect particles by finding consistent features across randomly transformed versions of the same image. These transformations can include translation, rotation, or scaling.
#
# By learning to predict the coordinate shifts between the transformed images, the network becomes very good at localizing objects—even under noisy or experimental conditions.
#
# This makes LodeSTAR especially useful when ground-truth labels are unavailable or unreliable, which is often the case in real microscopy work.

# %% [markdown]
# ### Simulate Training Data for LodeSTAR

# %% [markdown]
# To mimic real experimental conditions, we use DeepTrack to generate a set of synthetic images, each containing a single particle. These are produced using a mix of simulation and data augmentation. The particle’s size and intensity are randomized within realistic bounds, making the dataset more diverse and representative of what you'd expect in actual microscopy data.
#
# This setup reflects real use cases, where LodeSTAR is trained on augmentations of a single experimental crop.
#
# If the dataset already exists, you can simply load it; otherwise, new crops are simulated and saved.
#
# Finally, a few sample crops are visualized to confirm they look physically realistic.

# %%
# Number of samples, image size, and particles.
num_samples = 64
train_crops_size = 24
max_num_particles = 1
force_simulation = False  # Flag to force simulation even if data exists.

# Create path to store training dataset.
folder_name = "LodeSTAR"
training_dataset_filename = "LodeSTAR_training_dataset_ellipsoids.npz"
training_dataset_folder = os.path.join(folder_name, "training_data")
training_dataset_filepath = os.path.join(
    training_dataset_folder, 
    training_dataset_filename,
)

# Create the enclosing directory if not existent already.
os.makedirs(training_dataset_folder, exist_ok=True)

# Dictionaries for shell and core properties. Dimensions are set with lambda
# functions to introduce a bounded level of randomness to the dataset. 
ellipse_properties = {
    "radius": lambda: ((major_axis_length * np.random.normal(1, 0.1),
                        eccentricity * major_axis_length) * dt.units.nm),
    # "intensity": lambda: np.random.uniform(0.9, 1.1) * 0.35,
    "upscale_factor": 2,
}

# Set the optical properties of the microscope.
optics_properties = dt.Brightfield(
    NA=0.9,  # Numerical aperture
    wavelength=500 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, train_crops_size, train_crops_size],
    magnification=1,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
    upscale=1)


# Try to load preexisting simulated data; if not available or forced, raise the
# exception error to generate new data.
try:
    if force_simulation: 
        # Raise the exception error if simulation is forced.
        raise FileNotFoundError("Forced simulation by user request.")
    
    if not os.path.isfile(training_dataset_filepath):
        # If file is not found, start training.    
        raise FileNotFoundError(
            "Training dataset file not found. Starting simulation."
        )
    
    # Load existing data
    data = np.load(training_dataset_filepath)
    crop_images = data["crop_images"]
    crop_maps = data["crop_maps"]
    Nsamples = len(crop_images)  # Update number of samples.
    print(f"Loaded file: {training_dataset_filepath}")
        
# Handle the case of either file not found or forced training.
except FileNotFoundError:
    
    # Perform simulation if file not found or forced.
    crop_images, crop_maps = utils.generate_particle_dataset(
        num_samples=num_samples,
        fov_size=train_crops_size,
        max_num_particles=max_num_particles,
        core_particle_dict=ellipse_properties,
        optics_properties=optics_properties,
        background_props={"poisson_snr": 40, "background_mean": 2},
    )

    # Save the simulated training dataset.
    np.savez(
        training_dataset_filepath, 
        crop_images=crop_images, 
        crop_maps=crop_maps,
    )
    print("Generated and saved new dataset.")
    
    # Plot up to 18 simulated crops.
utils.plot_crops(np.squeeze(crop_images), title="Simulated Crops")
# Out:
# Loaded file: LodeSTAR/training_data/LodeSTAR_training_dataset_ellipsoids.npz

# %% [markdown]
# Build a training pipeline that randomly selects and augments particle crops on the fly. Each crop is chosen randomly from the simulated dataset and normalized with slightly varying min/max values to mimic contrast and illumination changes.
#
# This setup creates a diverse training set without needing to store multiple augmented copies.

# %%
# Define the training pipeline with additional settings, such as multiplication
# of global intensity and Gaussian noise.
selector = dt.Lambda(
    lambda i: lambda x: x[i],
    i=lambda l: np.random.randint(l),
    l=len(crop_images),
)

# Define a training pipeline with augmentations. 
training_pipeline = (
    dt.Value(lambda: crop_images)
    # >> dt.NormalizeMinMax(0.0, 1.0, channel_axis=0)
    # >> dt.Gaussian(0.0, 0.025)
    >> dt.NormalizeMinMax(
        lambda: np.random.uniform(0.0, 0.1), 
        lambda: np.random.uniform(0.9, 1.0),
        # channel_axis=0
    )
    >> selector
)

# Build a training dataset with a pipeline that randomly selects a crop each
# time.
train_dataset = dt.pytorch.Dataset(
    training_pipeline,
    length=128,
)

# Dataloader contains the randomized training dataset and additional settings.
dataloader = dl.DataLoader(
    train_dataset,
    batch_size=12,
)

# We can check one of the elements in the training pipeline with augmentations.
sanity_check_crop = training_pipeline.update().resolve()

plt.figure()
plt.imshow(np.squeeze(sanity_check_crop), cmap="gray", aspect="equal")
plt.title("Random Crop from Training Pipeline")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Train LodeSTAR and Apply it to Simulations

# %% [markdown]
# Create a LodeSTAR model with 4 random geometric transformations per input and set up the trainer, which will handle the training loop.

# %%
#  Initialize the model.
lodestar = dl.LodeSTAR(
    n_transforms=6,
    optimizer=dl.Adam(lr=1e-3),
).build()

# Set up the trainer and specify number of epochs.
trainer_lodestar = dl.Trainer(max_epochs=50, accelerator="auto")

# %% [markdown]
# Check if pretrained weights already exist. Otherwise train LodeSTAR on the simulated crops using the training pipeline and save the trained weights for later use. Otherwise, simply load the existing weights from file.
#
# Finally, switch the model to evaluation mode, which disables training-specific behaviors.

# %%
# Define whether to force training even if weights exist.
force_training = True

# Define folder and path for storing LodeSTAR weights.
folder_name = "LodeSTAR"
lodestar_path = os.path.join(folder_name, "lodestar_weights_simulated")

# Train or load weights.
if not os.path.isfile(lodestar_path) or force_training:
    print("Training LodeSTAR model (either forced or weights not found).")
    
    # Ensure the save directory exists.
    os.makedirs(folder_name, exist_ok=True)
    
    # Train the model.
    trainer_lodestar.fit(lodestar, dataloader)
    
    # Save weights.
    torch.save(lodestar.state_dict(), lodestar_path)
    print(f"Saved LodeSTAR weights to '{lodestar_path}'.")
else:
    # Load pre-trained weights.
    lodestar.load_state_dict(torch.load(lodestar_path, weights_only=True))
    print(f"Loaded preexisting LodeSTAR weights from '{lodestar_path}'.")
    
# Monitor training history.
trainer_lodestar.history.plot()

# Set model to evaluation mode.
lodestar.eval();

# Transfer the model to the best available device (optional).
lodestar.to(device);
# Out:
# Training LodeSTAR model (either forced or weights not found).
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/lightning/pytorch/trainer/configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type                       ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ ConvolutionalNeuralNetwork │  251 K │ train │     0 │
# │ 1 │ between_loss  │ L1Loss                     │      0 │ train │     0 │
# │ 2 │ within_loss   │ L1Loss                     │      0 │ train │     0 │
# │ 3 │ train_metrics │ MetricCollection           │      0 │ train │     0 │
# │ 4 │ val_metrics   │ MetricCollection           │      0 │ train │     0 │
# │ 5 │ test_metrics  │ MetricCollection           │      0 │ train │     0 │
# │ 6 │ optimizer     │ Adam                       │      0 │ train │     0 │
# └───┴───────────────┴────────────────────────────┴────────┴───────┴───────┘
# Trainable params: 251 K
# Non-trainable params: 0
# Total params: 251 K
# Total estimated model params size (MB): 1
# Modules in train mode: 39
# Modules in eval mode: 0
# Total FLOPs: 0
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:317: The number of training batches (11) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Saved LodeSTAR weights to 'LodeSTAR/lodestar_weights_simulated'.

# %% [markdown]
# Apply the trained LodeSTAR model to a simulated image.  Set the inference parameters which control detection sensitivity. Get the prediction features, including the mass_feature, which can be useful for visualizing detections. Extract the final coordinates of the detected particles and print how many particles were detected.

# %%
# Parameters for inference.
alpha = 0.9
beta = 1 - alpha
cutoff = 0.97

# Extract predictions.
sim_image_pred_lodestar = \
    lodestar(formatted_sim_image.to(device)).squeeze().detach()

# Extract the mass feature from the prediction.
sim_image_mass_feature = sim_image_pred_lodestar[2].cpu()

# Infer on the pytorch image.
sim_locs_pred_method4 = lodestar.detect(
    formatted_sim_image,
    alpha = alpha,
    beta = beta, 
    mode = "quantile",
    cutoff = cutoff,
)[0]
                         
print(f"Found {len(sim_locs_pred_method4[:, 1])} detections.")
# Out:
# Found 350 detections.

# %% [markdown]
# Display mass features predicted for the simulated image.

# %%
plt.figure(figsize=(10, 5))

#  Subfigure 1, test image.
plt.subplot(1, 3, 1)
plt.imshow(sim_image, cmap="gray")
plt.axis("off")
plt.title("Simulated Image")

#  Subfigure 2, mass feature distribution.
plt.subplot(1, 3, 2)
plt.imshow(sim_image_mass_feature, cmap="gray")
plt.axis("off")
plt.title("Mass Features Predicted by LodeSTAR")

plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the predicted positions from LodeSTAR alongside the ground truth on the simulated image and quantify the performance.

# %%
# Plot the predicted positions and the ground truth overlaid on the simulated
# image.
utils.plot_predicted_positions(
    image=sim_image,
    pred_positions=sim_locs_pred_method4,
    gt_positions=sim_locs_gt,
    title="Method 4 Trained on Simulations - Simulated Image",
)
#  Evaluate performance.
utils.evaluate_locs(
    sim_locs_pred_method4, sim_locs_gt, distance_th=major_axis_length,
);
# Out:
# True Positives: 77/350
# False Positives: 273
# False Negatives: 273
# F1 Score: 0.2200
# RMSE: 6.9829

# %% [markdown]
# ### Apply the Trained LodeSTAR on Experiments

# %% [markdown]
# - Apply LodeSTAR to the experimental image using the same inference settings (alpha, beta, cutoff) as before.
# - Run the model to extract prediction features, including the mass channel.
# - Get the final particle coordinates and print the total number of detections.
# - Visualize the original experimental image and the mass feature map predicted by LodeSTAR.

# %%
#  Parameters for inference.
alpha = 0.5
beta = 1 - alpha
cutoff = 0.8

# Extract predictions and convert into a tensor
exp_image_pred_lodestar = \
    lodestar(formatted_exp_image.to(device)).squeeze().detach()

# Extract the mass feature from the prediction
exp_image_mass_feature = \
    exp_image_pred_lodestar[2].cpu()  # Transfer to CPU for plotting

# Infer positions from experimental image.
exp_locs_pred_method4 = lodestar.detect(
    formatted_exp_image,
    alpha = alpha,
    beta = beta, 
    mode = "quantile",
    cutoff = cutoff,
)[0]

print(f"Found {len(exp_locs_pred_method4[:,1])} detections.")

## Display predictions of experimental image
# Set the figure size
plt.figure(figsize=(10, 5))

#  Subfigure 1, test image.
plt.subplot(1, 3, 1)
plt.imshow(exp_image, cmap="gray")
plt.axis("off")
plt.title("Experimental Image")

#  Subfigure 2, mass features.
plt.subplot(1, 3, 2)
plt.imshow(exp_image_mass_feature, cmap="gray")
plt.axis("off")
plt.title("Mass Features Predicted by LodeSTAR")

plt.gca().set_aspect('equal', adjustable='box')
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Found 278 detections.

# %% [markdown]
# Display the experimental image with the predicted particle positions overlaid to visually inspect the detection quality.

# %%
utils.plot_predicted_positions(
   image=exp_image,
   pred_positions= exp_locs_pred_method4,
   title="Method 4 Trained on Simulations - Experimental Image",
)
# Out:
# No ground truth positions were passed

# %% [markdown]
# ### Train LodeSTAR with Experiments

# %% [markdown]
# Since LodeSTAR is self-supervised, you can train it directly on experimental crops—no ground-truth labels needed.
#
# Start by identifying a few representative particles in the experimental image. From these, extract small crops centered on the particles using the same code to get the first crop in this tutorial. These serve as the training data, and LodeSTAR learns by applying random transformations to these crops and predicting how the particle positions change.

# %%
# Define crop parameters: (x, y, width)
crop_params = [
    (398, 500, exp_crop_size),
    (421, 460, exp_crop_size),
    (426, 493, exp_crop_size),
    (487, 444, exp_crop_size),
    (593, 203, exp_crop_size),
    (626, 538, exp_crop_size),
    (27, 581, exp_crop_size),
]

# Extract particle-centered crops from the image.
exp_crops = [exp_image[np.newaxis, y - w//2:y + w//2, x - w//2:x + w//2]
             for x, y, w in crop_params]


# Plot up to 18 crops.
utils.plot_crops(np.squeeze(exp_crops), title="Experimental Crops")

# %% [markdown]
# Prepare the training pipeline with the selected experimental crops.

# %%
# Random selector of crops.
random_crop = lambda: random.choice(np.array(exp_crops))

# Define training pipeline.
training_pipeline = (
    dt.Value(random_crop)
    # >> dt.NormalizeMinMax(
    #     0.0, 
    #     1.0,
    #     channel_axis=0)
    # >> dt.Gaussian(0.0, 0.05)
    >> dt.NormalizeMinMax(
        lambda: np.random.uniform(0.0, 0.1), 
        lambda: np.random.uniform(0.9, 1.0),
        channel_axis=0
        )
    >> dt.pytorch.ToTensor(dtype=torch.float32)
)

# Build a training dataset with a pipeline that randomly selects a crop each
# time.
train_dataset = dt.pytorch.Dataset(
    training_pipeline,
    length=128,
)

# Dataloader contains the randomized training dataset and additional settings.
dataloader = dl.DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True,
)

# We can check one of the elements in the training pipeline with augmentations.
sanity_check_crop = training_pipeline.update().resolve()

plt.figure()
plt.imshow(np.squeeze(sanity_check_crop), cmap="gray")
plt.title("Random Crop from Training Pipeline")
plt.axis("off")
plt.show()

# %% [markdown]
# Create a LodeSTAR model with 8 random geometric transformations per input and set up the trainer, which will handle the training loop.

# %%
#  Initialize the model as a Deeplay instance.
lodestar_exp = dl.LodeSTAR(
    n_transforms=6, 
    optimizer=dl.Adam(lr=1e-3),
).build()

# Initialize the trainer.
trainer_lodestar_exp = dl.Trainer(max_epochs=50, accelerator="auto")

# %% [markdown]
# Check whether pre-trained LodeSTAR weights already exist on disk. If they are missing or if training is explicitly forced, the model is trained on the experimental crops using the specified training pipeline, and the resulting weights are saved for future use.
#
# If the weights are already available and training is not forced, they are simply loaded from file.
#
# Afterward, the model is set to evaluation mode, which disables training-specific behaviors, ensuring consistent behavior during inference.

# %%
# Define whether to force training even if weights exist.
force_training = False

# Define folder and path for storing LodeSTAR experimental weights.
folder_name = "LodeSTAR"
lodestar_exp_path = os.path.join(folder_name, "lodestar_weights_exp")

# Train or load weights.
if not os.path.isfile(lodestar_exp_path) or force_training:
    print("Training LodeSTAR on experimental data "
          "(either forced or weights not found).")
    
    # Ensure the save directory exists.
    os.makedirs(folder_name, exist_ok=True)

    # Train the model.
    trainer_lodestar_exp.fit(lodestar_exp, dataloader)
    
    # Monitor training history.
    trainer_lodestar_exp.history.plot()

    # Save weights.
    torch.save(lodestar_exp.state_dict(), lodestar_exp_path)
    print(f"Saved experimental LodeSTAR weights to '{lodestar_exp_path}'.")
else:
    # Load pre-trained weights.
    lodestar_exp.load_state_dict(
        torch.load(lodestar_exp_path, weights_only=True)
    )
    print(f"Loaded preexisting LodeSTAR weights from '{lodestar_exp_path}'.")


# Set model to evaluation mode.
lodestar_exp.eval();

# Transfer the model to the best available device (optional).
lodestar_exp.to(device);
# Out:
# Loaded preexisting LodeSTAR weights from 'LodeSTAR/lodestar_weights_exp'.

# %% [markdown]
# Apply the trained LodeSTAR model to an experimental image. Set the inference parameters which control detection sensitivity. Get the prediction features, including the mass_feature, which can be useful for visualizing detections. Extract the final coordinates of the detected particles and print how many particles were detected.

# %%
#  Parameters for inference.
alpha = 0.9
beta = 1 - alpha 
cutoff = 0.8

#  Extract predictions and convert into a tensor.
exp_image_pred_lodestar_exp = \
    lodestar_exp(formatted_exp_image.to(device)).squeeze().detach()

# Extract the mass feature from the prediction.
exp_image_mass_feature_exp = \
    exp_image_pred_lodestar_exp[2].cpu()  # Transfer to CPU for plotting

#  Infer positions from experimental image.
exp_locs_pred_method4_exp = lodestar_exp.detect(
    formatted_exp_image,
    alpha=alpha,
    beta=beta, 
    mode="quantile",
    cutoff=cutoff,
)[0]
                         
print(f"Found {len(exp_locs_pred_method4_exp[:,1])} detections.")
# Out:
# Found 303 detections.

# %% [markdown]
# Display mass features predicted for the experimental image.

# %%
# Set the figure size.
plt.figure(figsize=(10, 5))

#  Subfigure 1, test image.
plt.subplot(1, 3, 1)
plt.imshow(exp_image, cmap="gray")
plt.axis("off")
plt.title("Experimental Image")

#  Subfigure 2, mass feature distribution.
plt.subplot(1, 3, 2)
plt.imshow(exp_image_mass_feature_exp, cmap="gray")
plt.axis("off")
plt.title("Mass Features Predicted by LodeSTAR")

plt.gca().set_aspect('equal', adjustable='box')
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the predicted positions from LodeSTAR on the experimental image.

# %%
utils.plot_predicted_positions(
   image=exp_image,
   pred_positions= exp_locs_pred_method4_exp,
   title="Method 4 Trained on Experimental Crops - Experimental Image",
)
# Out:
# No ground truth positions were passed

# %% [markdown]
# # Detection statistics

# %%
from joblib import Parallel, delayed, parallel_config

# %%
def run_simulation(i):
    # Parameters of the simulation. 
    sim_image_size = 640
    N_particles = 350  # Number of particles in the image
    major_axis_length = 1000  # Size of the long ellipsoid semiaxis in nm
    eccentricity = 0.185  # Eccentricity of the ellipsoidal particle

    # Dictionary for particle properties. Dimensions are set with lambda functions
    # to introduce variety to the dataset.
    ellipse_properties = {
        "radius": lambda: (
            major_axis_length * np.random.normal(1, 0.1),
            eccentricity * major_axis_length
        ) * dt.units.nm,
        "intensity": lambda: np.random.uniform(0.9, 1.1) * 0.35,
        "upscale_factor": 2,
    }

    # Set the optical properties of the microscope.
    optics_properties = dt.Brightfield(
        NA=0.9,  # Numerical aperture
        wavelength=500 * dt.units.nm,
        refractive_index_medium=1.33,
        output_region=[0, 0, sim_image_size, sim_image_size],
        magnification=1,
        resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
    )

    # Generate ground truth positions.
    sim_locs_gt = utils.generate_centroids(
        num_particles=N_particles,
        fov_size=sim_image_size,
        particle_radius=major_axis_length,
    )

    # Simulate image.
    sim_image = utils.transform_to_video(
        sim_locs_gt,
        fov_size=sim_image_size,
        core_particle_props=ellipse_properties,
        optics_props=optics_properties,
        background_props={"poisson_snr": 100, "background_mean":5},
    )

    # Generate the ground truth as Gaussian clouds centered at the position of the
    # ellipsoids. The standard deviation of the Gaussians are set to be
    # proportional to the semiaxes of the corresponding particles.
    gt_cloud_size = np.array(
        [major_axis_length, eccentricity * major_axis_length]
    ) / 3

    # Generate ground truth map using the positions, orientations and size of 
    # particles.
    sim_map = utils.create_ground_truth_map(
        sim_locs_gt, 
        fov_size=sim_image_size, 
        sigma=gt_cloud_size
    )

    print(f"Finished simulation {i+1}")
    return sim_locs_gt, sim_image, sim_map


# Number of simulations.
N_simulations = 100

# Number of parallel workers.
N_workers = 12

# Run simulations in parallel.
results = Parallel(
    n_jobs=N_workers,
    verbose=10,
)(
    delayed(run_simulation)(i)
    for i in range(N_simulations)
)


# Arrays to store results.
sim_locs_gt_array = np.empty(N_simulations, dtype=object)
sim_image_array = np.empty(N_simulations, dtype=object)
sim_map_array = np.empty(N_simulations, dtype=object)

# Store results.
for i, (sim_locs_gt, sim_image, sim_map) in enumerate(results):
    sim_locs_gt_array[i] = sim_locs_gt
    sim_image_array[i] = sim_image
    sim_map_array[i] = sim_map

# Save arrays to working directory.
np.save("sim_locs_gt_array_ellipses.npy", sim_locs_gt_array)
np.save("sim_image_array_ellipses.npy", sim_image_array)
np.save("sim_map_array_ellipses.npy", sim_map_array)
# Out:
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1870: UserWarning: Brightfield imaging from ScatteredVolume assumes a weak-phase / projection approximation. Use ScatteredField for physically accurate brightfield simulations.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1891: UserWarning: Scatterer defines 'intensity', which is ignored in brightfield microscopy.
#   warnings.warn(
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/deeptrack/optical/optics.py:1900: UserWarning: No 'refractive_index' specified; using 'value' as a non-physical brightfield contrast. Results are not physically calibrated. Define 'refractive_index' for physically meaningful contrast.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 71
#      68 N_workers = 12
#      70 # Run simulations in parallel.
# ---> 71 results = Parallel(
#      72     n_jobs=N_workers,
#      73     verbose=10,
#      74 )(
#      75     delayed(run_simulation)(i)
#      76     for i in range(N_simulations)
#      77 )
#      80 # Arrays to store results.
#      81 sim_locs_gt_array = np.empty(N_simulations, dtype=object)
#
# File /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# If simulation was already performed

# %%
# Load ellipse arrays.
sim_locs_gt_array_ellipses = np.load(
    "sim_locs_gt_array_ellipses.npy",
    allow_pickle=True,
)

sim_image_array_ellipses = np.load(
    "sim_image_array_ellipses.npy",
    allow_pickle=True,
)

sim_map_array_ellipses = np.load(
    "sim_map_array_ellipses.npy",
    allow_pickle=True,
)

# %% [markdown]
# Perform threshold detection

# %%
def run_threshold_detection(sim_image, sim_locs_gt):

    # Apply a Gaussian filter to the image to smooth out noise.
    filtered_sim_image = scipy.ndimage.gaussian_filter(sim_image, sigma=2.0)

    # Extract the quantile-based threshold from each filtered image
    quantile=0.1
    quantile_threshold_filtered_sim = np.quantile(filtered_sim_image, quantile)


    # Create the binary mask by applying the threshold.
    sim_mask = filtered_sim_image < quantile_threshold_filtered_sim

    # Ensure the mask is a 2D array.
    sim_mask = np.squeeze(sim_mask)

    # Use the function to extract positions from mask.
    sim_locs_pred_method1 = utils.mask_to_positions(sim_mask)

    TP, FP, FN, F1, RMSE = utils.evaluate_locs(
        sim_locs_pred_method1, sim_locs_gt, distance_th=major_axis_length, pixel_size_nm=pixel_size_nm
    )

    # Estimate the location of the centroid of a masked particle image.
    sim_locs_pred_method1_ref = \
        utils.mask_to_positions(sim_mask, sim_image.squeeze())

    # Evaluate the performance.
    TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx = utils.evaluate_locs(
        sim_locs_pred_method1_ref, sim_locs_gt, distance_th=major_axis_length, pixel_size_nm=pixel_size_nm
    )

    return (
        TP, FP, FN, F1, RMSE,
        TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx,
    )


# Number of parallel workers.
N_workers = 16

# Apply threshold detection to all simulated images.
with parallel_config(
    backend="loky",
    n_jobs=N_workers,
    inner_max_num_threads=1,
):
    results = Parallel()(
        delayed(run_threshold_detection)(
            sim_image_array[i],
            sim_locs_gt_array[i],
        )
        for i in range(len(sim_image_array))
    )


# Convert results directly to a NumPy array.
results = np.asarray(results)

# Standard pixel-level localization.
TP_array_threshold   = results[:, 0]
FP_array_threshold   = results[:, 1]
FN_array_threshold   = results[:, 2]
F1_array_threshold   = results[:, 3]
RMSE_array_threshold = results[:, 4]

# Sub-pixel refined localization.
TP_subpx_array_threshold   = results[:, 5]
FP_subpx_array_threshold   = results[:, 6]
FN_subpx_array_threshold   = results[:, 7]
F1_subpx_array_threshold   = results[:, 8]
RMSE_subpx_array_threshold = results[:, 9]

print("Threshold method")
print("----------------")

print(f"TP:          {TP_array_threshold.mean():.2f} ± {TP_array_threshold.std():.2f}")
print(f"FP:          {FP_array_threshold.mean():.2f} ± {FP_array_threshold.std():.2f}")
print(f"FN:          {FN_array_threshold.mean():.2f} ± {FN_array_threshold.std():.2f}")
print(f"F1:          {F1_array_threshold.mean():.4f} ± {F1_array_threshold.std():.4f}")
print(f"RMSE:        {RMSE_array_threshold.mean():.4f} ± {RMSE_array_threshold.std():.4f}")

print("\nSub-pixel refined")
print("-----------------")

print(f"TP:          {TP_subpx_array_threshold.mean():.2f} ± {TP_subpx_array_threshold.std():.2f}")
print(f"FP:          {FP_subpx_array_threshold.mean():.2f} ± {FP_subpx_array_threshold.std():.2f}")
print(f"FN:          {FN_subpx_array_threshold.mean():.2f} ± {FN_subpx_array_threshold.std():.2f}")
print(f"F1:          {F1_subpx_array_threshold.mean():.4f} ± {F1_subpx_array_threshold.std():.4f}")
print(f"RMSE:        {RMSE_subpx_array_threshold.mean():.4f} ± {RMSE_subpx_array_threshold.std():.4f}")
# Out:
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.6858
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.6847
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7672
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.9364
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.8654
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7583
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.8651
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7588
# True Positives: 348/350
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9971
# RMSE: 0.7341
# True Positives: 348/350
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9957
# RMSE: 0.1304
# True Positives: 341/350
# False Positives: 2
# False Negatives: 9
# F1 Score: 0.9841
# RMSE: 1.1652
# True Positives: 348/350
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9971
# RMSE: 0.7348
# True Positives: 341/350
# False Positives: 2
# False Negatives: 9
# F1 Score: 0.9841
# RMSE: 1.1650
# True Positives: 348/350
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9957
# RMSE: 0.1313
# True Positives: 348/350
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9971
# RMSE: 0.7225
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.9082
# True Positives: 348/350
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9971
# RMSE: 0.7230
# True Positives: 340/350
# False Positives: 4
# False Negatives: 10
# F1 Score: 0.9798
# RMSE: 0.7708
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.9079
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.9018
# True Positives: 342/350
# False Positives: 3
# False Negatives: 8
# F1 Score: 0.9842
# RMSE: 0.7469
# True Positives: 340/350
# False Positives: 4
# False Negatives: 10
# F1 Score: 0.9798
# RMSE: 0.7694
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.9014
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7191
# True Positives: 340/350
# False Positives: 4
# False Negatives: 10
# F1 Score: 0.9798
# RMSE: 0.7466
# True Positives: 342/350
# False Positives: 3
# False Negatives: 8
# F1 Score: 0.9842
# RMSE: 0.7464
# True Positives: 342/350
# False Positives: 3
# False Negatives: 8
# F1 Score: 0.9842
# RMSE: 0.7499
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7182
# True Positives: 349/350
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9986
# RMSE: 0.5340
# True Positives: 340/350
# False Positives: 4
# False Negatives: 10
# F1 Score: 0.9798
# RMSE: 0.7476
# True Positives: 342/350
# False Positives: 3
# False Negatives: 8
# F1 Score: 0.9842
# RMSE: 0.7502
# True Positives: 342/350
# False Positives: 4
# False Negatives: 8
# F1 Score: 0.9828
# RMSE: 0.1348
# True Positives: 349/350
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9986
# RMSE: 0.5349
# True Positives: 342/350
# False Positives: 4
# False Negatives: 8
# F1 Score: 0.9828
# RMSE: 0.1357
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5501
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5491
# True Positives: 344/350
# False Positives: 1
# False Negatives: 6
# F1 Score: 0.9899
# RMSE: 1.0321
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5056
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5070
# True Positives: 342/350
# False Positives: 2
# False Negatives: 8
# F1 Score: 0.9856
# RMSE: 1.0558
# True Positives: 344/350
# False Positives: 3
# False Negatives: 6
# F1 Score: 0.9871
# RMSE: 0.1343
# True Positives: 342/350
# False Positives: 2
# False Negatives: 8
# F1 Score: 0.9856
# RMSE: 1.0566
# True Positives: 344/350
# False Positives: 1
# False Negatives: 6
# F1 Score: 0.9899
# RMSE: 1.0318
# True Positives: 344/350
# False Positives: 3
# False Negatives: 6
# F1 Score: 0.9871
# RMSE: 0.1351
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.9184
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.8826
# True Positives: 346/350
# False Positives: 0
# False Negatives: 4
# F1 Score: 0.9943
# RMSE: 0.6999
# True Positives: 346/350
# False Positives: 2
# False Negatives: 4
# F1 Score: 0.9914
# RMSE: 0.1260
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.9190
# True Positives: 346/350
# False Positives: 0
# False Negatives: 4
# F1 Score: 0.9943
# RMSE: 0.7006
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5500
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.8819
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5514
# True Positives: 346/350
# False Positives: 2
# False Negatives: 4
# F1 Score: 0.9914
# RMSE: 0.1272
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5351
# True Positives: 346/350
# False Positives: 2
# False Negatives: 4
# F1 Score: 0.9914
# RMSE: 0.1294
# True Positives: 339/350
# False Positives: 3
# False Negatives: 11
# F1 Score: 0.9798
# RMSE: 1.1777
# True Positives: 345/350
# False Positives: 0
# False Negatives: 5
# F1 Score: 0.9928
# RMSE: 1.1069
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7221
# True Positives: 339/350
# False Positives: 3
# False Negatives: 11
# F1 Score: 0.9798
# RMSE: 1.1779
# True Positives: 346/350
# False Positives: 2
# False Negatives: 4
# F1 Score: 0.9914
# RMSE: 0.1250
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5344
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7232
# True Positives: 346/350
# False Positives: 2
# False Negatives: 4
# F1 Score: 0.9914
# RMSE: 0.1303
# True Positives: 345/350
# False Positives: 0
# False Negatives: 5
# F1 Score: 0.9928
# RMSE: 1.1078
# True Positives: 344/350
# False Positives: 1
# False Negatives: 6
# F1 Score: 0.9899
# RMSE: 1.0339
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5239
# True Positives: 340/350
# False Positives: 4
# False Negatives: 10
# F1 Score: 0.9798
# RMSE: 0.1922
# True Positives: 341/350
# False Positives: 3
# False Negatives: 9
# F1 Score: 0.9827
# RMSE: 0.8997
# True Positives: 344/350
# False Positives: 1
# False Negatives: 6
# F1 Score: 0.9899
# RMSE: 1.0349
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7290
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5474
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5442
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7516
# True Positives: 342/350
# False Positives: 2
# False Negatives: 8
# F1 Score: 0.9856
# RMSE: 1.0548
# True Positives: 342/350
# False Positives: 3
# False Negatives: 8
# F1 Score: 0.9842
# RMSE: 0.7637
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7289
# True Positives: 341/350
# False Positives: 3
# False Negatives: 9
# F1 Score: 0.9827
# RMSE: 0.5746
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5245
# True Positives: 341/350
# False Positives: 3
# False Negatives: 9
# F1 Score: 0.9827
# RMSE: 0.9005
# True Positives: 339/350
# False Positives: 3
# False Negatives: 11
# F1 Score: 0.9798
# RMSE: 1.0683
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7514
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5472
# True Positives: 342/350
# False Positives: 2
# False Negatives: 8
# F1 Score: 0.9856
# RMSE: 1.0557
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5452
# True Positives: 342/350
# False Positives: 3
# False Negatives: 8
# F1 Score: 0.9842
# RMSE: 0.7633
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.8966
# True Positives: 341/350
# False Positives: 3
# False Negatives: 9
# F1 Score: 0.9827
# RMSE: 0.5233
# True Positives: 339/350
# False Positives: 3
# False Negatives: 11
# F1 Score: 0.9798
# RMSE: 1.0677
# True Positives: 346/350
# False Positives: 2
# False Negatives: 4
# F1 Score: 0.9914
# RMSE: 0.1258
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.8965
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7354
# True Positives: 344/350
# False Positives: 3
# False Negatives: 6
# F1 Score: 0.9871
# RMSE: 0.1286
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5216
# True Positives: 341/350
# False Positives: 3
# False Negatives: 9
# F1 Score: 0.9827
# RMSE: 0.5232
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7363
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.6329
# True Positives: 346/350
# False Positives: 2
# False Negatives: 4
# F1 Score: 0.9914
# RMSE: 0.1384
# True Positives: 344/350
# False Positives: 3
# False Negatives: 6
# F1 Score: 0.9871
# RMSE: 0.1296
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5203
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5559
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.8905
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7546
# True Positives: 346/350
# False Positives: 2
# False Negatives: 4
# F1 Score: 0.9914
# RMSE: 0.1392
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.6340
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5556
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.8919
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.5425
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1289
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7552
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5032
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1297
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.5431
# True Positives: 342/350
# False Positives: 3
# False Negatives: 8
# F1 Score: 0.9842
# RMSE: 0.7720
# True Positives: 342/350
# False Positives: 1
# False Negatives: 8
# F1 Score: 0.9870
# RMSE: 1.2615
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5042
# True Positives: 348/350
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9957
# RMSE: 0.1346
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5537
# True Positives: 342/350
# False Positives: 3
# False Negatives: 8
# F1 Score: 0.9842
# RMSE: 0.7718
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7629
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.4921
# True Positives: 342/350
# False Positives: 1
# False Negatives: 8
# F1 Score: 0.9870
# RMSE: 1.2614
# True Positives: 348/350
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9957
# RMSE: 0.1355
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5529
# True Positives: 340/350
# False Positives: 3
# False Negatives: 10
# F1 Score: 0.9812
# RMSE: 1.0644
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7620
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.4935
# True Positives: 340/350
# False Positives: 3
# False Negatives: 10
# F1 Score: 0.9812
# RMSE: 1.0647
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.9214
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5473
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.5247
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.9218
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5486
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5137
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.9165
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.5250
# True Positives: 342/350
# False Positives: 2
# False Negatives: 8
# F1 Score: 0.9856
# RMSE: 1.0191
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5133
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.5292
# True Positives: 345/350
# False Positives: 1
# False Negatives: 5
# F1 Score: 0.9914
# RMSE: 0.9171
# True Positives: 342/350
# False Positives: 2
# False Negatives: 8
# F1 Score: 0.9856
# RMSE: 1.0188
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.6939
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.5289
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5228
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.8491
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7051
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.6945
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5226
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.8501
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.5534
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7060
# True Positives: 347/350
# False Positives: 0
# False Negatives: 3
# F1 Score: 0.9957
# RMSE: 0.9133
# True Positives: 349/350
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9986
# RMSE: 0.5463
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.5537
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7641
# True Positives: 336/350
# False Positives: 5
# False Negatives: 14
# F1 Score: 0.9725
# RMSE: 1.0505
# True Positives: 344/350
# False Positives: 1
# False Negatives: 6
# F1 Score: 0.9899
# RMSE: 0.7685
# True Positives: 347/350
# False Positives: 0
# False Negatives: 3
# F1 Score: 0.9957
# RMSE: 0.9153
# True Positives: 349/350
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9986
# RMSE: 0.5476
# True Positives: 336/350
# False Positives: 5
# False Negatives: 14
# F1 Score: 0.9725
# RMSE: 1.0499
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7644
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5027
# True Positives: 344/350
# False Positives: 1
# False Negatives: 6
# F1 Score: 0.9899
# RMSE: 0.7682
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5522
# True Positives: 347/350
# False Positives: 0
# False Negatives: 3
# F1 Score: 0.9957
# RMSE: 0.9024
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5016
# True Positives: 348/350
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9971
# RMSE: 0.7187
# True Positives: 343/350
# False Positives: 3
# False Negatives: 7
# F1 Score: 0.9856
# RMSE: 0.5526
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.5209
# True Positives: 347/350
# False Positives: 0
# False Negatives: 3
# F1 Score: 0.9957
# RMSE: 0.9021
# True Positives: 348/350
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9971
# RMSE: 0.7200
# True Positives: 345/350
# False Positives: 0
# False Negatives: 5
# F1 Score: 0.9928
# RMSE: 0.9209
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7532
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.5210
# True Positives: 341/350
# False Positives: 4
# False Negatives: 9
# F1 Score: 0.9813
# RMSE: 0.4756
# True Positives: 345/350
# False Positives: 0
# False Negatives: 5
# F1 Score: 0.9928
# RMSE: 0.9218
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7535
# True Positives: 337/350
# False Positives: 5
# False Negatives: 13
# F1 Score: 0.9740
# RMSE: 0.9394
# True Positives: 341/350
# False Positives: 4
# False Negatives: 9
# F1 Score: 0.9813
# RMSE: 0.4754
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7406
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.9356
# True Positives: 337/350
# False Positives: 5
# False Negatives: 13
# F1 Score: 0.9740
# RMSE: 0.9411
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1318
# True Positives: 346/350
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9928
# RMSE: 0.7398
# True Positives: 343/350
# False Positives: 2
# False Negatives: 7
# F1 Score: 0.9871
# RMSE: 0.9355
# True Positives: 341/350
# False Positives: 2
# False Negatives: 9
# F1 Score: 0.9841
# RMSE: 0.9270
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5371
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1324
# True Positives: 337/350
# False Positives: 5
# False Negatives: 13
# F1 Score: 0.9740
# RMSE: 0.9306
# True Positives: 341/350
# False Positives: 2
# False Negatives: 9
# F1 Score: 0.9841
# RMSE: 0.9272
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5369
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5505
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7635
# True Positives: 337/350
# False Positives: 5
# False Negatives: 13
# F1 Score: 0.9740
# RMSE: 0.9313
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5521
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5520
# True Positives: 344/350
# False Positives: 2
# False Negatives: 6
# F1 Score: 0.9885
# RMSE: 0.7635
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.4938
# True Positives: 347/350
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9943
# RMSE: 0.5519
# True Positives: 345/350
# False Positives: 2
# False Negatives: 5
# F1 Score: 0.9900
# RMSE: 0.4923
# Threshold method
# ----------------
# TP:          344.33 ± 2.75
# FP:          1.79 ± 1.19
# FN:          5.67 ± 2.75
# F1:          0.9893 ± 0.0055
# RMSE:        0.6758 ± 0.2716
#
# Sub-pixel refined
# -----------------
# TP:          344.35 ± 2.73
# FP:          1.77 ± 1.17
# FN:          5.65 ± 2.73
# F1:          0.9893 ± 0.0055
# RMSE:        0.6816 ± 0.2684

# %%
def run_crocker_grier_detection(sim_image, sim_locs_gt):

    # Estimate and tune the diameter of particles in pixels, ensuring it is an
    # odd number. Adjust if necessary.
    estimated_size_sim = 25

    # Use the locate built-in function from TrackPy.
    # Output is type DataFrame([x, y, mass, size, ecc, signal, raw_mass]).
    df_sim_locs_pred_method2 = tp.locate(
        sim_image, 
        diameter=estimated_size_sim,
        invert=True,  # Invert the image
        noise_size=4,  # Setting for denoising image
        separation=15 # Minimum separation distabce between particles, in px.
    )

    # Extract the predicted positions from DataFrame["x","y"] into a NumPy array.
    sim_locs_pred_method2 = np.array(df_sim_locs_pred_method2)[:, :2]

    TP, FP, FN, F1, RMSE = utils.evaluate_locs(
        sim_locs_pred_method2,
        sim_locs_gt,
        distance_th=major_axis_length, 
        pixel_size_nm=pixel_size_nm
    )

    return TP, FP, FN, F1, RMSE
        
N_workers = 16

with parallel_config(
    backend="loky",
    n_jobs=N_workers,
    inner_max_num_threads=1,
):
    results = Parallel()(
        delayed(run_crocker_grier_detection)(
            sim_image_array[i],
            sim_locs_gt_array[i],
        )
        for i in range(len(sim_image_array))
    )

results = np.asarray(results)

TP_array_CG   = results[:, 0]
FP_array_CG   = results[:, 1]
FN_array_CG   = results[:, 2]
F1_array_CG   = results[:, 3]
RMSE_array_CG = results[:, 4]


# Convert results directly to a NumPy array.
results = np.asarray(results)

# Standard pixel-level localization.
TP_array_CG   = results[:, 0]
FP_array_CG   = results[:, 1]
FN_array_CG  = results[:, 2]
F1_array_CG   = results[:, 3]
RMSE_array_CG = results[:, 4]



print("Crocker-Grier method")
print("----------------")

print(f"TP:          {TP_array_CG.mean():.2f} ± {TP_array_CG.std():.2f}")
print(f"FP:          {FP_array_CG.mean():.2f} ± {FP_array_CG.std():.2f}")
print(f"FN:          {FN_array_CG.mean():.2f} ± {FN_array_CG.std():.2f}")
print(f"F1:          {F1_array_CG.mean():.4f} ± {F1_array_CG.std():.4f}")
print(f"RMSE:        {RMSE_array_CG.mean():.4f} ± {RMSE_array_CG.std():.4f}")
# Out:
# True Positives: 318/350
# False Positives: 10
# False Negatives: 32
# F1 Score: 0.9381
# RMSE: 0.5088
# True Positives: 325/350
# False Positives: 6
# False Negatives: 25
# F1 Score: 0.9545
# RMSE: 0.7528
# True Positives: 323/350
# False Positives: 6
# False Negatives: 27
# F1 Score: 0.9514
# RMSE: 0.5632
# True Positives: 317/350
# False Positives: 6
# False Negatives: 33
# F1 Score: 0.9421
# RMSE: 0.5290
# True Positives: 321/350
# False Positives: 9
# False Negatives: 29
# F1 Score: 0.9441
# RMSE: 0.5162
# True Positives: 316/350
# False Positives: 7
# False Negatives: 34
# F1 Score: 0.9391
# RMSE: 0.5302
# True Positives: 321/350
# False Positives: 9
# False Negatives: 29
# F1 Score: 0.9441
# RMSE: 0.4833
# True Positives: 324/350
# False Positives: 9
# False Negatives: 26
# F1 Score: 0.9488
# RMSE: 0.4976
# True Positives: 315/350
# False Positives: 8
# False Negatives: 35
# F1 Score: 0.9361
# RMSE: 0.4961
# True Positives: 329/350
# False Positives: 8
# False Negatives: 21
# F1 Score: 0.9578
# RMSE: 0.5538
# True Positives: 320/350
# False Positives: 7
# False Negatives: 30
# F1 Score: 0.9453
# RMSE: 0.4834
# True Positives: 323/350
# False Positives: 12
# False Negatives: 27
# F1 Score: 0.9431
# RMSE: 0.7850
# True Positives: 318/350
# False Positives: 8
# False Negatives: 32
# F1 Score: 0.9408
# RMSE: 0.6399
# True Positives: 322/350
# False Positives: 7
# False Negatives: 28
# F1 Score: 0.9485
# RMSE: 0.6134
# True Positives: 319/350
# False Positives: 16
# False Negatives: 31
# F1 Score: 0.9314
# RMSE: 0.4831
# True Positives: 320/350
# False Positives: 14
# False Negatives: 30
# F1 Score: 0.9357
# RMSE: 0.5861
# True Positives: 320/350
# False Positives: 11
# False Negatives: 30
# F1 Score: 0.9398
# RMSE: 0.4849
# True Positives: 322/350
# False Positives: 9
# False Negatives: 28
# F1 Score: 0.9457
# RMSE: 0.5993
# True Positives: 324/350
# False Positives: 4
# False Negatives: 26
# F1 Score: 0.9558
# RMSE: 0.5341
# True Positives: 325/350
# False Positives: 6
# False Negatives: 25
# F1 Score: 0.9545
# RMSE: 0.7044
# True Positives: 318/350
# False Positives: 10
# False Negatives: 32
# F1 Score: 0.9381
# RMSE: 0.5235
# True Positives: 318/350
# False Positives: 14
# False Negatives: 32
# F1 Score: 0.9326
# RMSE: 0.4555
# True Positives: 320/350
# False Positives: 4
# False Negatives: 30
# F1 Score: 0.9496
# RMSE: 0.6694
# True Positives: 320/350
# False Positives: 12
# False Negatives: 30
# F1 Score: 0.9384
# RMSE: 0.5083
# True Positives: 325/350
# False Positives: 10
# False Negatives: 25
# F1 Score: 0.9489
# RMSE: 0.5265
# True Positives: 309/350
# False Positives: 5
# False Negatives: 41
# F1 Score: 0.9307
# RMSE: 0.7063
# True Positives: 323/350
# False Positives: 6
# False Negatives: 27
# F1 Score: 0.9514
# RMSE: 0.6302
# True Positives: 326/350
# False Positives: 7
# False Negatives: 24
# F1 Score: 0.9546
# RMSE: 0.5820
# True Positives: 319/350
# False Positives: 13
# False Negatives: 31
# F1 Score: 0.9355
# RMSE: 0.5364
# True Positives: 321/350
# False Positives: 12
# False Negatives: 29
# F1 Score: 0.9400
# RMSE: 0.5348
# True Positives: 311/350
# False Positives: 7
# False Negatives: 39
# F1 Score: 0.9311
# RMSE: 0.5366
# True Positives: 322/350
# False Positives: 7
# False Negatives: 28
# F1 Score: 0.9485
# RMSE: 0.4979
# True Positives: 314/350
# False Positives: 14
# False Negatives: 36
# F1 Score: 0.9263
# RMSE: 0.4583
# True Positives: 318/350
# False Positives: 11
# False Negatives: 32
# F1 Score: 0.9367
# RMSE: 0.7171
# True Positives: 315/350
# False Positives: 10
# False Negatives: 35
# F1 Score: 0.9333
# RMSE: 0.5614
# True Positives: 327/350
# False Positives: 7
# False Negatives: 23
# F1 Score: 0.9561
# RMSE: 0.4884
# True Positives: 320/350
# False Positives: 10
# False Negatives: 30
# F1 Score: 0.9412
# RMSE: 0.6525
# True Positives: 321/350
# False Positives: 8
# False Negatives: 29
# F1 Score: 0.9455
# RMSE: 0.4602
# True Positives: 320/350
# False Positives: 9
# False Negatives: 30
# F1 Score: 0.9426
# RMSE: 0.4768
# True Positives: 320/350
# False Positives: 11
# False Negatives: 30
# F1 Score: 0.9398
# RMSE: 0.5195
# True Positives: 316/350
# False Positives: 12
# False Negatives: 34
# F1 Score: 0.9322
# RMSE: 0.5763
# True Positives: 321/350
# False Positives: 9
# False Negatives: 29
# F1 Score: 0.9441
# RMSE: 0.5650
# True Positives: 321/350
# False Positives: 6
# False Negatives: 29
# F1 Score: 0.9483
# RMSE: 0.5115
# True Positives: 325/350
# False Positives: 4
# False Negatives: 25
# F1 Score: 0.9573
# RMSE: 0.5533
# True Positives: 318/350
# False Positives: 9
# False Negatives: 32
# F1 Score: 0.9394
# RMSE: 0.4785
# True Positives: 325/350
# False Positives: 8
# False Negatives: 25
# F1 Score: 0.9517
# RMSE: 0.5355
# True Positives: 324/350
# False Positives: 7
# False Negatives: 26
# F1 Score: 0.9515
# RMSE: 0.5679
# True Positives: 329/350
# False Positives: 6
# False Negatives: 21
# F1 Score: 0.9606
# RMSE: 0.5485
# True Positives: 320/350
# False Positives: 8
# False Negatives: 30
# F1 Score: 0.9440
# RMSE: 0.6136
# True Positives: 311/350
# False Positives: 13
# False Negatives: 39
# F1 Score: 0.9228
# RMSE: 0.5570
# True Positives: 322/350
# False Positives: 9
# False Negatives: 28
# F1 Score: 0.9457
# RMSE: 0.4696
# True Positives: 321/350
# False Positives: 11
# False Negatives: 29
# F1 Score: 0.9413
# RMSE: 0.7584
# True Positives: 315/350
# False Positives: 9
# False Negatives: 35
# F1 Score: 0.9347
# RMSE: 0.4282
# True Positives: 321/350
# False Positives: 10
# False Negatives: 29
# F1 Score: 0.9427
# RMSE: 0.4666
# True Positives: 323/350
# False Positives: 9
# False Negatives: 27
# F1 Score: 0.9472
# RMSE: 0.5731
# True Positives: 320/350
# False Positives: 11
# False Negatives: 30
# F1 Score: 0.9398
# RMSE: 0.5241
# True Positives: 300/350
# False Positives: 7
# False Negatives: 50
# F1 Score: 0.9132
# RMSE: 0.6575
# True Positives: 313/350
# False Positives: 12
# False Negatives: 37
# F1 Score: 0.9274
# RMSE: 0.6459
# True Positives: 315/350
# False Positives: 10
# False Negatives: 35
# F1 Score: 0.9333
# RMSE: 0.6938
# True Positives: 310/350
# False Positives: 14
# False Negatives: 40
# F1 Score: 0.9199
# RMSE: 0.5676
# True Positives: 316/350
# False Positives: 8
# False Negatives: 34
# F1 Score: 0.9377
# RMSE: 0.5337
# True Positives: 317/350
# False Positives: 11
# False Negatives: 33
# F1 Score: 0.9351
# RMSE: 0.4661
# True Positives: 316/350
# False Positives: 5
# False Negatives: 34
# F1 Score: 0.9419
# RMSE: 0.4746
# True Positives: 314/350
# False Positives: 10
# False Negatives: 36
# F1 Score: 0.9318
# RMSE: 0.7222
# True Positives: 313/350
# False Positives: 8
# False Negatives: 37
# F1 Score: 0.9329
# RMSE: 0.4785
# True Positives: 315/350
# False Positives: 8
# False Negatives: 35
# F1 Score: 0.9361
# RMSE: 0.5222
# True Positives: 321/350
# False Positives: 9
# False Negatives: 29
# F1 Score: 0.9441
# RMSE: 0.4942
# True Positives: 319/350
# False Positives: 6
# False Negatives: 31
# F1 Score: 0.9452
# RMSE: 0.5770
# True Positives: 320/350
# False Positives: 5
# False Negatives: 30
# F1 Score: 0.9481
# RMSE: 0.5032
# True Positives: 323/350
# False Positives: 7
# False Negatives: 27
# F1 Score: 0.9500
# RMSE: 0.4952
# True Positives: 323/350
# False Positives: 10
# False Negatives: 27
# F1 Score: 0.9458
# RMSE: 0.5931
# True Positives: 329/350
# False Positives: 8
# False Negatives: 21
# F1 Score: 0.9578
# RMSE: 0.6400
# True Positives: 319/350
# False Positives: 8
# False Negatives: 31
# F1 Score: 0.9424
# RMSE: 0.5247
# True Positives: 320/350
# False Positives: 13
# False Negatives: 30
# F1 Score: 0.9370
# RMSE: 0.5150
# True Positives: 318/350
# False Positives: 12
# False Negatives: 32
# F1 Score: 0.9353
# RMSE: 0.5035
# True Positives: 317/350
# False Positives: 9
# False Negatives: 33
# F1 Score: 0.9379
# RMSE: 0.6547
# True Positives: 314/350
# False Positives: 12
# False Negatives: 36
# F1 Score: 0.9290
# RMSE: 0.6217
# True Positives: 320/350
# False Positives: 12
# False Negatives: 30
# F1 Score: 0.9384
# RMSE: 0.6656
# True Positives: 313/350
# False Positives: 11
# False Negatives: 37
# F1 Score: 0.9288
# RMSE: 0.5260
# True Positives: 320/350
# False Positives: 7
# False Negatives: 30
# F1 Score: 0.9453
# RMSE: 0.5892
# True Positives: 326/350
# False Positives: 7
# False Negatives: 24
# F1 Score: 0.9546
# RMSE: 0.6091
# True Positives: 326/350
# False Positives: 7
# False Negatives: 24
# F1 Score: 0.9546
# RMSE: 0.6168
# True Positives: 319/350
# False Positives: 10
# False Negatives: 31
# F1 Score: 0.9396
# RMSE: 0.6522
# True Positives: 321/350
# False Positives: 11
# False Negatives: 29
# F1 Score: 0.9413
# RMSE: 0.5575
# True Positives: 313/350
# False Positives: 7
# False Negatives: 37
# F1 Score: 0.9343
# RMSE: 0.8043
# True Positives: 325/350
# False Positives: 5
# False Negatives: 25
# F1 Score: 0.9559
# RMSE: 0.5608
# True Positives: 317/350
# False Positives: 8
# False Negatives: 33
# F1 Score: 0.9393
# RMSE: 0.5042
# True Positives: 323/350
# False Positives: 7
# False Negatives: 27
# F1 Score: 0.9500
# RMSE: 0.5436
# True Positives: 318/350
# False Positives: 9
# False Negatives: 32
# F1 Score: 0.9394
# RMSE: 0.7660
# True Positives: 316/350
# False Positives: 7
# False Negatives: 34
# F1 Score: 0.9391
# RMSE: 0.4849
# True Positives: 323/350
# False Positives: 11
# False Negatives: 27
# F1 Score: 0.9444
# RMSE: 0.5430
# True Positives: 322/350
# False Positives: 8
# False Negatives: 28
# F1 Score: 0.9471
# RMSE: 0.8487
# True Positives: 320/350
# False Positives: 17
# False Negatives: 30
# F1 Score: 0.9316
# RMSE: 0.5423
# True Positives: 318/350
# False Positives: 16
# False Negatives: 32
# F1 Score: 0.9298
# RMSE: 0.6255
# True Positives: 320/350
# False Positives: 5
# False Negatives: 30
# F1 Score: 0.9481
# RMSE: 0.5494
# True Positives: 317/350
# False Positives: 11
# False Negatives: 33
# F1 Score: 0.9351
# RMSE: 0.4880
# True Positives: 318/350
# False Positives: 10
# False Negatives: 32
# F1 Score: 0.9381
# RMSE: 0.6226
# True Positives: 320/350
# False Positives: 13
# False Negatives: 30
# F1 Score: 0.9370
# RMSE: 0.5113
# True Positives: 321/350
# False Positives: 12
# False Negatives: 29
# F1 Score: 0.9400
# RMSE: 0.5341
# True Positives: 319/350
# False Positives: 10
# False Negatives: 31
# F1 Score: 0.9396
# RMSE: 0.5697
# Crocker-Grier method
# ----------------
# TP:          319.48 ± 4.54
# FP:          9.13 ± 2.76
# FN:          30.52 ± 4.54
# F1:          0.9415 ± 0.0088
# RMSE:        0.5671 ± 0.0856

# %% [markdown]
# U-Net image regression-based detection

# %%
def run_unet_regression_detection(sim_image, sim_locs_gt):

    # Convert the image to analyze into a PyTorch tensor.
    formatted_sim_image = utils.format_image(sim_image).to(device)

    # Apply the UNet to the loaded image.
    with torch.inference_mode():
        sim_image_pred_map_tensor = regressor_unet(formatted_sim_image)

    # Convert to NumPy array.
    sim_image_pred_map = (
        sim_image_pred_map_tensor[0, 0, :, :]
        .cpu()
        .detach()
        .numpy()
    )

    # Normalize intensity.
    sim_image_pred_map = utils.normalize_min_max(sim_image_pred_map)

    # Apply thresholding to the predicted ground truth map.
    sim_image_pred_mask_unet = sim_image_pred_map > 0.25

    # Extract predicted positions.
    sim_locs_pred_unet = utils.mask_to_positions(
        sim_image_pred_mask_unet
    )

    # Evaluate the performance.
    TP, FP, FN, F1, RMSE = utils.evaluate_locs(
        sim_locs_pred_unet,
        sim_locs_gt,
        distance_th=major_axis_length, 
        pixel_size_nm=pixel_size_nm
    )

    # Estimate sub-pixel positions using the predicted regression map.
    sim_locs_pred_unet_ref = utils.mask_to_positions(
        sim_image_pred_mask_unet,
        sim_image_pred_map,
    )

    # Evaluate the refined positions.
    TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx = utils.evaluate_locs(
        sim_locs_pred_unet_ref,
        sim_locs_gt,
        distance_th=major_axis_length, 
        pixel_size_nm=pixel_size_nm
    )

    return (
        TP, FP, FN, F1, RMSE,
        TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx,
    )

# %%
results = []

regressor_unet.eval()

for i in range(len(sim_image_array)):
    results.append(
        run_unet_regression_detection(
            sim_image_array[i],
            sim_locs_gt_array[i],
        )
    )

results = np.asarray(results)

# Standard localization.
TP_array_UNet   = results[:, 0]
FP_array_UNet   = results[:, 1]
FN_array_UNet   = results[:, 2]
F1_array_UNet   = results[:, 3]
RMSE_array_UNet = results[:, 4]

# Sub-pixel refined localization.
TP_subpx_array_UNet   = results[:, 5]
FP_subpx_array_UNet   = results[:, 6]
FN_subpx_array_UNet   = results[:, 7]
F1_subpx_array_UNet   = results[:, 8]
RMSE_subpx_array_UNet = results[:, 9]

print("U-Net method")
print("----------------")

print(f"TP:          {TP_array_UNet.mean():.2f} ± {TP_array_UNet.std():.2f}")
print(f"FP:          {FP_array_UNet.mean():.2f} ± {FP_array_UNet.std():.2f}")
print(f"FN:          {FN_array_UNet.mean():.2f} ± {FN_array_UNet.std():.2f}")
print(f"F1:          {F1_array_UNet.mean():.4f} ± {F1_array_UNet.std():.4f}")
print(f"RMSE:        {RMSE_array_UNet.mean():.4f} ± {RMSE_array_UNet.std():.4f}")
# Out:
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.3604
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.3283
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.4044
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3722
# True Positives: 350/350
# False Positives: 14
# False Negatives: 0
# F1 Score: 0.9804
# RMSE: 0.3996
# True Positives: 350/350
# False Positives: 14
# False Negatives: 0
# F1 Score: 0.9804
# RMSE: 0.3559
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.4072
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3644
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4145
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3669
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4262
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3756
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.3886
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.3640
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3880
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3490
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3859
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3657
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3993
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3657
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3933
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3606
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.4119
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3919
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4095
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3700
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.4326
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3727
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.3842
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.3501
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4021
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3664
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.4041
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.3754
# True Positives: 350/350
# False Positives: 9
# False Negatives: 0
# F1 Score: 0.9873
# RMSE: 0.3894
# True Positives: 350/350
# False Positives: 9
# False Negatives: 0
# F1 Score: 0.9873
# RMSE: 0.3481
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.4106
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3779
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4377
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3935
# True Positives: 350/350
# False Positives: 10
# False Negatives: 0
# F1 Score: 0.9859
# RMSE: 0.4366
# True Positives: 350/350
# False Positives: 10
# False Negatives: 0
# F1 Score: 0.9859
# RMSE: 0.4044
# True Positives: 350/350
# False Positives: 12
# False Negatives: 0
# F1 Score: 0.9831
# RMSE: 0.4262
# True Positives: 350/350
# False Positives: 12
# False Negatives: 0
# F1 Score: 0.9831
# RMSE: 0.3904
# True Positives: 350/350
# False Positives: 10
# False Negatives: 0
# F1 Score: 0.9859
# RMSE: 0.4132
# True Positives: 350/350
# False Positives: 10
# False Negatives: 0
# F1 Score: 0.9859
# RMSE: 0.3763
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.4137
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3741
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.4155
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.3839
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4709
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4461
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3865
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3548
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.4060
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.3681
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.4063
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.3732
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.4375
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3913
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3867
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3483
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4036
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3893
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3802
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3464
# True Positives: 350/350
# False Positives: 13
# False Negatives: 0
# F1 Score: 0.9818
# RMSE: 0.4359
# True Positives: 350/350
# False Positives: 13
# False Negatives: 0
# F1 Score: 0.9818
# RMSE: 0.3896
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4175
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3681
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.4091
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.3709
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3900
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3607
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4602
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4278
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.4153
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3673
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4070
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3721
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.3904
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.3490
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3985
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3627
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4044
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3635
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4187
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3919
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.4240
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.4176
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3903
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3552
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.4068
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3675
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.3884
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.3601
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3612
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3347
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4149
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3708
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3847
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3433
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.4090
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.3867
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4212
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3736
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4046
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3687
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4085
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3698
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3892
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3403
# True Positives: 350/350
# False Positives: 15
# False Negatives: 0
# F1 Score: 0.9790
# RMSE: 0.4363
# True Positives: 350/350
# False Positives: 15
# False Negatives: 0
# F1 Score: 0.9790
# RMSE: 0.3919
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.4068
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3627
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3957
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3631
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3758
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3387
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4048
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3859
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3661
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3363
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3911
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3512
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3865
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3439
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.4081
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3630
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.4204
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.3828
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3815
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3551
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3980
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3573
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4048
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3616
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4248
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3728
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.4028
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3697
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3669
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3418
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3510
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3158
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4156
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3693
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3602
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3207
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3918
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.3605
# True Positives: 350/350
# False Positives: 9
# False Negatives: 0
# F1 Score: 0.9873
# RMSE: 0.4050
# True Positives: 350/350
# False Positives: 9
# False Negatives: 0
# F1 Score: 0.9873
# RMSE: 0.3644
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4175
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3707
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4045
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3597
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.4097
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.3765
# True Positives: 350/350
# False Positives: 9
# False Negatives: 0
# F1 Score: 0.9873
# RMSE: 0.4175
# True Positives: 350/350
# False Positives: 9
# False Negatives: 0
# F1 Score: 0.9873
# RMSE: 0.3911
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4329
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4067
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3886
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.3541
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3830
# True Positives: 350/350
# False Positives: 5
# False Negatives: 0
# F1 Score: 0.9929
# RMSE: 0.3526
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4154
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3797
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.4297
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.3642
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.4092
# True Positives: 350/350
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9972
# RMSE: 0.3642
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.4128
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3883
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3842
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3513
# True Positives: 350/350
# False Positives: 12
# False Negatives: 0
# F1 Score: 0.9831
# RMSE: 0.4084
# True Positives: 350/350
# False Positives: 12
# False Negatives: 0
# F1 Score: 0.9831
# RMSE: 0.3737
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4420
# True Positives: 350/350
# False Positives: 8
# False Negatives: 0
# F1 Score: 0.9887
# RMSE: 0.4000
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.4249
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.3828
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.4092
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3709
# True Positives: 350/350
# False Positives: 9
# False Negatives: 0
# F1 Score: 0.9873
# RMSE: 0.3947
# True Positives: 350/350
# False Positives: 9
# False Negatives: 0
# F1 Score: 0.9873
# RMSE: 0.3682
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.4188
# True Positives: 350/350
# False Positives: 7
# False Negatives: 0
# F1 Score: 0.9901
# RMSE: 0.3736
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.4107
# True Positives: 350/350
# False Positives: 4
# False Negatives: 0
# F1 Score: 0.9943
# RMSE: 0.3688
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3906
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.3543
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.4039
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.3799
# True Positives: 350/350
# False Positives: 10
# False Negatives: 0
# F1 Score: 0.9859
# RMSE: 0.4577
# True Positives: 350/350
# False Positives: 10
# False Negatives: 0
# F1 Score: 0.9859
# RMSE: 0.4235
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.4169
# True Positives: 350/350
# False Positives: 11
# False Negatives: 0
# F1 Score: 0.9845
# RMSE: 0.3705
# U-Net method
# ----------------
# TP:          350.00 ± 0.00
# FP:          6.26 ± 3.04
# FN:          0.00 ± 0.00
# F1:          0.9912 ± 0.0043
# RMSE:        0.4056 ± 0.0209

# %% [markdown]
# LodeSTAR detection

# %%
def run_lodestar_detection(sim_image, sim_locs_gt):

    # Convert the image to analyze into a PyTorch tensor.
    formatted_sim_image = utils.format_image(sim_image).to(device)

    # Parameters for inference.
    alpha = 0.9
    beta = 1 - alpha
    cutoff = 0.8

    # Extract predictions.
    with torch.inference_mode():
        sim_image_pred_lodestar = \
            lodestar(formatted_sim_image.to(device)).squeeze().detach()

    # Extract the mass feature from the prediction.
    sim_image_mass_feature = sim_image_pred_lodestar[2].cpu()

    # Infer on the pytorch image.
    with torch.inference_mode():
        sim_locs_pred_method4 = lodestar.detect(
            formatted_sim_image,
            alpha=alpha,
            beta=beta,
            mode="quantile",
            cutoff=cutoff,
        )[0]

    # Convert predicted locations to NumPy.
    sim_locs_pred_method4 = (
        sim_locs_pred_method4
    )

    # Evaluate the performance.
    TP, FP, FN, F1, RMSE = utils.evaluate_locs(
        sim_locs_pred_method4,
        sim_locs_gt,
        distance_th=major_axis_length, 
        pixel_size_nm=pixel_size_nm
    )

    return TP, FP, FN, F1, RMSE

# %%
results = []

lodestar.eval()

for i in range(len(sim_image_array)):
    results.append(
        run_lodestar_detection(
            sim_image_array[i],
            sim_locs_gt_array[i],
        )
    )

results = np.asarray(results)

TP_array_LodeSTAR   = results[:, 0]
FP_array_LodeSTAR   = results[:, 1]
FN_array_LodeSTAR   = results[:, 2]
F1_array_LodeSTAR   = results[:, 3]
RMSE_array_LodeSTAR = results[:, 4]


print("LodeSTAR method")
print("----------------")

print(f"TP:          {TP_array_LodeSTAR.mean():.2f} ± {TP_array_LodeSTAR.std():.2f}")
print(f"FP:          {FP_array_LodeSTAR.mean():.2f} ± {FP_array_LodeSTAR.std():.2f}")
print(f"FN:          {FN_array_LodeSTAR.mean():.2f} ± {FN_array_LodeSTAR.std():.2f}")
print(f"F1:          {F1_array_LodeSTAR.mean():.4f} ± {F1_array_LodeSTAR.std():.4f}")
print(f"RMSE:        {RMSE_array_LodeSTAR.mean():.4f} ± {RMSE_array_LodeSTAR.std():.4f}")
# Out:
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2921
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2770
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3192
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3088
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3359
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3568
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3477
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3206
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3099
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3341
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3211
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3181
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3306
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3738
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3192
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3886
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3184
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3949
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2838
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3233
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3167
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2741
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3164
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2981
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2890
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3516
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3475
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2952
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3808
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3174
# True Positives: 350/350
# False Positives: 69
# False Negatives: 0
# F1 Score: 0.9103
# RMSE: 0.4977
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2988
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3115
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3221
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3461
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3270
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3570
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3203
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3245
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3295
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3357
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2985
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3874
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3096
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2526
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3547
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3115
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3217
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3518
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3250
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3639
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3064
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2868
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3322
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3248
# True Positives: 350/350
# False Positives: 6
# False Negatives: 0
# F1 Score: 0.9915
# RMSE: 0.4569
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3418
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3987
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3112
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3530
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3045
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3320
# True Positives: 350/350
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9986
# RMSE: 0.4200
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3500
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3248
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3397
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3628
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3579
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3359
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3425
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3211
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3433
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3584
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3248
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3534
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3229
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3151
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3621
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3657
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3278
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3373
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3204
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3053
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2983
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2718
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3316
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3444
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3067
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3324
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3261
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3105
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3420
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2713
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3314
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3714
# True Positives: 350/350
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9957
# RMSE: 0.4918
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2982
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3171
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.2985
# True Positives: 350/350
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.3229
# LodeSTAR method
# ----------------
# TP:          350.00 ± 0.00
# FP:          0.79 ± 6.89
# FN:          0.00 ± 0.00
# F1:          0.9990 ± 0.0090
# RMSE:        0.3331 ± 0.0390

# %%
import matplotlib.pyplot as plt
import numpy as np

# Method names.
method_names = [
    "Threshold",
    "Crocker-Grier",
    "U-Net",
    "LodeSTAR",
]

# F1 arrays for each method.
F1_arrays = [
    F1_array_threshold,
    F1_array_CG,
    F1_subpx_array_UNet,
    F1_array_LodeSTAR,
]

# RMSE arrays for each method.
RMSE_arrays = [
    RMSE_array_threshold,
    RMSE_array_CG,
    RMSE_subpx_array_UNet,
    RMSE_array_LodeSTAR,
]

# Calculate means.
F1_means = np.array([np.mean(x) for x in F1_arrays])
RMSE_means = np.array([np.mean(x) for x in RMSE_arrays])

# Calculate standard deviations.
F1_stds = np.array([np.std(x) for x in F1_arrays])
RMSE_stds = np.array([np.std(x) for x in RMSE_arrays])

# Plot.
fig, ax = plt.subplots(figsize=(5, 4))

for i, method in enumerate(method_names):
    ax.errorbar(
        F1_means[i],
        RMSE_means[i],
        xerr=F1_stds[i],
        yerr=RMSE_stds[i],
        fmt="o",
        capsize=4,
        label=method,
    )

ax.set_xlabel("F1 score (higher is better)")
ax.set_ylabel("RMSE [px] (Lower is better)")
ax.set_xlim(0.9, 1.01)
ax.set_ylim(0.0, 1.01)
ax.legend(loc='upper left')
plt.savefig("ellipses_detection_statistics.svg")
# ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

print("Statistics")
print(f"Threshold")
# Out:
# Statistics
# Threshold

# %%
print("Threshold method")
print("----------------")

print(f"TP:          {TP_array_threshold.mean():.2f} ± {TP_array_threshold.std():.2f}")
print(f"FP:          {FP_array_threshold.mean():.2f} ± {FP_array_threshold.std():.2f}")
print(f"FN:          {FN_array_threshold.mean():.2f} ± {FN_array_threshold.std():.2f}")
print(f"F1:          {F1_array_threshold.mean():.4f} ± {F1_array_threshold.std():.4f}")
print(f"RMSE:        {RMSE_array_threshold.mean():.4f} ± {RMSE_array_threshold.std():.4f}")

print("\nSub-pixel refined")
print("-----------------")

print(f"TP:          {TP_subpx_array_threshold.mean():.2f} ± {TP_subpx_array_threshold.std():.2f}")
print(f"FP:          {FP_subpx_array_threshold.mean():.2f} ± {FP_subpx_array_threshold.std():.2f}")
print(f"FN:          {FN_subpx_array_threshold.mean():.2f} ± {FN_subpx_array_threshold.std():.2f}")
print(f"F1:          {F1_subpx_array_threshold.mean():.4f} ± {F1_subpx_array_threshold.std():.4f}")
print(f"RMSE:        {RMSE_subpx_array_threshold.mean():.4f} ± {RMSE_subpx_array_threshold.std():.4f}")
print()

print("Crocker-Grier method")
print("----------------")

print(f"TP:          {TP_array_CG.mean():.2f} ± {TP_array_CG.std():.2f}")
print(f"FP:          {FP_array_CG.mean():.2f} ± {FP_array_CG.std():.2f}")
print(f"FN:          {FN_array_CG.mean():.2f} ± {FN_array_CG.std():.2f}")
print(f"F1:          {F1_array_CG.mean():.4f} ± {F1_array_CG.std():.4f}")
print(f"RMSE:        {RMSE_array_CG.mean():.4f} ± {RMSE_array_CG.std():.4f}")
print()

print("U-Net method")
print("----------------")

print(f"TP:          {TP_array_UNet.mean():.2f} ± {TP_array_UNet.std():.2f}")
print(f"FP:          {FP_array_UNet.mean():.2f} ± {FP_array_UNet.std():.2f}")
print(f"FN:          {FN_array_UNet.mean():.2f} ± {FN_array_UNet.std():.2f}")
print(f"F1:          {F1_array_UNet.mean():.4f} ± {F1_array_UNet.std():.4f}")
print(f"RMSE:        {RMSE_array_UNet.mean():.4f} ± {RMSE_array_UNet.std():.4f}")
print()

print("LodeSTAR method")
print("----------------")

print(f"TP:          {TP_array_LodeSTAR.mean():.2f} ± {TP_array_LodeSTAR.std():.2f}")
print(f"FP:          {FP_array_LodeSTAR.mean():.2f} ± {FP_array_LodeSTAR.std():.2f}")
print(f"FN:          {FN_array_LodeSTAR.mean():.2f} ± {FN_array_LodeSTAR.std():.2f}")
print(f"F1:          {F1_array_LodeSTAR.mean():.4f} ± {F1_array_LodeSTAR.std():.4f}")
print(f"RMSE:        {RMSE_array_LodeSTAR.mean():.4f} ± {RMSE_array_LodeSTAR.std():.4f}")
# Out:
# Threshold method
# ----------------
# TP:          344.33 ± 2.75
# FP:          1.79 ± 1.19
# FN:          5.67 ± 2.75
# F1:          0.9893 ± 0.0055
# RMSE:        0.6758 ± 0.2716
#
# Sub-pixel refined
# -----------------
# TP:          344.35 ± 2.73
# FP:          1.77 ± 1.17
# FN:          5.65 ± 2.73
# F1:          0.9893 ± 0.0055
# RMSE:        0.6816 ± 0.2684
#
# Crocker-Grier method
# ----------------
# TP:          319.48 ± 4.54
# FP:          9.13 ± 2.76
# FN:          30.52 ± 4.54
# F1:          0.9415 ± 0.0088
# RMSE:        0.5671 ± 0.0856
#
# U-Net method
# ----------------
# TP:          350.00 ± 0.00
# FP:          6.26 ± 3.04
# FN:          0.00 ± 0.00
# F1:          0.9912 ± 0.0043
# RMSE:        0.4056 ± 0.0209
#
# LodeSTAR method
# ----------------
# TP:          350.00 ± 0.00
# FP:          0.79 ± 6.89
# FN:          0.00 ± 0.00
# F1:          0.9990 ± 0.0090
# RMSE:        0.3331 ± 0.0390

# %%
fig = plt.figure(figsize=(4, 8))

# ------------------------------------------------------------------
# Define common width for both axes.
# ------------------------------------------------------------------

left = 0.15
width = 0.80

# Since the figure is 6 x 10 inches, make the top axes physically square.
# Physical width = 0.80 * 6 = 4.8 inches
# Therefore physical height must also be 4.8 inches:
# 4.8 / 10 = 0.48 of the figure height.

ax_img = fig.add_axes([
    left,    # left
    0.50,    # bottom
    width,   # width
    0.48,    # height
])

ax_stats = fig.add_axes([
    left,    # left
    0.08,    # bottom
    width,   # SAME width
    0.32,    # height
])

# ------------------------------------------------------------------
# Top panel: simulated image.
# ------------------------------------------------------------------

ax_img.imshow(
    sim_image_array[-1],
    cmap="gray",
    origin="upper",
)

ax_img.set_xlabel("x [px]")
ax_img.set_ylabel("y [px]")

# ------------------------------------------------------------------
# Bottom panel: detection statistics.
# ------------------------------------------------------------------

for i, method in enumerate(method_names):
    ax_stats.errorbar(
        F1_means[i],
        RMSE_means[i],
        xerr=F1_stds[i],
        yerr=RMSE_stds[i],
        fmt="o",
        capsize=4,
        label=method,
    )
    
# ax_img.set_title("Simulated ellipses")
ax_stats.set_title("Ellipses")

ax_stats.set_xlabel("F1 score (higher is better)")
ax_stats.set_ylabel("RMSE [px] (lower is better)")
ax_stats.set_xlim(0.9, 1.01)
ax_stats.set_ylim(0.0, 1.01)
ax_stats.legend(loc="lower left")

# ------------------------------------------------------------------
# Save.
# ------------------------------------------------------------------

plt.savefig(
    "ellipses_detection_statistics.svg",
    bbox_inches="tight",
)

plt.show()
