# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aarondomenzain/tracking-softmatter-aarond/blob/tracking-softmatter-aarond-dev/tutorial/detection/detection_spheres.ipynb)

# %% [markdown]
# # Particle Tracking Tutorial: Particle Detection and Localization
#
# In this tutorial, you’ll explore different methods to detect and localize particles in microscopy images using both simulated data and real experimental images.
#
# You’ll start by generating a simulated image of microscopic particles, mimicking what you might see in a soft matter or biophysics experiment. Since you know the true particle positions in the simulation (i.e., the 'ground truth'), you can directly evaluate how well each detection method performs.
#
# These are the detection and localization methods that you’ll test and compare:
#
# - Thresholding and Connected Components
#
# - Crocker and Grier (using TrackPy — a classic in particle tracking)
#
# - U-Net (a neural network for image segmentation)
#
# - LodeSTAR (a self-supervised deep learning method)
#
# You’ll be using Python libraries like NumPy, SciPy, Matplotlib, scikit-image, PyTorch, DeepTrack, and Deeplay.

# %% [markdown]
# ## Table of Contents
#
# 0. [Import the Required Libraries and Load Utility Functions](#import-the-required-libraries-and-load-utility-functions)
# 1. [Load and Visualize Experimental Images](#load-and-visualize-experimental-images)
# 2. [Simulate Realistic Images with DeepTrack](#simulate-realistic-images-with-deeptrack)
#     - [Simulate a Single Particle](#simulate-a-single-particle)
#     - [Simulate a Test Image to Benchmark Detection Methods](#simulate-a-test-image-to-benchmark-detection-methods)
# 3. [Method 1: Thresholding and Connected Components](#3-method-1-thresholding-and-connected-components)
#     - [Apply Intensity Thresholding](#apply-intensity-thresholding)
#     - [Determine Centroids with Connected Components Analysis](#determine-centroids-with-connected-components-analysis)
#     - [Evaluate the Performance of the Method](#evaluate-the-performance-of-the-method)
#       - [Refine Localization](#refine-localization)
#     - [Apply the Method to Experiments](#apply-the-method-to-experiments)
#
# 4. [Method 2: Crocker and Grier](#method-2-crocker-and-grier)
#     - [Estimate Particle Size from Simulations](#estimate-particle-size-from-simulations)
#     - [Apply the Crocker and Grier Method to Simulations](#apply-the-crocker-and-grier-method-to-simulations)
#     - [Apply the Crocker and Grier Method to Experiments](#apply-the-crocker-and-grier-method-to-experiments)
#
# 5. [Method 3: U-Net](#method-3-u-net)
#     - [Create a Training Dataset](#create-a-training-dataset)
#     - [Define a U-Net Model with Deeplay](#define-a-u-net-model-with-deeplay)
#     - [Train the U-Net model](#train-the-u-net-model)
#     - [Apply the Trained U-Net to the Simulations](#apply-the-trained-u-net-to-simulations)
#     - [Apply the Trained U-Net to the Experiments](#apply-the-trained-u-net-to-experiments)
#
# 6. [Method 4: LodeSTAR](#method-4-lodestar)
#     - [Simulate Training Data for LodeSTAR](#simulate-training-data-for-lodestar)
#     - [Train LodeSTAR and Apply it to Simulations](#train-lodestar-and-apply-it-to-simulations)
#     - [Apply the Trained LodeSTAR to Experiments](#apply-the-trained-lodestar-to-experiments)
#     - [Train LodeSTAR with Experiments](#train-lodestar-with-experimentas)

# %% [markdown]
# ## Import the Required Libraries and Load Utility Functions

# %% [markdown]
# Uncomment the next cell if running on Google Colab/Kaggle.

# %%
#!pip install deeptrack deeplay trackpy -q

# %% [markdown]
# Import required libraries.

# %%
# Standard libraries
import os
import random
import sys

# Core Scientific Stack
import numpy as np
import scipy

# Plotting and Display
import matplotlib.pyplot as plt

# Machine Learning
import deeplay as dl
import torch

# Particle Tracking and Simulation
import deeptrack as dt
import trackpy as tp

# Image Analysis
import skimage  # Image analysis (scikit)

# %% [markdown]
# Load a set of custom functions defined specifically for this notebook from the `utils` directory. For detailed documentation of each function, refer to the comments and docstrings within the files.

# %%
# Load functions and utilities for dataset generation and visualization.
# Sys appends a folder to the path.
sys.path.append(os.path.abspath(os.path.join("..", "..")))

# Import all the functions contained in the folder utils.
import utils

# %% [markdown]
# Set random seeds to make results reproducible across runs, especially during training and data simulation.

# %%
# Set a fixed seed value.
seed = 89

# Python, NumPy, and PyTorch (CPU).
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# Only set CUDA seeds if a GPU is available.
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

print(f"Seeds set to {seed} (with CUDA: {torch.cuda.is_available()})")

# Get the best available device for Torch computation.
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using CUDA GPU: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple GPU (MPS)")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Seeds set to 89 (with CUDA: False)
# Using Apple GPU (MPS)

# %% [markdown]
# ## Load and Visualize Experimental Images

# %% [markdown]
# Load a `.tif` image from the `images/` folder and display it using scikit-image.

# %%
# Define the folder and image file name.
image_folder = "images"
image_file_name = "JT008_AFM_15.tif"

# Construct the full path.
image_path = os.path.join(image_folder, image_file_name)

# Create an instance of the loaded file using SciKit.
exp_image = skimage.io.imread(image_path)

# Get the shape of the image.
assert exp_image.shape[0] == exp_image.shape[1], "Warning: Image not square!"
exp_image_size = exp_image.shape[0]

# Print the name of the selected file.
print("Selected file:", image_path)

# Open a figure instance.
plt.figure()

# Plot the image in grayscale.
plt.imshow(exp_image, cmap="gray")
plt.axis("off")
plt.title("Experimental Image")
plt.tight_layout()
plt.show()

# Print the image size in pixels.
print(f"Size of imported image in pixels: {exp_image_size}")
# Out:
# Selected file: images/JT008_AFM_15.tif
# Size of imported image in pixels: 512

# %% [markdown]
# Manually select and display a single particle by specifying its centroid coordinates (x,y) and a box width.
#
# **Note:** Images in NumPy are indexed as `(column, row)`, which corresponds to (y, x) in Cartesian coordinates.

# %%
from matplotlib.patches import Rectangle

# Window size to zoom in an individual particle.
exp_crop_size = 28  

# Particle center coordinates
x_center, y_center = 212, 329  # (column, row)

# Compute crop bounds.
x_min = x_center - exp_crop_size // 2
x_max = x_center + exp_crop_size // 2
y_min = y_center - exp_crop_size // 2
y_max = y_center + exp_crop_size // 2

# Extract crop (note: rows = y, cols = x)
exp_crop = exp_image[y_min:y_max, x_min:x_max]

# Create a single figure with two panels
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

# Left panel: full image with square window.
axes[0].imshow(exp_image, cmap="gray")
axes[0].set_title("Experimental Image", fontsize=13)
axes[0].add_patch(
    Rectangle(
        (x_min, y_min), exp_crop_size, exp_crop_size,
        edgecolor="red", facecolor="none", linewidth=2,
    )
)
axes[0].axis("off")

# Right panel: zoomed-in crop
axes[1].imshow(exp_crop, cmap="gray")
axes[1].set_title("Zoomed Crop", fontsize=13)
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Simulate Realistic Images with DeepTrack

# %% [markdown]
# DeepTrack allows you to simulate physically realistic microscopy images, enabling precise control over imaging parameters and particle properties. These simulations provide ground-truth data, making them ideal for benchmarking classical and AI-based tracking methods, as well as for training neural networks.

# %% [markdown]
# ### Simulate a Single Particle

# %% [markdown]
# Adjust the simulation parameters to accurately replicate the features observed in the cropped region of the experimental image.

# %% [markdown]
# **Note:** While the experimental image was acquired using a non-optical technique (Atomic Force Microscopy), DeepTrack is versatile enough to simulate such images as well. However, in this case, imaging parameters have not physical meaning and can have unrealistic values.

# %%
# Same as the box width.
sim_crop_size = exp_crop_size  

# Size of a pixel in nanometers in the output image.
pixel_size_nm = 200  # In nm

# Radius of the particle.
particle_radius = 1000  # In nm

# Define central spherical scatterer.
sphere = dt.Sphere(
    position=0.5 * np.array([sim_crop_size, sim_crop_size]),
    z=-900 * dt.units.nm,  # Particle in focus
    radius=particle_radius * dt.units.nm,  # Radius in nm
    intensity=7.5E4,  # Field magnitude squared
)

# Simulate the properties of the fluorescence microscope.
optics = dt.Fluorescence(
    NA=0.7,  # Numerical aperture.
    wavelength=590 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, sim_crop_size, sim_crop_size],
    magnification=1.9,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
)

# Apply transformations.
sim_crop = (
    optics(sphere) 
    >> dt.Background(2500)
)
# Turn the crop into a NumPy array.
sim_crop = np.squeeze(sim_crop())

# Plot the simulated and experimental crops.
fig, axes = plt.subplots(1, 2)

from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.font_manager as fm

pixel_size_scalebar = 10
scalebar_length = pixel_size_scalebar * pixel_size_nm 

scalebar = AnchoredSizeBar(
    axes[0].transData,
    pixel_size_scalebar,   # Length in pixels
    f"{scalebar_length} nm",
    "lower left",
    pad=0.3,
    color="white",
    frameon=False,
    size_vertical=1,
    fontproperties=fm.FontProperties(size=16),
)

axes[0].add_artist(scalebar)

# Simulated crop.
axes[0].imshow(sim_crop, cmap="gray")
axes[0].axis("off")
axes[0].scatter([sim_crop_size / 2], [sim_crop_size / 2], color="red", s=50, marker="x")
#axes[0].set_title("Simulated Crop")

# Experimental crop.
axes[1].imshow(exp_crop, cmap="gray")
axes[1].axis("off")
#axes[1].set_title("Experimental Crop")

# Adjust layout and show plot.
plt.tight_layout()
plt.show()

# %% [markdown]
# Extract and visualize the raw intensity profiles along the central horizontal and vertical lines of both the simulated and experimental crops. This comparison helps evaluate how well the simulation reproduces the intensity distribution observed in real microscopy images.

# %%
# Compute the center index.
center = sim_crop_size // 2

# Extract horizontal (row) profiles.
sim_horiz = sim_crop[center, :]
exp_horiz = exp_crop[center, :]

# Extract vertical (column) profiles.
sim_vert = sim_crop[:, center]
exp_vert = exp_crop[:, center]

# Create a 1×2 subplot.
fig, axes = plt.subplots(1, 2, figsize=(12, 4), tight_layout=True)

# --- Horizontal profile ---
axes[0].plot(sim_horiz, label="Simulated Crop", color="orange")
axes[0].plot(exp_horiz, label="Experimental Crop", color="blue")
axes[0].set_xlabel("Pixel (x)")
axes[0].set_ylabel("Intensity")
axes[0].set_title("Horizontal Intensity Profile (Center Row)")
axes[0].legend()
axes[0].grid(True, linestyle="--", alpha=0.5)

# --- Vertical profile ---
axes[1].plot(sim_vert, label="Simulated Crop", color="orange")
axes[1].plot(exp_vert, label="Experimental Crop", color="blue")
axes[1].set_xlabel("Pixel (y)")
axes[1].set_ylabel("Intensity")
axes[1].set_title("Vertical Intensity Profile (Center Column)")
axes[1].legend()
axes[1].grid(True, linestyle="--", alpha=0.5)

# %% [markdown]
# A radial intensity profile can also offer valuable information in the case of spherical particles, by integrating the intensity along the angular coordinate.

# %%
# Compute radial intensity profiles.
def radial_profile(image):
    image = np.asarray(image)

    y, x = np.indices(image.shape)
    center = np.array(image.shape) // 2

    r = np.sqrt((x - center[1])**2 + (y - center[0])**2)
    r = r.astype(int)

    radial_sum = np.bincount(r.ravel(), image.ravel())
    radial_count = np.bincount(r.ravel())

    return radial_sum / radial_count

# Compute profiles.
sim_radial = radial_profile(sim_crop)
exp_radial = radial_profile(exp_crop)

# Radial coordinate.
radius = np.arange(len(sim_radial))

# Plot.
plt.figure(figsize=(6, 4))

plt.plot(radius, sim_radial, label="Simulated Crop", color="orange")
plt.plot(radius, exp_radial, label="Experimental Crop", color="blue")

plt.xlabel("Radius (pixels)")
plt.ylabel("Mean intensity")
#plt.title("Radial Intensity Profile")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Simulate a Test Image to Benchmark Detection Methods

# %% [markdown]
# Create a simulated image containing non-overlapping spherical particles. Begin by generating their coordinates to serve as the ground-truth positions. Then, use DeepTrack to render optically realistic particles at these coordinates, rendering in a physically plausible microscopy image.

# %%
# Parameters of the simulation.
sim_image_size = exp_image_size
N_particles = 450
particle_radius = 900 # In nm.

# Dictionary for particle properties.
# Dimensions are set with lambda functions to introduce variety to the dataset.
sphere_properties = {
    "radius": lambda: (np.random.uniform(0.9, 1.1) * particle_radius
                       * dt.units.nm),
    "intensity": lambda: np.random.normal(1.0, 0.1) * 7.5E4,
    "z": lambda: np.random.uniform(-1000, 1000) * dt.units.nm,
}

# Set the optical properties of the microscope.  
optics_properties = dt.Fluorescence(
    NA=0.7,  # Numerical aperture
    wavelength=590 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, exp_image_size, exp_image_size],
    magnification=2,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
)

# Generate ground truth positions.
sim_locs_gt = utils.generate_centroids(
    num_particles=N_particles,
    fov_size=sim_image_size,
    particle_radius=particle_radius, 
)

# Simulate image.
sim_image = utils.transform_to_video(
    sim_locs_gt,
    fov_size=sim_image_size,
    core_particle_props=sphere_properties,
    optics_props=optics_properties,
    background_props={"peak_snr": 5.5e5, "background_mean": 0, "background_std": 100},
)

# Generate the ground truth as Gaussian clouds centered at the position of the
# spheres. The standard deviation of the Gaussians are set to be proportional 
# to the radii of the corresponding spherical particles.
gt_cloud_size = particle_radius / 2

# Generate ground truth map using the positions, radii and intensities of the 
# particles.
sim_map = utils.create_ground_truth_map(
    sim_locs_gt, 
    fov_size=sim_image_size, 
    sigma=gt_cloud_size, 
)

# %% [markdown]
# Visualize the simulated image and compare it with the experimental one.

# %%
# Plot the simulated and experimental images.
fig, axes = plt.subplots(1, 2)

# Simulated image.
plot = axes[0].imshow(sim_image, cmap="gray")
axes[0].axis("off")
axes[0].set_title("Simulated Image")

# Experimental image.
axes[1].imshow(exp_image, cmap="gray")  
axes[1].axis("off")
axes[1].set_title("Experimental Image")

# Adjust layout and show plot.
plt.tight_layout()
plt.show()

# %% [markdown]
# Perform a more quantitative comparison by plotting the intensity histograms.

# %%
# Flatten the arrays to 1D.
sim_vals = sim_image.ravel()
exp_vals = exp_image.ravel()

# Create figure with two subplots sharing the y-axis.
fig, axes = plt.subplots(
    1, 2, figsize=(10, 4), sharey=True, sharex=True, tight_layout=True,
)

# Histogram for simulated image.
axes[0].hist(sim_vals, bins=80, alpha=0.7, edgecolor="black", density=True)
axes[0].set_title("Simulated Image Histogram")
axes[0].set_xlabel("Normalized Intensity")
axes[0].set_ylabel("Probability Density")

# Histogram for experimental image.
axes[1].hist(exp_vals, bins=80,  alpha=0.7, edgecolor="black", density=True)
axes[1].set_title("Experimental Image Histogram")
axes[1].set_xlabel("Normalized Intensity")
# No need to set ylabel on the second axes when sharing.

plt.show()

# %% [markdown]
# **Note:** The simulated image has less particles compared to the experimental one. These differences are visible in the histogram but the dynamic range and the overall shape of the distribution of intensity are rather similar.

# %% [markdown]
# Visualize the simulated image and the corresponding ground-truth map. Each particle has an associated ground-truth cloud with a Gaussian profile, whose standard deviation is proportional to the radius of the particle.

# %%
# Create a subfigure instance to plot the image and the probability map.
fig, ax = plt.subplots(1, 2)

# Instance for the simulated experimental image. 
img1 = ax[0].imshow(sim_image, cmap="gray")
ax[0].axis("off")
ax[0].set_title("Simulated Image")  

# Instance for the probability map.
img2 = ax[1].imshow(sim_map, cmap="gray")
ax[1].axis("off")
ax[1].set_title("Simulated Probability Map (Gaussian)") 

# Adjust layout to avoid overlap.
plt.tight_layout()

# Show the plot.
plt.show()

# %% [markdown]
# From now on, you'll use normalized images.

# %%
# Normalize the images to the range [0, 1].
exp_image = utils.normalize_min_max(
    exp_image, minimum_value=0.0, maximum_value=1.0,
)
sim_image = utils.normalize_min_max(
    sim_image, minimum_value=0.0, maximum_value=1.0,
)

# %% [markdown]
# ## Method 1: Thresholding and Connected Components

# %% [markdown]
# In a grayscale image, each pixel has an intensity value, where higher values typically indicate the presence of particles while lower values represent the background (but it can also be the other way around).
#
# A simple and effective method for particle detection is **intensity thresholding**, which converts the grayscale image into a binary mask. Pixels with intensities above a chosen threshold are marked as foreground (set to 1, corresponding to white), and the rest as background (set to 0, corresponding to black).
#
# If particles appear darker than the background—as in absorption-based or negative stain imaging—the threshold should instead be applied to the lower end of the intensity distribution.
#
# After thresholding, **connected component analysis** can be used to label and isolate individual foreground regions. Each connected component represents a candidate particle, enabling basic localization by computing properties such as the centroid (position), area (size), or bounding box (extent) of each region.

# %% [markdown]
# ### Apply Intensity Thresholding

# %% [markdown]
# A robust way to choose the threshold is to use the **intensity quantile**. For example, setting the threshold at the 90th percentile selects the brightest 10% of pixels, which often correspond to particles. This method is more reliable than using the image mean and standard deviation, which can be biased by background-dominated images.
#
# Before thresholding, it’s a good idea to smooth the image with a Gaussian filter. This helps suppress noise and small fluctuations that aren’t real particles.

# %%
# Apply a Gaussian filter to the image to smooth out noise.
filtered_sim_image = scipy.ndimage.gaussian_filter(sim_image, sigma=1.0)

# %% [markdown]
# Plot the intensity histogram of the simulated image before and after Gaussian filtering.

# %%
# Define the quantile level (e.g., 85% selects the top 15% brightest pixels).
quantile_level = 0.85

# Compute statistics
median_intensity_sim = np.median(sim_image)
quantile_threshold_sim = np.quantile(sim_image, quantile_level)

median_intensity_filtered_sim = np.median(filtered_sim_image)
quantile_threshold_filtered_sim = np.quantile(filtered_sim_image,
                                              quantile_level)

print(f"Intensity threshold (quantile={quantile_level*100:.0f}%): "
      f"{quantile_threshold_filtered_sim}")

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 3))

# Histogram for simulated image
axes[0].hist(sim_image.flatten(), bins=128, range=(0, 1), color="gray",
             alpha=0.75, density=True)
axes[0].axvline(median_intensity_sim, color="red", linestyle="dashed",
                linewidth=1.5, label="Median")
axes[0].axvline(quantile_threshold_sim, color="green", linestyle="dashed",
                linewidth=1.5, label=f"{int(quantile_level*100)}th Percentile")
axes[0].set_title("Simulated Image", fontsize=14)
axes[0].set_yticklabels([])  # Remove y labels
axes[0].legend()
axes[0].grid(True)

# Histogram for filtered image
axes[1].hist(filtered_sim_image.flatten(), bins=128, range=(0, 1),
             color="gray", alpha=0.75)
axes[1].axvline(median_intensity_filtered_sim, color="red", linestyle="dashed",
                linewidth=1.5, label="Median")
axes[1].axvline(quantile_threshold_filtered_sim, color="green",
                linestyle="dashed", linewidth=1.5,
                label=f"{int(quantile_level*100)}th Percentile")
axes[1].set_title("Simulated Image + Gaussian Filter", fontsize=14)
axes[1].set_yticklabels([])
axes[1].legend()
axes[1].grid(True)

# Set common x and y labels
fig.supxlabel("Normalized Intensity", fontsize=12)
fig.supylabel("Normalized Frequency [counts]", fontsize=12)

# Adjust layout and display
plt.tight_layout()
plt.show()
# Out:
# Intensity threshold (quantile=85%): 0.46342375135922026

# %% [markdown]
# Apply the threshold to generate a binary mask, then display it together with the original image for visual validation.

# %%
# Create the binary mask by applying the threshold.
sim_mask = filtered_sim_image > quantile_threshold_filtered_sim

# Ensure the mask is a 2D array.
sim_mask = np.squeeze(sim_mask)

# Plot the image with the calculated mask.
utils.plot_image_mask_ground_truth_map(
    image=sim_image, 
    mask=sim_mask, 
    title="Mask with Intensity Thresholding",
)

# %% [markdown]
# ### Determine Centroids with Connected Components Analysis

# %% [markdown]
# Detect objects from the binary mask and extract their centroids using the scikit-image library. This is typically done by identifying connected components and computing their center of mass, which provides an estimate of each particle’s position.

# %%
# Use the function to extract positions from mask.
sim_locs_pred_method1 = utils.mask_to_positions(sim_mask)
print(f"Found {len(sim_locs_pred_method1[:,1])} detections.")
# Out:
# Found 307 detections.

# %% [markdown]
# Plot the extracted centroids on top of the image.

# %%
# Use the plotting function to compare the detection with the ground truth.
utils.plot_predicted_positions(
    image=sim_image, 
    pred_positions=sim_locs_pred_method1, 
    gt_positions=sim_locs_gt, 
    title="Method 1 - Simulated Image",
)

# %% [markdown]
# ### Evaluate the Performance of the Method

# %% [markdown]
# Apply the `evaluate_locs` function that calculates evaluation metrics and print them. It calculates True Positives (TP), False Positives (FP), False Negatives (FN), F1 score (F1), and Root Mean Square Error (RMSE).

# %%
TP, FP, FN, F1, RMSE = utils.evaluate_locs(
    sim_locs_pred_method1, sim_locs_gt, distance_th=particle_radius,
)
# Out:
# True Positives: 306/312
# False Positives: 1
# False Negatives: 6
# F1 Score: 0.9887
# RMSE: 0.9592

# %% [markdown]
# #### Refine Localization

# %% [markdown]
# You can improve localization precision by passing the raw image to `mask_to_positions()`. This function uses the actual gray‐level intensities within each connected component to compute a weighted centroid, giving you subpixel‐refined coordinates.

# %% [markdown]
# Use weighted centroid refinement to achieve more accurate centroid positions.

# %%
# Estimate the location of the centroid of a masked particle image.
sim_locs_pred_method1_ref = \
    utils.mask_to_positions(sim_mask, sim_image.squeeze())

# Evaluate the performance.
TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx = utils.evaluate_locs(
    sim_locs_pred_method1_ref, sim_locs_gt, distance_th=particle_radius,
)
# Out:
# True Positives: 307/312
# False Positives: 0
# False Negatives: 5
# F1 Score: 0.9919
# RMSE: 1.0495

# %% [markdown]
# ### Apply the Method to Experiments

# %% [markdown]
# Apply the same method to the experimental image:
#
# - Smooth the image using a Gaussian filter.
# - Choose a threshold.
# - Create a binary mask where pixels above the threshold are marked as potential particles.
# - Extract positions from the mask.
# - Plot both the predicted positions and the mask for visual inspection.
# - Print the number of detections found.
#
# This gives you a first estimate of particle positions using just thresholding—no machine learning needed!

# %%
# Apply a Gaussian filter to the image to smooth out noise.
filtered_exp_image = scipy.ndimage.gaussian_filter(exp_image, sigma=1.0)

# quantile level for thresholding.
quantile_level = 0.85

# Intensity threshold for the experimental image.
quantile_threshold_filtered_exp = \
    np.quantile(filtered_exp_image, quantile_level)

# Create the binary mask by applying the threshold.
exp_mask = filtered_exp_image > quantile_threshold_filtered_exp

# Get predicted positions from the mask.
exp_locs_pred_method1 = utils.mask_to_positions(exp_mask, exp_image)

# Plot the experimental image with the predicted positions.
utils.plot_predicted_positions(
    image=exp_image,
    pred_positions=exp_locs_pred_method1,
    title="Method 1 - Experimental Image",
)

# Plot the experimental image and the mask.
utils.plot_image_mask_ground_truth_map(
    image=exp_image, 
    mask=exp_mask, 
    title="Method 1 - Experimental Image",
)

# Print the number of detections.
print(f"Found {len(exp_locs_pred_method1[:,1])} detections.")
# Out:
# No ground truth positions were passed
# Found 455 detections.

# %% [markdown]
# ## Method 2: Crocker and Grier (TrackPy)

# %% [markdown]
# A refined approach for particle detection and localization is the Crocker and Grier method. This method identifies local intensity maxima and refines their positions by fitting the surrounding region to a Gaussian-like profile. It offers subpixel accuracy and performs well even in moderately noisy conditions or crowded images.
#
# TrackPy provides a built-in implementation of the Crocker and Grier particle detection method.

# %% [markdown]
# ### Estimate Particle Size from Simulations

# %% [markdown]
# In the TrackPy implementation of the Crocker and Grier method, the primary parameter you need to set is the estimated particle size, which must be an odd number.
#
# To estimate this value, inspect the simulated image interactively: click on both edges of a representative particle to measure its approximate width. Keep in mind that particle sizes may vary across the image, so this should be treated as an initial guess. You can refine the diameter later by evaluating the quality of the detections.

# %% [markdown]
# **Note:** For the interactive widget to work correctly, you might need to install `ipykernel` manually, for example using:
# ```bash
# pip install ipykernel
# ```

# %%
# Set the matplotlib interactive backend.
# %matplotlib widget
utils.interactive_ruler(sim_image[200:300,200:300])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Switch the backend back to the default, where plots are rendered as static images in the notebook cells.

# %%
# Close the figure so it doesn't re-render.
plt.close("all")

# Switch back to static plots.
# %matplotlib inline

# %% [markdown]
# ### Apply the Crocker and Grier Method to Simulations

# %% [markdown]
# Use `trackpy.locate()` to detect particles in the image. This function returns a DataFrame object containing the coordinates of the detected particles along with various feature properties.
#
# Extract the (x, y) positions from the DataFrame and compare them to the ground truth coordinates to assess the accuracy of the detection.

# %%
# Estimate and tune the diameter of particles in pixels, ensuring it is an
# odd number. Adjust if necessary.
estimated_size_sim = 15

# Use the locate built-in function from TrackPy.
# Output is type DataFrame([x, y, mass, size, ecc, signal, raw_mass]).
df_sim_locs_pred_method2 = tp.locate(
    sim_image, 
    diameter=estimated_size_sim,
    noise_size=3,  # Setting for denoising image
)

# Extract the predicted positions from DataFrame["x","y"] into a NumPy array.
sim_locs_pred_method2 = np.array(df_sim_locs_pred_method2)[:,:2]

# Plot the prediction and the ground truth.
utils.plot_predicted_positions(
    image=sim_image,
    pred_positions=sim_locs_pred_method2,
    gt_positions=sim_locs_gt,
    title="Method 2 - Simulated Image",
)

# Evaluate the performance of tp.locate.
utils.evaluate_locs(
    sim_locs_pred_method2,
    sim_locs_gt,
    distance_th=particle_radius,
);
# Out:
# True Positives: 311/312
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5701

# %% [markdown]
# ### Apply the Crocker and Grier Method to Experiments

# %% [markdown]
# Interactively estimate particle size.

# %%
# Set the matplotlib interactive backend.
# %matplotlib widget
# Plot a small ROI of the experimental image.
utils.interactive_ruler(exp_image[200:300,200:300])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Switch the backend back to the default, where plots are rendered as static images in the notebook cells.

# %%
# Close the figure so it doesn't re-render
plt.close("all")

# Switch back to static plots
# %matplotlib inline

# %% [markdown]
# Detect particles in the image and display the results.

# %%
# Adjust the estimated diameter if necessary. 
estimated_size_exp = 13

# Use Trackpy.locate to experimental data file 'image'.
df_exp_locs_pred_method2 = tp.locate(
    exp_image, 
    diameter=estimated_size_exp,
    noise_size=3, # Setting for denoising image.
)

# Extract the predicted positions from DataFrame["x","y"] into a NumPy array.
exp_locs_pred_method2 = np.array(df_exp_locs_pred_method2)[:,:2]

# Plot the experimental image with predicted positions overlaid.
utils.plot_predicted_positions(
    image=exp_image,
    pred_positions=exp_locs_pred_method2,
    title="Method 2 - Experimental Image",
)

print(f"Found {len(exp_locs_pred_method2[:,1])} detections.")
# Out:
# No ground truth positions were passed
# Found 444 detections.

# %% [markdown]
# ## Method 3: U-Net

# %% [markdown]
# The U-Net is a convolutional neural network (CNN) widely used for image segmentation tasks. It performs pixel-wise classification, enabling precise separation between background and objects of interest—ranging from simple particles to complex cells or anatomical structures, depending on the training data.
#
# In the context of particle detection, a U-Net can be trained to map input microscopy images directly into **probability distributions** that represent the likelihood of a particle being present at each pixel. Instead of assigning a hard classification (particle or background), the network outputs a **dense probability map**—a soft, continuous prediction indicating how likely each pixel is to belong to a particle. This approach is particularly useful in challenging scenarios, such as overlapping particles—where discrete detection may fail—or small, faint particles that traditional methods might miss.
#
# Once trained, the U-Net generalizes to new images, producing smooth probability maps that can be thresholded to create binary masks for downstream connected-component analysis. For localization, these maps enable the calculation of **intensity-weighted centroids**, allowing subpixel resolution of particle positions and improving localization accuracy. Alternatively, the maps can be analyzed using peak detection algorithms or interpreted as confidence scores to filter or rank detections.

# %% [markdown]
# ### Create a training dataset

# %% [markdown]
# U-Net is trained using pairs of input images and corresponding target maps, which represent the expected output distribution. These target maps typically consist of Gaussian blobs centered at the true particle locations, encoding both position and uncertainty.
#
# To generate training data, you can simulate particle images using DeepTrack, along with their associated probability maps to serve as ground truth.
#
# If a dataset has already been generated and saved, you can simply load it and skip the simulation step.

# %%
# Number of samples, image size, and particles.
num_samples = 128
train_image_size = 64
max_num_particles = 10
force_simulation = True  # Flag to force simulation even if data exists

# Set the optical properties of the microscope.  
optics_properties = dt.Fluorescence(
    NA=0.7,  # Numerical aperture
    wavelength=590 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, train_image_size, train_image_size],
    magnification=2,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
)

# Create path to store training dataset.
folder_name = "UNet"
training_dataset_filename = "UNet_training_dataset_spheres.npz"
training_dataset_folder = os.path.join(folder_name, "training_data")
training_dataset_filepath = os.path.join(
    training_dataset_folder, 
    training_dataset_filename,
)

# Create the enclosing directory if not existent already.
if not os.path.exists(training_dataset_folder):
    os.makedirs(training_dataset_folder, exist_ok=True)

# Try to load preexisting data, if not available or forced, raise an exception
# error to generate new data.
try:
    if force_simulation: 
        # Raise the exception error if simulation is forced.
        raise FileNotFoundError("Forced simulation by user request.")
    
    if not os.path.isfile(training_dataset_filepath):
        # If file is not found, start training.    
        raise FileNotFoundError(
            "Training dataset file not found. Starting simulation."
        )
    
    # Load existing data
    data = np.load(training_dataset_filepath)
    images = data["images"]
    print(images.shape)
    maps = data["maps"]
    Nsamples = len(images)
    print(f"Loaded file: {training_dataset_filepath}")
        
# Handle the case of either file not found or forced training.
except FileNotFoundError:
    # Generate new dataset if file not found or simulation is forced.
    images, maps = utils.generate_particle_dataset(
        num_samples = num_samples,
        fov_size = train_image_size,
        max_num_particles = max_num_particles,
        core_particle_dict=sphere_properties,
        optics_properties=optics_properties,
        background_props={"peak_snr": 5.5e5, "background_mean": 0, "background_std": 100},
    )
    
    # Save the simulated training dataset.
    np.savez(training_dataset_filepath, images=images, maps=maps)
    print(f"Training dataset saved in: {training_dataset_filepath}.")
# Out:
# Generating sample 128/128
# Dataset generation complete.
# Training dataset saved in: UNet/training_data/UNet_training_dataset_spheres.npz.

# %% [markdown]
# Before training the U-Net model with Deeplay, ensure that the input dataset has the shape (N, X, Y, C), where:
#
# N: Number of samples (simulated images)\
# X: Width of the image (pixels along the horizontal axis)\
# Y: Height of the image (pixels along the vertical axis)\
# C: Number of channels (use 1 for grayscale images)

# %%
print(f"Image dimensions: {images.shape}")
print(f"Maps dimensions: {maps.shape}")
# Out:
# Image dimensions: (128, 64, 64, 1)
# Maps dimensions: (128, 64, 64, 1)

# %% [markdown]
# Visualize the simulated training dataset.

# %%
# Select an image and its corresponding probability maps and mask to show.
selected_image_index = np.random.randint(0, len(images))

# Extract the image and probability map from 4D arrays.
selected_image = np.squeeze(images[selected_image_index])
selected_probability_map = np.squeeze(maps[selected_image_index])

# Plot the image as the first subplot.
utils.plot_image_mask_ground_truth_map(
    image=selected_image,
    gt_map=selected_probability_map,
    title=f"Training dataset element: {selected_image_index+1}/{len(images)}",
)

# %% [markdown]
# ### Define a U-Net model using Deeplay

# %% [markdown]
# The name 'U-Net' comes from its characteristic U-shaped architecture, which features a symmetric encoder–decoder structure. The encoder (downsampling path) captures contextual information by progressively reducing spatial resolution, while the decoder (upsampling path) restores spatial detail. Skip connections between corresponding levels of the encoder and decoder help retain fine-grained features, improving segmentation accuracy—especially for small or faint objects.
#
# You'll define a 2D U-Net where both the input and output images have a single channel, corresponding to grayscale intensity. The goal is for the model to learn a mapping from the experimental image to a spatial probability density map that indicates the likelihood of particle presence at each pixel.
#
# As a rule of thumb, stacking N convolutional layers with 3×3 kernels gives a receptive field of about (2N+1)×(2N+1) pixels. For example, three layers correspond to roughly a 7×7 receptive field.
# Downsampling layers (like 2×2 pooling or stride-2 convolutions) expand the receptive field much more quickly, since each subsequent convolution “sees” a larger patch of the original image. This is why U-Nets with multiple downsampling stages can capture both fine details and large-scale context.

# %%
# Input and output channels are set to 1, since both images and probability
# maps only have one color channel.
unet = dl.UNet2d(
    in_channels=1, 
    channels=[8, 16, 24], 
    out_channels=1,
)

# %% [markdown]
# Compile the model for the task of regressing the masks from the images.

# %%
# A U-Net regressor is defined using a deeplay model. The loss function is Mean
# Squared Error Loss, since the output is a continuous intensity map.
regressor_unet = dl.Regressor(
    model=unet, 
    loss=torch.nn.MSELoss(), 
    optimizer=dl.Adam(lr=1e-3),
).create()

# %% [markdown]
# Define the training pipeline using Deeptrack to generate the training dataset
# The training pipeline is composed of the simulated images and the probability maps, together with instructions of value normalization and a selector of images, all of which are instances of Deeplay.

# %%
# Image selector with a random picker. This is performed in order to properly 
# link an element in maps array with its corresponding element in images 
# array.
selector = dt.Lambda(
    lambda i: lambda x: x[i], i=lambda l: np.random.randint(l), l=len(images)
)

# Apply augmentations of added Gaussian noise only to images.
images_augmentation_pipeline = (
    dt.Value(images)
    >> dt.NormalizeMinMax(0.0, 1.0)
    >> dt.Gaussian(0.0, 0.025)
    >> dt.NormalizeMinMax(
        lambda: np.random.uniform(0.0, 0.1), 
        lambda: np.random.uniform(0.9, 1.0),
    )
)

# Apply normalization to ground truth map.
maps_pipeline = dt.Value(maps) >> dt.NormalizeMinMax(0.0, 1.0)

# Training pipeline consists of two paired lists: images and ground-truth maps.
# Images are augmented and normalized, while maps are only normalized.
# The selector randomly selects an image and its corresponding ground truth.
# The pipeline is then passed to the deeplay model.
pipeline = (
    (images_augmentation_pipeline & maps_pipeline)
    >> dt.FlipUD()
    >> dt.FlipLR()
    >> selector
)

# Create the training dataset instance in PyTorch
train_dataset = dt.pytorch.Dataset(pipeline, length=256)

# %% [markdown]
# Randomly select and display one augmented crop from the training dataset.

# %%
# Sanity check.
sanity_check_pipeline_augmentation = np.squeeze(pipeline.update().resolve())
sanity_check_image_augmentation = sanity_check_pipeline_augmentation[0]
sanity_check_map_augmentation = sanity_check_pipeline_augmentation[1]

# Plot the image as the first subplot.
utils.plot_image_mask_ground_truth_map(
    image=sanity_check_image_augmentation,
    gt_map=sanity_check_map_augmentation,
    title=f"Random Augmentation from Training Pipeline",
)

# %% [markdown]
# ### Train the U-Net model

# %% [markdown]
# Create a data loader to iterate over the training dataset in batches ensuring randomized sampling at each epoch. Initialize a Trainer from Deeplay to train the U-Net model for up to 64 epochs.

# %%
from torch.utils.data import DataLoader

# Create a DataLoader for training.
train_loader = DataLoader(
    train_dataset, 
    batch_size=16, 
    shuffle=True,
)

# Initialize UNet trainer with automatic accelerator (e.g., CUDA if available).
trainer_unet = dl.Trainer(max_epochs=64, accelerator="auto")

# %% [markdown]
# Attempt to load pre-trained weights for the U-Net model. If the weights file does not exist, train the model from scratch and save the weights for future use.

# %%
# Force training if desired.
force_training = True

# Define the file paths for the model weights.
unet_path = "UNet_model_spheres.pth"
regressor_unet_path = "UNet_reg_spheres.pth"

# Define folder and construct full file paths.
folder_name = "UNet"
unet_path = os.path.join(folder_name, unet_path)
regressor_unet_path = os.path.join(folder_name, regressor_unet_path)

# Load preexisting weights if they exist and training is not forced.
if (not force_training and os.path.exists(unet_path)
    and os.path.exists(regressor_unet_path)):
    unet.load_state_dict(torch.load(unet_path, weights_only=True))
    regressor_unet.load_state_dict(
        torch.load(regressor_unet_path, weights_only=True)
    )
    print(f"Loaded preexisting U-Net weights from '{folder_name}/'.")
else:
    print("Training U-Net model (either forced or weights not found).")
    
    # Ensure the save directory exists.
    os.makedirs(folder_name, exist_ok=True)

    # Train the U-Net model.
    trainer_unet.fit(regressor_unet, train_loader)

    # Monitor training history.
    trainer_unet.history.plot()
    
    # Save the weights.
    torch.save(unet.state_dict(), unet_path)
    torch.save(regressor_unet.state_dict(), regressor_unet_path)
    print(f"Saved trained U-Net weights to '{folder_name}/'.")
    
# Transfer the model to the best available device (optional).
regressor_unet.to(device);
# Out:
# Training U-Net model (either forced or weights not found).
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ loss          │ MSELoss          │      0 │ train │     0 │
# │ 1 │ train_metrics │ MetricCollection │      0 │ train │     0 │
# │ 2 │ val_metrics   │ MetricCollection │      0 │ train │     0 │
# │ 3 │ test_metrics  │ MetricCollection │      0 │ train │     0 │
# │ 4 │ model         │ UNet2d           │ 23.0 K │ train │     0 │
# │ 5 │ optimizer     │ Adam             │      0 │ train │     0 │
# └───┴───────────────┴──────────────────┴────────┴───────┴───────┘
# Trainable params: 23.0 K
# Non-trainable params: 0
# Total params: 23.0 K
# Total estimated model params size (MB): 0
# Modules in train mode: 42
# Modules in eval mode: 0
# Total FLOPs: 0
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:317: The number of training batches (16) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Saved trained U-Net weights to 'UNet/'.

# %% [markdown]
# ### Apply the Trained U-Net to the Simulations

# %% [markdown]
# Use the trained U-Net to infer the probability map of the simulated image. This output represents the predicted likelihood of particle presence at each pixel.
#
# First, convert the selected image to a PyTorch tensor and pass it through the trained U-Net to infer the probability map of particle locations.

# %%
# Convert the image to analyze into a PyTorch tensor.
formatted_sim_image = utils.format_image(sim_image).to(device)

# Apply the UNet to the loaded image.
sim_image_pred_map_tensor = regressor_unet(formatted_sim_image)

# Convert to NumPy array.
sim_image_pred_map = sim_image_pred_map_tensor[0,0,:,:].cpu().detach().numpy()

# Normalize intensity.
sim_image_pred_map = utils.normalize_min_max(sim_image_pred_map)

# %% [markdown]
# Apply thresholding to the predicted probability map to isolate potential particle regions.
#
# Calculate the centroids of the detected regions using the probability map as a weight. This enables subpixel localization by emphasizing the most confident regions of each detection.

# %%
# Apply thresholding to the predicted ground truth map.
sim_image_pred_mask_unet = sim_image_pred_map > 0.2

# Convert the masked ground truth map to positions.
sim_locs_pred_method3 = \
    utils.mask_to_positions(sim_image_pred_mask_unet, sim_image_pred_map)

# Show the predicted positions and ground truth on the simulated image.
utils.plot_predicted_positions(
    image=sim_image,
    pred_positions=sim_locs_pred_method3, 
    gt_positions=sim_locs_gt,
    title="Method 3 - Simulated Image",
)
# Print the number of detections.
print(f"Found {len(sim_locs_pred_method3[:,1])} detections.")
# Out:
# Found 312 detections.

# %% [markdown]
# Evaluate performance by comparing the predicted coordinates with ground-truth positions.
#
# Visualize the results by displaying the original image with the localized particle positions overlaid, allowing you to qualitatively assess the accuracy of the prediction.

# %%
# Measure the performance.
utils.evaluate_locs(
    sim_locs_pred_method3, sim_locs_gt, distance_th=particle_radius,
);

# Plot the predicted ground truth map and its masked version.
utils.plot_image_mask_ground_truth_map(
    mask=sim_image_pred_mask_unet,
    gt_map=sim_image_pred_map,
    title="Method 3 - Simulated Image",
)
# Out:
# True Positives: 312/312
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1273

# %% [markdown]
# ### Apply the Trained U-Net to the Experiments

# %% [markdown]
# Use the trained U-Net model to predict where particles are in the experimental image:
#
# - Normalize the image so pixel values are between 0 and 1.
# - Reshape the image to match the input format expected by the network: (N, C, X, Y) → where N=1 (batch size), and C=1 (grayscale).
# - Convert the image to a PyTorch tensor and feed it to the U-Net.
# - The model returns a probability map showing where it thinks particles are most likely to be.
# - Normalize the predicted map again to scale between 0 and 1.
# - Apply a threshold to the probability map to create a binary mask.
# - Extract particle positions from this mask.
# - Plot both the experimental image with predicted positions and the model's output map + masked version for inspection.

# %%
# Convert the image to analyze into a PyTorch tensor.
formatted_exp_image = utils.format_image(exp_image[..., np.newaxis])

# Transfer the tensor to the best available device (optional).
formatted_exp_image = formatted_exp_image.to(device)

# Apply the UNet to the loaded image.
exp_image_pred_map_tensor = regressor_unet(formatted_exp_image)

# Convert to NumPy array.
exp_image_pred_map = exp_image_pred_map_tensor[0,0,:,:].cpu().detach().numpy()

# Normalize intensity.
exp_image_pred_map = utils.normalize_min_max(exp_image_pred_map)

# Apply thresholding to the predicted ground truth map.
exp_image_pred_mask_unet = exp_image_pred_map > 0.2

# Convert the masked ground truth map to positions.
exp_locs_pred_method3 = \
    utils.mask_to_positions(exp_image_pred_mask_unet, exp_image_pred_map)

# Plot the experimental image with the positions predicted by U-Net.
utils.plot_predicted_positions(
    image=exp_image, 
    pred_positions=exp_locs_pred_method3, 
    title="Method 3 - Experimental Image",
)

# Plot the predicted ground truth map and its masked version.
utils.plot_image_mask_ground_truth_map(
    mask=exp_image_pred_mask_unet,
    gt_map=exp_image_pred_map,
    title="Method 3 - Experimental Image",
)

# Print the number of detections.
print(f"Found {len(exp_locs_pred_method3[:,1])} detections.")
# Out:
# No ground truth positions were passed
# Found 464 detections.

# %% [markdown]
# ## Method 4: LodeSTAR

# %% [markdown]
# LodeSTAR is a self-supervised method for object detection that doesn’t require labeled data. You can even train it using a single input image—no manual annotations needed!
#
# The idea is simple but powerful: LodeSTAR learns to detect particles by finding consistent features across randomly transformed versions of the same image. These transformations can include translation, rotation, or scaling.
#
# By learning to predict the coordinate shifts between the transformed images, the network becomes very good at localizing objects—even under noisy or experimental conditions.
#
# This makes LodeSTAR especially useful when ground-truth labels are unavailable or unreliable, which is often the case in real microscopy work.

# %% [markdown]
# ### Simulate Training Data for LodeSTAR

# %% [markdown]
# To mimic real experimental conditions, you'll use DeepTrack to generate a set of synthetic images, each containing a single particle. These are produced using a mix of simulation and data augmentation. The particle’s size and intensity are randomized within realistic bounds, making the dataset more diverse and representative of what you'd expect in actual microscopy data.
#
# This setup reflects real use cases, where LodeSTAR is trained on augmentations of a single experimental crop.
#
# If the dataset already exists, you can simply load it; otherwise, new crops are simulated and saved.
#
# Finally, a few sample crops are visualized to confirm they look physically realistic.

# %%
# Number of samples, image size, and particles.
num_samples = 64
train_crops_size = sim_crop_size
max_num_particles = 1
force_simulation = True  # Flag to force simulation even if data exists

# Create path to store training dataset.
folder_name = "LodeSTAR"
training_dataset_filename = "LodeSTAR_training_dataset_spheres.npz"
training_dataset_folder = os.path.join(folder_name, "training_data")
training_dataset_filepath = os.path.join(
    training_dataset_folder, 
    training_dataset_filename,
)

# Create the enclosing directory if not existent already.
os.makedirs(training_dataset_folder, exist_ok=True)

# Dictionary for particle properties. Dimensions are set with lambda
# functions to introduce variety to the dataset.
sphere_properties = {
    "radius": lambda: (np.random.uniform(0.9, 1.0) * particle_radius
                       * dt.units.nm),
    "intensity": lambda: np.random.normal(1.0, 0.1) * 7.5E4,
    "z": lambda: np.random.uniform(-50, 50) * dt.units.nm,
}

# Set the optical properties of the microscope.  
optics_properties = dt.Fluorescence(
    NA=0.7,  # Numerical aperture
    wavelength=590 * dt.units.nm,
    refractive_index_medium=1.33,
    output_region=[0, 0, train_crops_size, train_crops_size],
    magnification=2,
    resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
)

# Try to load preexisting simulated data; if not available or forced, raise an
# exception error to generate new data.
try:
    if force_simulation: 
        # Raise the exception error if simulation is forced.
        raise FileNotFoundError("Forced simulation by user request.")
    
    if not os.path.isfile(training_dataset_filepath):
        # If file is not found, start training.    
        raise FileNotFoundError(
            "Training dataset file not found. Starting simulation."
        )
    
    # Load existing data
    data = np.load(training_dataset_filepath)
    crop_images = data["crop_images"]
    crop_maps = data["crop_maps"]
    Nsamples = len(crop_images)  # Update number of samples.
    print(f"Loaded file: {training_dataset_filepath}")
        
# Handle the case of either file not found or forced training.
except FileNotFoundError:
    
    # Perform simulation if file not found or forced.
    crop_images, crop_maps = utils.generate_particle_dataset(
        num_samples = num_samples,
        fov_size = train_crops_size,
        max_num_particles = max_num_particles,
        core_particle_dict=sphere_properties,
        optics_properties=optics_properties,
        background_props={"peak_snr": 5.5e5, "background_mean": 0, "background_std": 100},
    )

    # Save the simulated training dataset.
    np.savez(
        training_dataset_filepath, 
        crop_images=crop_images, 
        crop_maps=crop_maps,
    )
    print("New dataset generated and saved.")
    
# Plot up to 18 simulated crops.
utils.plot_crops(np.squeeze(crop_images), title="Simulated Crops")
# Out:
# Generating sample 64/64
# Dataset generation complete.
# New dataset generated and saved.

# %% [markdown]
# Build a training pipeline that randomly selects and augments particle crops on the fly. Each crop is chosen randomly from the simulated dataset and normalized with slightly varying min/max values to mimic contrast and illumination changes.
#
# This setup creates a diverse training set without needing to store multiple augmented copies.

# %%
# Define the training pipeline with additional settings, such as multiplication
# of global intensity and Gaussian noise.
selector = dt.Lambda(
    lambda i: lambda x: x[i],
    i=lambda l: np.random.randint(l),
    l=len(crop_images),
)

# Define a training pipeline with augmentations. 
training_pipeline = (
    dt.Value(lambda: crop_images)
    >> dt.NormalizeMinMax(0.0, 1.0)
    # >> dt.Gaussian(0.0, 0.025)
    # >> dt.NormalizeMinMax(
    #     lambda: np.random.uniform(0.0, 0.1), 
    #     lambda: np.random.uniform(0.9, 1.0)
    # )
    >> selector
)

# Build a training dataset with a pipeline that randomly selects a crop each
# time.
train_dataset = dt.pytorch.Dataset(
    training_pipeline,
    length=128,
)

# Dataloader contains the randomized training dataset and additional settings.
dataloader = dl.DataLoader(
    train_dataset,
    batch_size=8,
)

# We can check one of the elements in the training pipeline with augmentations.
sanity_check_crop = training_pipeline.update().resolve()

plt.figure()
plt.imshow(np.squeeze(sanity_check_crop), cmap="gray", aspect="equal")
plt.title("Random Crop from Training Pipeline")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Train LodeSTAR and Apply it to Simulations

# %% [markdown]
# Create a LodeSTAR model with 4 random geometric transformations per input and set up the trainer, which will handle the training loop.

# %%
#  Initialize the model.
lodestar = dl.LodeSTAR(
    n_transforms=3,
    optimizer=dl.Adam(lr=1e-3),
).build()

# Set up the trainer and specify number of epochs.
trainer_lodestar = dl.Trainer(max_epochs=48, accelerator="auto")

# %% [markdown]
# Check if pretrained weights already exist. Otherwise train LodeSTAR on the simulated crops using the training pipeline and save the trained weights for later use. Otherwise, simply load the existing weights from file.
#
# Finally, switch the model to evaluation mode, which disables training-specific behaviors.

# %%
# Define whether to force training even if weights exist.
force_training = True

# Define folder and path for storing LodeSTAR weights.
folder_name = "LodeSTAR"
lodestar_path = os.path.join(folder_name, "lodestar_weights_simulated")

# Train or load weights.
if not os.path.isfile(lodestar_path) or force_training:
    print("Training LodeSTAR model (either forced or weights not found).")
    
    # Ensure the save directory exists.
    os.makedirs(folder_name, exist_ok=True)
    
    # Train the model.
    trainer_lodestar.fit(lodestar, dataloader)
    
    # Monitor training history.
    trainer_lodestar.history.plot()
    
    # Save weights.
    torch.save(lodestar.state_dict(), lodestar_path)
    print(f"Saved LodeSTAR weights to '{lodestar_path}'.")
else:
    # Load pre-trained weights.
    lodestar.load_state_dict(torch.load(lodestar_path, weights_only=True))
    print(f"Loaded preexisting LodeSTAR weights from '{lodestar_path}'.")



# Set model to evaluation mode.
lodestar.eval();

# Transfer the model to the best available device (optional).
lodestar.to(device);
# Out:
# Training LodeSTAR model (either forced or weights not found).
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type                       ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ ConvolutionalNeuralNetwork │  251 K │ train │     0 │
# │ 1 │ between_loss  │ L1Loss                     │      0 │ train │     0 │
# │ 2 │ within_loss   │ L1Loss                     │      0 │ train │     0 │
# │ 3 │ train_metrics │ MetricCollection           │      0 │ train │     0 │
# │ 4 │ val_metrics   │ MetricCollection           │      0 │ train │     0 │
# │ 5 │ test_metrics  │ MetricCollection           │      0 │ train │     0 │
# │ 6 │ optimizer     │ Adam                       │      0 │ train │     0 │
# └───┴───────────────┴────────────────────────────┴────────┴───────┴───────┘
# Trainable params: 251 K
# Non-trainable params: 0
# Total params: 251 K
# Total estimated model params size (MB): 1
# Modules in train mode: 39
# Modules in eval mode: 0
# Total FLOPs: 0
# Training: |          | 0/? [00:00<?, ?it/s]
# Saved LodeSTAR weights to 'LodeSTAR/lodestar_weights_simulated'.

# %% [markdown]
# Apply the trained LodeSTAR model to a simulated image.  Set the inference parameters which control detection sensitivity. Get the prediction features, including the mass_feature, which can be useful for visualizing detections. Extract the final coordinates of the detected particles and print how many particles were detected.

# %%
# Parameters for inference.
alpha = 0.9
beta = 1 -alpha
cutoff = 0.8

# Extract predictions.
sim_image_pred_lodestar = \
    lodestar(formatted_sim_image.to(device)).squeeze().detach()

# Extract the mass feature from the prediction.
sim_image_mass_feature = sim_image_pred_lodestar[2].cpu()

# Infer on the pytorch image.
sim_locs_pred_method4 = lodestar.detect(
    formatted_sim_image,
    alpha = alpha,
    beta = beta, 
    mode = "quantile",
    cutoff = cutoff,
)[0]
                         
print(f"Found {len(sim_locs_pred_method4[:, 1])} detections.")
# Out:
# Found 315 detections.

# %% [markdown]
# Display mass features predicted for the simulated image.

# %%
plt.figure(figsize=(10, 5))

#  Subfigure 1, test image.
plt.subplot(1, 3, 1)
plt.imshow(sim_image, cmap="gray")
plt.axis("off")
plt.title("Simulated Image")

#  Subfigure 2, mass feature distribution.
plt.subplot(1, 3, 2)
plt.imshow(sim_image_mass_feature, cmap="gray")
plt.axis("off")
plt.title("Mass Features Predicted by LodeSTAR")

plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the predicted positions from LodeSTAR alongside the ground truth on the simulated image and quantify the performance.

# %%
# Plot the predicted positions and the ground truth overlaid on the simulated
# image.
utils.plot_predicted_positions(
    image=sim_image,
    pred_positions=sim_locs_pred_method4,
    gt_positions=sim_locs_gt,
    title="Method 4 Trained on Simulations - Simulated Image",
)
#  Evaluate performance.
utils.evaluate_locs(
    sim_locs_pred_method4, sim_locs_gt, distance_th=particle_radius,
);
# Out:
# True Positives: 312/312
# False Positives: 3
# False Negatives: 0
# F1 Score: 0.9952
# RMSE: 0.6079

# %% [markdown]
# ### Apply the Trained LodeSTAR on Experiments

# %% [markdown]
# - Apply LodeSTAR to the experimental image using the same inference settings (alpha, beta, cutoff) as before.
# - Run the model to extract prediction features, including the mass channel.
# - Get the final particle coordinates and print the total number of detections.
# - Visualize the original experimental image and the mass feature map predicted by LodeSTAR.

# %%
#  Parameters for inference.
alpha = 0.5
beta = 1 - alpha
cutoff = 0.5

# Extract predictions and convert into a tensor
exp_image_pred_lodestar = \
    lodestar(formatted_exp_image.to(device)).squeeze().detach()

# Extract the mass feature from the prediction
exp_image_mass_feature = \
    exp_image_pred_lodestar[2].cpu()  # Transfer to CPU for plotting

# Infer positions from experimental image.
exp_locs_pred_method4 = lodestar.detect(
    formatted_exp_image,
    alpha = alpha,
    beta = beta, 
    mode = "quantile",
    cutoff = cutoff,
)[0]

print(f"Found {len(exp_locs_pred_method4[:,1])} detections.")

## Display predictions of experimental image
# Set the figure size
plt.figure(figsize=(10, 5))

#  Subfigure 1, test image.
plt.subplot(1, 3, 1)
plt.imshow(exp_image, cmap="gray")
plt.axis("off")
plt.title("Experimental Image")

#  Subfigure 2, mass features.
plt.subplot(1, 3, 2)
plt.imshow(exp_image_mass_feature, cmap="gray")
plt.axis("off")
plt.title("Mass Features Predicted by LodeSTAR")

plt.gca().set_aspect('equal', adjustable='box')
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Found 507 detections.

# %% [markdown]
# Display the experimental image with the predicted particle positions overlaid to visually inspect the detection quality.

# %%
utils.plot_predicted_positions(
   image=exp_image,
   pred_positions= exp_locs_pred_method4,
   title="Method 4 Trained on Simulations - Experimental Image",
)
# Out:
# No ground truth positions were passed

# %% [markdown]
# ### Train LodeSTAR with Experiments

# %% [markdown]
# Since LodeSTAR is self-supervised, you can train it directly on experimental crops—no ground-truth labels needed.
#
# Start by identifying a few representative particles in the experimental image. From these, extract small crops centered on the particles using the same code to get the first crop in this tutorial. These serve as the training data, and LodeSTAR learns by applying random transformations to these crops and predicting how the particle positions change.

# %%
# Define crop parameters: (x, y, width)
crop_params = [
    (285, 243,  exp_crop_size),
    (192, 184,  exp_crop_size),
    (203, 375,  exp_crop_size),
    (449, 344,  exp_crop_size),
]


# Extract particle-centered crops from the image.
exp_crops = [exp_image[y - w//2:y + w//2, x - w//2:x + w//2, np.newaxis]
             for x, y, w in crop_params]

# Plot up to 18 crops.
utils.plot_crops(np.squeeze(exp_crops), title="Experimental Crops")

# %% [markdown]
# Prepare the training pipeline with the selected experimental crops.

# %%
# Random selector of crops.
random_crop = lambda: random.choice(np.array(exp_crops))

# Define training pipeline.
training_pipeline = (
    dt.Value(random_crop)
    >> dt.NormalizeMinMax(0.0, 1.0)
    >> dt.Gaussian(0.0, 0.025)
    >> dt.NormalizeMinMax(
        lambda: np.random.uniform(0.0, 0.1), 
        lambda: np.random.uniform(0.9, 1.0),
        )
    #>> dt.pytorch.ToTensor(dtype=torch.float32)
)

# Build a training dataset with a pipeline that randomly selects a crop each
# time.
train_dataset = dt.pytorch.Dataset(
    training_pipeline,
    length=128,
)

# Dataloader contains the randomized training dataset and additional settings.
dataloader = dl.DataLoader(
    train_dataset,
    batch_size=12,
    shuffle=True,
)

# We can check one of the elements in the training pipeline with augmentations.
sanity_check_crop = training_pipeline.update().resolve()
plt.figure()
plt.imshow(np.squeeze(sanity_check_crop), cmap="gray", aspect="equal")
plt.title("Random Crop from Training Pipeline")
plt.axis("off")
plt.show()

# %% [markdown]
# Create a LodeSTAR model with 4 random geometric transformations per input and set up the trainer, which will handle the training loop.

# %%
#  Initialize the model.
lodestar_exp = dl.LodeSTAR(
    n_transforms=4, 
    optimizer=dl.Adam(lr=1e-3),
).build()

# Set up the trainer and specify number of epochs.
trainer_lodestar_exp = dl.Trainer(max_epochs=48, accelerator="auto")

# %% [markdown]
# Check whether pre-trained LodeSTAR weights already exist on disk. If they are missing or if training is explicitly forced, the model is trained on the experimental crops using the specified training pipeline, and the resulting weights are saved for future use.
#
# If the weights are already available and training is not forced, they are simply loaded from file.
#
# Afterward, the model is set to evaluation mode, which disables training-specific behaviors, ensuring consistent behavior during inference.

# %%
# Define whether to force training even if weights exist.
force_training = True

# Define folder and path for storing LodeSTAR experimental weights.
folder_name = "LodeSTAR"
lodestar_exp_path = os.path.join(folder_name, "lodestar_weights_exp")

# Train or load weights.
if not os.path.isfile(lodestar_exp_path) or force_training:
    print("Training LodeSTAR on experimental data "
          "(either forced or weights not found).")
    
    # Ensure the save directory exists.
    os.makedirs(folder_name, exist_ok=True)

    # Train the model.
    trainer_lodestar_exp.fit(lodestar_exp, dataloader)
    
    # Monitor training history.
    trainer_lodestar_exp.history.plot()

    # Save weights.
    torch.save(lodestar_exp.state_dict(), lodestar_exp_path)
    print(f"Saved experimental LodeSTAR weights to '{lodestar_exp_path}'.")
else:
    # Load pre-trained weights.
    lodestar_exp.load_state_dict(
        torch.load(lodestar_exp_path, weights_only=True)
    )
    print(f"Loaded preexisting LodeSTAR weights from '{lodestar_exp_path}'.")



# Set model to evaluation mode.
lodestar_exp.eval();

# Transfer the model to the best available device (optional).
lodestar_exp.to(device);
# Out:
# Training LodeSTAR on experimental data (either forced or weights not found).
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/lightning/pytorch/trainer/configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type                       ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model         │ ConvolutionalNeuralNetwork │  251 K │ train │     0 │
# │ 1 │ between_loss  │ L1Loss                     │      0 │ train │     0 │
# │ 2 │ within_loss   │ L1Loss                     │      0 │ train │     0 │
# │ 3 │ train_metrics │ MetricCollection           │      0 │ train │     0 │
# │ 4 │ val_metrics   │ MetricCollection           │      0 │ train │     0 │
# │ 5 │ test_metrics  │ MetricCollection           │      0 │ train │     0 │
# │ 6 │ optimizer     │ Adam                       │      0 │ train │     0 │
# └───┴───────────────┴────────────────────────────┴────────┴───────┴───────┘
# Trainable params: 251 K
# Non-trainable params: 0
# Total params: 251 K
# Total estimated model params size (MB): 1
# Modules in train mode: 39
# Modules in eval mode: 0
# Total FLOPs: 0
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/lightning/pytorch/loops/fit_loop.py:317: The number of training batches (11) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
# Saved experimental LodeSTAR weights to 'LodeSTAR/lodestar_weights_exp'.

# %% [markdown]
# Apply the trained LodeSTAR model to an experimental image. Set the inference parameters which control detection sensitivity. Get the prediction features, including the mass_feature, which can be useful for visualizing detections. Extract the final coordinates of the detected particles and print how many particles were detected.

# %%
#  Parameters for inference.
alpha = 0.7
beta = 1 - alpha 
cutoff = 0.1

#  Extract predictions and convert into a tensor.
exp_image_pred_lodestar_exp = \
    lodestar_exp(formatted_exp_image.to(device)).squeeze().detach()

# Extract the mass feature from the prediction.
exp_image_mass_feature_exp = \
    exp_image_pred_lodestar_exp[2].cpu() # Transfer to CPU for plotting

#  Infer positions from experimental image.
exp_locs_pred_method4_exp = lodestar_exp.detect(
    formatted_exp_image,
    alpha=alpha,
    beta=beta, 
    mode="quantile",
    cutoff=cutoff,
)[0]
                         
print(f"Found {len(exp_locs_pred_method4_exp[:,1])} detections.")
# Out:
# Found 463 detections.

# %% [markdown]
# Display mass features predicted for the experimental image.

# %%
# Set the figure size.
plt.figure(figsize=(10, 5))

#  Subfigure 1, test image.
plt.subplot(1, 3, 1)
plt.imshow(exp_image, cmap="gray")
plt.axis("off")
plt.title("Experimental Image")

#  Subfigure 2, mass feature distribution.
plt.subplot(1, 3, 2)
plt.imshow(exp_image_mass_feature_exp, cmap="gray")
plt.axis("off")
plt.title("Mass Features Predicted by LodeSTAR")

plt.gca().set_aspect('equal', adjustable='box')
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the predicted positions from LodeSTAR on the experimental image.

# %%
utils.plot_predicted_positions(
   image=exp_image,
   pred_positions= exp_locs_pred_method4_exp,
   title="Method 4 Trained on Experimental Crops - Experimental Image",
)
# Out:
# No ground truth positions were passed

# %% [markdown]
# # Detection statistics

# %%
from joblib import Parallel, delayed, parallel_config

# %%
def run_simulation(i):
    print(f"Running simulation {i+1}")
    # Parameters of the simulation.
    sim_image_size = exp_image_size
    N_particles = 450
    particle_radius = 900 # In nm.

    # Dictionary for particle properties.
    # Dimensions are set with lambda functions to introduce variety to the dataset.
    sphere_properties = {
        "radius": lambda: (np.random.uniform(0.9, 1.1) * particle_radius
                           * dt.units.nm),
        "intensity": lambda: np.random.normal(1.0, 0.1) * 7.5E4,
        "z": lambda: np.random.uniform(-1000, 1000) * dt.units.nm,
    }

    # Set the optical properties of the microscope.  
    optics_properties = dt.Fluorescence(
        NA=0.7,  # Numerical aperture
        wavelength=590 * dt.units.nm,
        refractive_index_medium=1.33,
        output_region=[0, 0, exp_image_size, exp_image_size],
        magnification=2,
        resolution=pixel_size_nm * dt.units.nm,  # Camera effective resolution
    )

    # Generate ground truth positions.
    sim_locs_gt = utils.generate_centroids(
        num_particles=N_particles,
        fov_size=sim_image_size,
        particle_radius=particle_radius, 
    )

    # Simulate image.
    sim_image = utils.transform_to_video(
        sim_locs_gt,
        fov_size=sim_image_size,
        core_particle_props=sphere_properties,
        optics_props=optics_properties,
        background_props={"peak_snr": 5.5e5, "background_mean": 0, "background_std": 100},
    )

    # Generate the ground truth as Gaussian clouds centered at the position of the
    # spheres. The standard deviation of the Gaussians are set to be proportional 
    # to the radii of the corresponding spherical particles.
    gt_cloud_size = particle_radius / 2

    # Generate ground truth map using the positions, radii and intensities of the 
    # particles.
    sim_map = utils.create_ground_truth_map(
        sim_locs_gt, 
        fov_size=sim_image_size, 
        sigma=gt_cloud_size, 
    )

    print(f"Finished simulation {i+1}")
    return sim_locs_gt, sim_image, sim_map


# Number of simulations.
N_simulations = 100

# Number of parallel workers.
N_workers = 16

# Run simulations in parallel.
results = Parallel(
    n_jobs=N_workers,
    verbose=10,
)(
    delayed(run_simulation)(i)
    for i in range(N_simulations)
)


# Arrays to store results.
sim_locs_gt_array = np.empty(N_simulations, dtype=object)
sim_image_array = np.empty(N_simulations, dtype=object)
sim_map_array = np.empty(N_simulations, dtype=object)

# Store results.
for i, (sim_locs_gt, sim_image, sim_map) in enumerate(results):
    sim_locs_gt_array[i] = sim_locs_gt
    sim_image_array[i] = sim_image
    sim_map_array[i] = sim_map

# Save arrays to working directory.
np.save("sim_locs_gt_array_spheres.npy", sim_locs_gt_array)
np.save("sim_image_array_spheres.npy", sim_image_array)
np.save("sim_map_array_spheres.npy", sim_map_array)
# Out:
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# Running simulation 1
# Running simulation 9
# Running simulation 2
# Running simulation 6
# Running simulation 3
# Running simulation 5
# Running simulation 7
# Running simulation 11
# Running simulation 4
# Running simulation 12
# Running simulation 15
# Running simulation 16
# Running simulation 8
# Running simulation 13
# Running simulation 10
# Running simulation 14
# Finished simulation 1
# Running simulation 17
# Finished simulation 11
# Finished simulation 8
# Finished simulation 2
# Finished simulation 13
# Finished simulation 15
# Running simulation 18
# Finished simulation 4
# Finished simulation 14
# Finished simulation 3
# Finished simulation 9
# [Parallel(n_jobs=16)]: Done   9 tasks      | elapsed:   27.2s
# Finished simulation 7
# Running simulation 19
# Running simulation 20
# Finished simulation 10
# Running simulation 21
# Running simulation 22
# Running simulation 23
# Finished simulation 5
# Finished simulation 12
# Finished simulation 6
# Running simulation 24
# Running simulation 25
# Running simulation 26
# Running simulation 27
# Finished simulation 16
# Running simulation 28
# Running simulation 29
# Running simulation 30
# Running simulation 31
# Running simulation 32
# Finished simulation 17
# Running simulation 33
# Finished simulation 33
# Running simulation 34
# [Parallel(n_jobs=16)]: Done  18 tasks      | elapsed:   34.3s
# Finished simulation 19
# Running simulation 35
# Finished simulation 34
# Running simulation 36
# Finished simulation 29
# Running simulation 37
# Finished simulation 20
# Running simulation 38
# Finished simulation 35
# Running simulation 39
# Finished simulation 18
# Running simulation 40
# Finished simulation 30
# Running simulation 41
# Finished simulation 22
# Running simulation 42
# Finished simulation 21
# Running simulation 43
# Finished simulation 23
# Running simulation 44
# Finished simulation 24
# Finished simulation 28
# Running simulation 45
# Running simulation 46
# [Parallel(n_jobs=16)]: Done  29 tasks      | elapsed:   54.3s
# Finished simulation 27
# Running simulation 47
# Finished simulation 32
# Finished simulation 31
# Running simulation 48
# Running simulation 49
# Finished simulation 26
# Running simulation 50
# Finished simulation 25
# Running simulation 51
# Finished simulation 39
# Running simulation 52
# Finished simulation 37
# Running simulation 53
# Finished simulation 36
# Running simulation 54
# Finished simulation 38
# Running simulation 55
# Finished simulation 40
# [Parallel(n_jobs=16)]: Done  40 tasks      | elapsed:   58.3s
# Finished simulation 41
# Running simulation 56
# Finished simulation 42
# Finished simulation 56
# Finished simulation 55
# Finished simulation 52
# /opt/anaconda3/envs/PT_exp/lib/python3.13/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Running simulation 57
# Finished simulation 43
# Finished simulation 54
# Finished simulation 46
# Finished simulation 44
# Finished simulation 48
# Finished simulation 50
# Finished simulation 45
# Finished simulation 49
# Finished simulation 51
# Finished simulation 47
# Finished simulation 53
# Running simulation 59
# Running simulation 60
# Running simulation 61
# Running simulation 62
# Running simulation 63
# Running simulation 64
# Running simulation 65
# Running simulation 66
# Running simulation 67
# Running simulation 68
# Running simulation 69
# Running simulation 71
# [Parallel(n_jobs=16)]: Done  53 tasks      | elapsed:  1.3min
# Finished simulation 57
# Running simulation 72
# Running simulation 58
# Finished simulation 59
# Running simulation 74
# Running simulation 70
# Finished simulation 72
# Running simulation 75
# Finished simulation 66
# Running simulation 76
# Finished simulation 64
# Finished simulation 71
# Running simulation 77
# Running simulation 78
# Finished simulation 60
# Finished simulation 65
# Running simulation 79
# Finished simulation 67
# Finished simulation 61
# Running simulation 80
# Finished simulation 68
# Running simulation 81
# Finished simulation 69
# Running simulation 82
# Running simulation 83
# Finished simulation 63
# [Parallel(n_jobs=16)]: Done  66 tasks      | elapsed:  1.4min
# Running simulation 84
# Running simulation 85
# Finished simulation 62
# Running simulation 86
# Running simulation 73
# Finished simulation 58
# Running simulation 87
# Finished simulation 74
# Finished simulation 87
# Finished simulation 75
# Running simulation 88
# Running simulation 89
# Finished simulation 70
# Finished simulation 73
# Finished simulation 84
# Finished simulation 80
# Running simulation 91
# Running simulation 92
# Finished simulation 76
# Finished simulation 83
# Running simulation 93
# [Parallel(n_jobs=16)]: Done  80 out of 100 | elapsed:  1.7min remaining:   26.1s
# Running simulation 94
# Finished simulation 85
# Running simulation 95
# Finished simulation 79
# Running simulation 96
# Running simulation 97
# Finished simulation 82
# Running simulation 98
# Finished simulation 77
# Running simulation 99
# Finished simulation 86
# Running simulation 100
# Finished simulation 81
# Finished simulation 78
# Finished simulation 88
# Finished simulation 89
# Running simulation 90
# Finished simulation 90
# Finished simulation 96
# Finished simulation 92
# [Parallel(n_jobs=16)]: Done  91 out of 100 | elapsed:  1.9min remaining:   11.5s
# Finished simulation 99
# Finished simulation 91
# Finished simulation 93
# Finished simulation 94
# Finished simulation 100
# Finished simulation 97
# Finished simulation 95
# Finished simulation 98
# [Parallel(n_jobs=16)]: Done 100 out of 100 | elapsed:  1.9min finished

# %% [markdown]
# If simulation was already performed

# %%
# Load arrays from working directory.
sim_locs_gt_array = np.load(
    "sim_locs_gt_array_spheres.npy",
    allow_pickle=True,
)

sim_image_array = np.load(
    "sim_image_array_spheres.npy",
    allow_pickle=True,
)

sim_map_array = np.load(
    "sim_map_array_spheres.npy",
    allow_pickle=True,
)

# %% [markdown]
# Perform threshold detection

# %%
def run_threshold_detection(sim_image, sim_locs_gt):

    # Apply a Gaussian filter to the image to smooth out noise.
    filtered_sim_image = scipy.ndimage.gaussian_filter(sim_image, sigma=1.0)

    # Extract the quantile-based threshold from each filtered image
    quantile=0.9
    quantile_threshold_filtered_sim = np.quantile(filtered_sim_image, quantile)


    # Create the binary mask by applying the threshold.
    sim_mask = filtered_sim_image > quantile_threshold_filtered_sim

    # Ensure the mask is a 2D array.
    sim_mask = np.squeeze(sim_mask)

    # Use the function to extract positions from mask.
    sim_locs_pred_method1 = utils.mask_to_positions(sim_mask)

    TP, FP, FN, F1, RMSE = utils.evaluate_locs(
        sim_locs_pred_method1, sim_locs_gt, distance_th=particle_radius,
    )

    # Estimate the location of the centroid of a masked particle image.
    sim_locs_pred_method1_ref = \
        utils.mask_to_positions(sim_mask, sim_image.squeeze())

    # Evaluate the performance.
    TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx = utils.evaluate_locs(
        sim_locs_pred_method1_ref, sim_locs_gt, distance_th=particle_radius,
    )

    return (
        TP, FP, FN, F1, RMSE,
        TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx,
    )


# Number of parallel workers.
N_workers = 8

# Apply threshold detection to all simulated images.
with parallel_config(
    backend="loky",
    n_jobs=N_workers,
    inner_max_num_threads=1,
):
    results = Parallel()(
        delayed(run_threshold_detection)(
            sim_image_array[i],
            sim_locs_gt_array[i],
        )
        for i in range(len(sim_image_array))
    )


# Convert results directly to a NumPy array.
results = np.asarray(results)

# Standard pixel-level localization.
TP_array_threshold   = results[:, 0]
FP_array_threshold   = results[:, 1]
FN_array_threshold   = results[:, 2]
F1_array_threshold   = results[:, 3]
RMSE_array_threshold = results[:, 4]

# Sub-pixel refined localization.
TP_subpx_array_threshold   = results[:, 5]
FP_subpx_array_threshold   = results[:, 6]
FN_subpx_array_threshold   = results[:, 7]
F1_subpx_array_threshold   = results[:, 8]
RMSE_subpx_array_threshold = results[:, 9]

# Standard pixel-level localization.
TP_array_threshold   = results[:, 0]
FP_array_threshold   = results[:, 1]
FN_array_threshold   = results[:, 2]
F1_array_threshold   = results[:, 3]
RMSE_array_threshold = results[:, 4]

# Sub-pixel refined localization.
TP_subpx_array_threshold   = results[:, 5]
FP_subpx_array_threshold   = results[:, 6]
FN_subpx_array_threshold   = results[:, 7]
F1_subpx_array_threshold   = results[:, 8]
RMSE_subpx_array_threshold = results[:, 9]

print("Threshold method")
print("----------------")

print(f"TP:          {TP_array_threshold.mean():.2f} ± {TP_array_threshold.std():.2f}")
print(f"FP:          {FP_array_threshold.mean():.2f} ± {FP_array_threshold.std():.2f}")
print(f"FN:          {FN_array_threshold.mean():.2f} ± {FN_array_threshold.std():.2f}")
print(f"F1:          {F1_array_threshold.mean():.4f} ± {F1_array_threshold.std():.4f}")
print(f"RMSE:        {RMSE_array_threshold.mean():.4f} ± {RMSE_array_threshold.std():.4f}")

print("\nSub-pixel refined")
print("-----------------")

print(f"TP:          {TP_subpx_array_threshold.mean():.2f} ± {TP_subpx_array_threshold.std():.2f}")
print(f"FP:          {FP_subpx_array_threshold.mean():.2f} ± {FP_subpx_array_threshold.std():.2f}")
print(f"FN:          {FN_subpx_array_threshold.mean():.2f} ± {FN_subpx_array_threshold.std():.2f}")
print(f"F1:          {F1_subpx_array_threshold.mean():.4f} ± {F1_subpx_array_threshold.std():.4f}")
print(f"RMSE:        {RMSE_subpx_array_threshold.mean():.4f} ± {RMSE_subpx_array_threshold.std():.4f}")
# Out:
# True Positives: 308/323
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9762
# RMSE: 0.1510
# True Positives: 309/331
# False Positives: 0
# False Negatives: 22
# F1 Score: 0.9656
# RMSE: 0.4807
# True Positives: 308/323
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9762
# RMSE: 0.1416
# True Positives: 309/331
# False Positives: 0
# False Negatives: 22
# F1 Score: 0.9656
# RMSE: 0.4605
# True Positives: 312/324
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9811
# RMSE: 0.5276
# True Positives: 314/323
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9859
# RMSE: 0.1552
# True Positives: 314/325
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9828
# RMSE: 0.5323
# True Positives: 310/326
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9748
# RMSE: 0.1349
# True Positives: 312/324
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9811
# RMSE: 0.5223
# True Positives: 314/323
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9859
# RMSE: 0.1478
# True Positives: 303/317
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9774
# RMSE: 0.1357
# True Positives: 311/327
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9749
# RMSE: 0.1438
# True Positives: 310/326
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9748
# RMSE: 0.1270
# True Positives: 314/325
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9828
# RMSE: 0.5293
# True Positives: 303/317
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9774
# RMSE: 0.1268
# True Positives: 311/327
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9749
# RMSE: 0.1366
# True Positives: 307/325
# False Positives: 0
# False Negatives: 18
# F1 Score: 0.9715
# RMSE: 0.5324
# True Positives: 310/327
# False Positives: 0
# False Negatives: 17
# F1 Score: 0.9733
# RMSE: 0.1493
# True Positives: 318/328
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9845
# RMSE: 0.1499
# True Positives: 331/345
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9793
# RMSE: 0.7040
# True Positives: 310/324
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9779
# RMSE: 0.1449
# True Positives: 318/328
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9845
# RMSE: 0.1448
# True Positives: 310/327
# False Positives: 0
# False Negatives: 17
# F1 Score: 0.9733
# RMSE: 0.1407
# True Positives: 318/328
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9845
# RMSE: 0.1412
# True Positives: 309/321
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9810
# RMSE: 0.1637
# True Positives: 331/345
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9793
# RMSE: 0.6911
# True Positives: 307/325
# False Positives: 0
# False Negatives: 18
# F1 Score: 0.9715
# RMSE: 0.5221
# True Positives: 310/324
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9779
# RMSE: 0.1359
# True Positives: 318/328
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9845
# RMSE: 0.1369
# True Positives: 309/321
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9810
# RMSE: 0.1543
# True Positives: 316/336
# False Positives: 0
# False Negatives: 20
# F1 Score: 0.9693
# RMSE: 0.4419
# True Positives: 316/336
# False Positives: 0
# False Negatives: 20
# F1 Score: 0.9693
# RMSE: 0.4185
# True Positives: 297/314
# False Positives: 0
# False Negatives: 17
# F1 Score: 0.9722
# RMSE: 0.1534
# True Positives: 319/334
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9770
# RMSE: 0.1494
# True Positives: 297/304
# False Positives: 0
# False Negatives: 7
# F1 Score: 0.9884
# RMSE: 0.1356
# True Positives: 297/314
# False Positives: 0
# False Negatives: 17
# F1 Score: 0.9722
# RMSE: 0.1450
# True Positives: 308/328
# False Positives: 0
# False Negatives: 20
# F1 Score: 0.9686
# RMSE: 0.6358
# True Positives: 319/334
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9770
# RMSE: 0.1419
# True Positives: 310/318
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9873
# RMSE: 0.1497
# True Positives: 297/304
# False Positives: 0
# False Negatives: 7
# F1 Score: 0.9884
# RMSE: 0.1273
# True Positives: 308/319
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9825
# RMSE: 0.1551
# True Positives: 308/328
# False Positives: 0
# False Negatives: 20
# F1 Score: 0.9686
# RMSE: 0.6008
# True Positives: 310/318
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9873
# RMSE: 0.1405
# True Positives: 305/315
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9839
# RMSE: 0.5128
# True Positives: 305/319
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9776
# RMSE: 0.1575
# True Positives: 308/319
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9825
# RMSE: 0.1464
# True Positives: 311/320
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9857
# RMSE: 0.1564
# True Positives: 307/329
# False Positives: 0
# False Negatives: 22
# F1 Score: 0.9654
# RMSE: 0.5100
# True Positives: 316/331
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9768
# RMSE: 0.1489
# True Positives: 305/315
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9839
# RMSE: 0.4907
# True Positives: 305/319
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9776
# RMSE: 0.1494
# True Positives: 311/320
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9857
# RMSE: 0.1460
# True Positives: 307/329
# False Positives: 0
# False Negatives: 22
# F1 Score: 0.9654
# RMSE: 0.5021
# True Positives: 320/330
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9846
# RMSE: 0.1581
# True Positives: 316/331
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9768
# RMSE: 0.1401
# True Positives: 309/325
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9748
# RMSE: 0.5320
# True Positives: 309/326
# False Positives: 1
# False Negatives: 17
# F1 Score: 0.9717
# RMSE: 0.5324
# True Positives: 305/323
# False Positives: 0
# False Negatives: 18
# F1 Score: 0.9713
# RMSE: 0.6629
# True Positives: 320/330
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9846
# RMSE: 0.1493
# True Positives: 313/327
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9781
# RMSE: 0.1378
# True Positives: 309/325
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9748
# RMSE: 0.5222
# True Positives: 299/309
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9836
# RMSE: 0.1495
# True Positives: 305/323
# False Positives: 0
# False Negatives: 18
# F1 Score: 0.9713
# RMSE: 0.6337
# True Positives: 318/328
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9845
# RMSE: 0.1418
# True Positives: 309/326
# False Positives: 1
# False Negatives: 17
# F1 Score: 0.9717
# RMSE: 0.5302
# True Positives: 313/327
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9781
# RMSE: 0.1299
# True Positives: 309/325
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9748
# RMSE: 0.1434
# True Positives: 299/309
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9836
# RMSE: 0.1403
# True Positives: 309/317
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9872
# RMSE: 0.4785
# True Positives: 318/328
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9845
# RMSE: 0.1341
# True Positives: 309/325
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9748
# RMSE: 0.1353
# True Positives: 299/311
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9803
# RMSE: 0.3756
# True Positives: 309/317
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9872
# RMSE: 0.4544
# True Positives: 313/329
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9751
# RMSE: 0.1417
# True Positives: 314/329
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9767
# RMSE: 0.1482
# True Positives: 299/311
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9803
# RMSE: 0.3644
# True Positives: 312/322
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9842
# RMSE: 0.1417
# True Positives: 305/314
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9855
# RMSE: 0.1546
# True Positives: 313/329
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9751
# RMSE: 0.1337
# True Positives: 314/329
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9767
# RMSE: 0.1394
# True Positives: 304/323
# False Positives: 0
# False Negatives: 19
# F1 Score: 0.9697
# RMSE: 0.1588
# True Positives: 309/323
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9778
# RMSE: 0.1508
# True Positives: 305/314
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9855
# RMSE: 0.1457
# True Positives: 312/322
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9842
# RMSE: 0.1331
# True Positives: 313/331
# False Positives: 0
# False Negatives: 18
# F1 Score: 0.9720
# RMSE: 0.5037
# True Positives: 304/323
# False Positives: 0
# False Negatives: 19
# F1 Score: 0.9697
# RMSE: 0.1502
# True Positives: 309/323
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9778
# RMSE: 0.1430
# True Positives: 308/318
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9840
# RMSE: 0.1446
# True Positives: 313/332
# False Positives: 0
# False Negatives: 19
# F1 Score: 0.9705
# RMSE: 0.1479
# True Positives: 302/317
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9758
# RMSE: 0.1561
# True Positives: 313/331
# False Positives: 0
# False Negatives: 18
# F1 Score: 0.9720
# RMSE: 0.4845
# True Positives: 307/315
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9871
# RMSE: 0.1429
# True Positives: 317/325
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9875
# RMSE: 0.1408
# True Positives: 313/332
# False Positives: 0
# False Negatives: 19
# F1 Score: 0.9705
# RMSE: 0.1389
# True Positives: 308/318
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9840
# RMSE: 0.1360
# True Positives: 302/317
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9758
# RMSE: 0.1473
# True Positives: 311/325
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9780
# RMSE: 0.1489
# True Positives: 307/315
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9871
# RMSE: 0.1345
# True Positives: 317/325
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9875
# RMSE: 0.1327
# True Positives: 311/325
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9780
# RMSE: 0.1410
# True Positives: 307/330
# False Positives: 0
# False Negatives: 23
# F1 Score: 0.9639
# RMSE: 0.4593
# True Positives: 311/324
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9795
# RMSE: 0.1499
# True Positives: 306/323
# False Positives: 0
# False Negatives: 17
# F1 Score: 0.9730
# RMSE: 0.4989
# True Positives: 314/333
# False Positives: 0
# False Negatives: 19
# F1 Score: 0.9706
# RMSE: 0.1444
# True Positives: 307/330
# False Positives: 0
# False Negatives: 23
# F1 Score: 0.9639
# RMSE: 0.4258
# True Positives: 299/320
# False Positives: 0
# False Negatives: 21
# F1 Score: 0.9661
# RMSE: 0.7380
# True Positives: 325/337
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9819
# RMSE: 0.5147
# True Positives: 309/319
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9841
# RMSE: 0.1393
# True Positives: 306/323
# False Positives: 0
# False Negatives: 17
# F1 Score: 0.9730
# RMSE: 0.4816
# True Positives: 314/333
# False Positives: 0
# False Negatives: 19
# F1 Score: 0.9706
# RMSE: 0.1366
# True Positives: 311/324
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9795
# RMSE: 0.1415
# True Positives: 299/320
# False Positives: 0
# False Negatives: 21
# F1 Score: 0.9661
# RMSE: 0.7226
# True Positives: 309/319
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9841
# RMSE: 0.1309
# True Positives: 325/337
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9819
# RMSE: 0.5066
# True Positives: 308/322
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9778
# RMSE: 0.5182
# True Positives: 321/337
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9757
# RMSE: 0.1511
# True Positives: 321/331
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9847
# RMSE: 0.1553
# True Positives: 307/323
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9746
# RMSE: 0.5020
# True Positives: 312/321
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9858
# RMSE: 0.1482
# True Positives: 308/322
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9778
# RMSE: 0.5186
# True Positives: 313/327
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9781
# RMSE: 0.1345
# True Positives: 321/331
# False Positives: 0
# False Negatives: 10
# F1 Score: 0.9847
# RMSE: 0.1479
# True Positives: 321/337
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9757
# RMSE: 0.1438
# True Positives: 312/321
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9858
# RMSE: 0.1388
# True Positives: 307/323
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9746
# RMSE: 0.4896
# True Positives: 308/330
# False Positives: 1
# False Negatives: 22
# F1 Score: 0.9640
# RMSE: 0.4869
# True Positives: 313/327
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9781
# RMSE: 0.1271
# True Positives: 309/330
# False Positives: 0
# False Negatives: 21
# F1 Score: 0.9671
# RMSE: 0.6863
# True Positives: 309/331
# False Positives: 0
# False Negatives: 22
# F1 Score: 0.9656
# RMSE: 0.7039
# True Positives: 309/316
# False Positives: 0
# False Negatives: 7
# F1 Score: 0.9888
# RMSE: 0.1616
# True Positives: 318/332
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9785
# RMSE: 0.1579
# True Positives: 309/331
# False Positives: 0
# False Negatives: 22
# F1 Score: 0.9656
# RMSE: 0.6849
# True Positives: 310/322
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9810
# RMSE: 0.5024
# True Positives: 322/335
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9802
# RMSE: 0.5099
# True Positives: 309/316
# False Positives: 0
# False Negatives: 7
# F1 Score: 0.9888
# RMSE: 0.1534
# True Positives: 313/321
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9874
# RMSE: 0.5034
# True Positives: 318/332
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9785
# RMSE: 0.1494
# True Positives: 316/327
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9829
# RMSE: 0.4933
# True Positives: 322/335
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9802
# RMSE: 0.4917
# True Positives: 313/321
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9874
# RMSE: 0.4799
# True Positives: 313/329
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9751
# RMSE: 0.1591
# True Positives: 310/322
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9810
# RMSE: 0.5027
# True Positives: 316/327
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9829
# RMSE: 0.4775
# True Positives: 313/329
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9751
# RMSE: 0.1500
# True Positives: 305/317
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9807
# RMSE: 0.5094
# True Positives: 320/331
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9831
# RMSE: 0.5190
# True Positives: 313/322
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9858
# RMSE: 0.6634
# True Positives: 308/324
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9747
# RMSE: 0.5049
# True Positives: 307/319
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9808
# RMSE: 0.1464
# True Positives: 305/317
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9807
# RMSE: 0.4991
# True Positives: 320/331
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9831
# RMSE: 0.5137
# True Positives: 308/321
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9793
# RMSE: 0.5246
# True Positives: 304/313
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9854
# RMSE: 0.4863
# True Positives: 307/319
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9808
# RMSE: 0.1384
# True Positives: 308/324
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9747
# RMSE: 0.4897
# True Positives: 313/322
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9858
# RMSE: 0.6411
# True Positives: 308/321
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9793
# RMSE: 0.5192
# True Positives: 304/313
# False Positives: 0
# False Negatives: 9
# F1 Score: 0.9854
# RMSE: 0.4710
# True Positives: 310/322
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9810
# RMSE: 0.7196
# True Positives: 304/324
# False Positives: 1
# False Negatives: 20
# F1 Score: 0.9666
# RMSE: 0.5073
# True Positives: 318/331
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9800
# RMSE: 0.1548
# True Positives: 310/322
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9810
# RMSE: 0.5031
# True Positives: 310/322
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9810
# RMSE: 0.7068
# True Positives: 313/327
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9781
# RMSE: 0.1453
# True Positives: 305/321
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9744
# RMSE: 0.3435
# True Positives: 305/324
# False Positives: 0
# False Negatives: 19
# F1 Score: 0.9698
# RMSE: 0.7087
# True Positives: 318/331
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9800
# RMSE: 0.1469
# True Positives: 314/330
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9752
# RMSE: 0.4550
# True Positives: 310/322
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9810
# RMSE: 0.4921
# True Positives: 313/327
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9781
# RMSE: 0.1366
# True Positives: 305/321
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9744
# RMSE: 0.3476
# True Positives: 314/330
# False Positives: 0
# False Negatives: 16
# F1 Score: 0.9752
# RMSE: 0.4213
# True Positives: 326/340
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9790
# RMSE: 0.1372
# True Positives: 315/327
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9813
# RMSE: 0.1513
# True Positives: 315/330
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9767
# RMSE: 0.8186
# True Positives: 317/325
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9875
# RMSE: 0.4621
# True Positives: 326/340
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9790
# RMSE: 0.1302
# True Positives: 312/323
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9827
# RMSE: 0.1451
# True Positives: 314/325
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9828
# RMSE: 0.1617
# True Positives: 317/331
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9784
# RMSE: 0.5072
# True Positives: 315/327
# False Positives: 0
# False Negatives: 12
# F1 Score: 0.9813
# RMSE: 0.1429
# True Positives: 317/325
# False Positives: 0
# False Negatives: 8
# F1 Score: 0.9875
# RMSE: 0.4296
# True Positives: 315/330
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9767
# RMSE: 0.7858
# True Positives: 317/331
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9784
# RMSE: 0.5018
# True Positives: 312/323
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9827
# RMSE: 0.1363
# True Positives: 312/325
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9796
# RMSE: 0.4615
# True Positives: 314/325
# False Positives: 0
# False Negatives: 11
# F1 Score: 0.9828
# RMSE: 0.1525
# True Positives: 315/330
# False Positives: 1
# False Negatives: 15
# F1 Score: 0.9752
# RMSE: 0.1426
# True Positives: 308/328
# False Positives: 0
# False Negatives: 20
# F1 Score: 0.9686
# RMSE: 0.6500
# True Positives: 308/321
# False Positives: 1
# False Negatives: 13
# F1 Score: 0.9778
# RMSE: 0.1419
# True Positives: 312/325
# False Positives: 0
# False Negatives: 13
# F1 Score: 0.9796
# RMSE: 0.4351
# True Positives: 306/321
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9761
# RMSE: 0.1519
# True Positives: 315/330
# False Positives: 1
# False Negatives: 15
# F1 Score: 0.9752
# RMSE: 0.1353True Positives: 308/328
# False Positives: 0
# False Negatives: 20
# F1 Score: 0.9686
# RMSE: 0.6112
#
# True Positives: 308/321
# False Positives: 1
# False Negatives: 13
# F1 Score: 0.9778
# RMSE: 0.1335
# True Positives: 306/321
# False Positives: 0
# False Negatives: 15
# F1 Score: 0.9761
# RMSE: 0.1433
# True Positives: 313/327
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9781
# RMSE: 0.5155
# True Positives: 313/327
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9781
# RMSE: 0.5050
# True Positives: 308/322
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9778
# RMSE: 0.4985
# True Positives: 308/322
# False Positives: 0
# False Negatives: 14
# F1 Score: 0.9778
# RMSE: 0.4867
# Threshold method
# ----------------
# TP:          310.97 ± 5.97
# FP:          0.05 ± 0.22
# FN:          13.77 ± 3.82
# F1:          0.9783 ± 0.0061
# RMSE:        0.3221 ± 0.2019
#
# Sub-pixel refined
# -----------------
# TP:          310.99 ± 5.96
# FP:          0.03 ± 0.17
# FN:          13.75 ± 3.79
# F1:          0.9783 ± 0.0059
# RMSE:        0.3146 ± 0.2038

# %%
def run_crocker_grier_detection(sim_image, sim_locs_gt):

    # Estimate and tune the diameter of particles in pixels, ensuring it is an
    # odd number. Adjust if necessary.
    estimated_size_sim = 17

    # Use the locate built-in function from TrackPy.
    # Output is type DataFrame([x, y, mass, size, ecc, signal, raw_mass]).
    df_sim_locs_pred_method2 = tp.locate(
        sim_image,
        diameter=estimated_size_sim,
        noise_size=3,
        separation=10
    )

    # Extract the predicted positions from DataFrame["x","y"] into a NumPy array.
    sim_locs_pred_method2 = np.array(df_sim_locs_pred_method2)[:, :2]

    TP, FP, FN, F1, RMSE = utils.evaluate_locs(
        sim_locs_pred_method2,
        sim_locs_gt,
        distance_th=particle_radius,
    )

    return TP, FP, FN, F1, RMSE
        
N_workers = 16

with parallel_config(
    backend="loky",
    n_jobs=N_workers,
    inner_max_num_threads=1,
):
    results = Parallel()(
        delayed(run_crocker_grier_detection)(
            sim_image_array[i],
            sim_locs_gt_array[i],
        )
        for i in range(len(sim_image_array))
    )

# Convert results directly to a NumPy array.
results = np.asarray(results)

TP_array_CG   = results[:, 0]
FP_array_CG   = results[:, 1]
FN_array_CG   = results[:, 2]
F1_array_CG   = results[:, 3]
RMSE_array_CG = results[:, 4]

# Convert results directly to a NumPy array.
results = np.asarray(results)

# Standard pixel-level localization.
TP_array_CG   = results[:, 0]
FP_array_CG   = results[:, 1]
FN_array_CG  = results[:, 2]
F1_array_CG   = results[:, 3]
RMSE_array_CG = results[:, 4]


print("Crocker-Grier method")
print("----------------")

print(f"TP:          {TP_array_CG.mean():.2f} ± {TP_array_CG.std():.2f}")
print(f"FP:          {FP_array_CG.mean():.2f} ± {FP_array_CG.std():.2f}")
print(f"FN:          {FN_array_CG.mean():.2f} ± {FN_array_CG.std():.2f}")
print(f"F1:          {F1_array_CG.mean():.4f} ± {F1_array_CG.std():.4f}")
print(f"RMSE:        {RMSE_array_CG.mean():.4f} ± {RMSE_array_CG.std():.4f}")
# Out:
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4631
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4585
# True Positives: 314/314
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4422
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4217
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4402
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4563
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4079
# True Positives: 334/334
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4519
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4633
# True Positives: 304/304
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4219
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4215
# True Positives: 326/326
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4202
# True Positives: 318/318
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4099
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4528
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4441
# True Positives: 315/315
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4601
# True Positives: 320/320
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4303
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4354
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4378
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4337
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4397
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4378
# True Positives: 326/326
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4944
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4447
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.3990
# True Positives: 315/317
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9968
# RMSE: 0.4334
# True Positives: 309/309
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4258
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4468
# True Positives: 311/311
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4441
# True Positives: 328/329
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4278
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4127
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4785
# True Positives: 313/314
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.4338
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4231
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4326
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4342
# True Positives: 332/332
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4184
# True Positives: 318/318
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4308
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4457
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4632
# True Positives: 332/333
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4532
# True Positives: 315/315
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4131
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4551
# True Positives: 337/337
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4293
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4689
# True Positives: 321/322
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.4487
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4409
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4982
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4478
# True Positives: 337/337
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4416
# True Positives: 319/320
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.4545
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4174
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4431
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4535
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4136
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4380
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4412
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4644
# True Positives: 316/316
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4545
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4423
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4579
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4556
# True Positives: 335/335
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4524
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4565
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4416
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4736
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4508
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4295
# True Positives: 332/332
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4377
# True Positives: 313/313
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4330
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4533
# True Positives: 320/321
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.4490
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4318
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4168
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4427
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4409
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4790
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4329
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4463
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4488
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4287
# True Positives: 340/340
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4443
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4229
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4074
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4201
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4365
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4170
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4560
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4186
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4488
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4110
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4558
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4717
# True Positives: 345/345
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4649
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4626
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4269
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4480
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4420
# True Positives: 336/336
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.4396
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5022
# Crocker-Grier method
# ----------------
# TP:          324.62 ± 6.56
# FP:          0.00 ± 0.00
# FN:          0.12 ± 0.35
# F1:          0.9998 ± 0.0006
# RMSE:        0.4421 ± 0.0195

# %% [markdown]
# U-Net image regression-based detection

# %%
def run_unet_regression_detection(sim_image, sim_locs_gt):

    # Convert the image to analyze into a PyTorch tensor.
    formatted_sim_image = utils.format_image(sim_image).to(device)

    # Apply the UNet to the loaded image.
    with torch.inference_mode():
        sim_image_pred_map_tensor = regressor_unet(formatted_sim_image)

    # Convert to NumPy array.
    sim_image_pred_map = (
        sim_image_pred_map_tensor[0, 0, :, :]
        .cpu()
        .detach()
        .numpy()
    )

    # Normalize intensity.
    sim_image_pred_map = utils.normalize_min_max(sim_image_pred_map)

    # Apply thresholding to the predicted ground truth map.
    sim_image_pred_mask_unet = sim_image_pred_map > 0.2

    # Extract predicted positions.
    sim_locs_pred_unet = utils.mask_to_positions(
        sim_image_pred_mask_unet
    )

    # Evaluate the performance.
    TP, FP, FN, F1, RMSE = utils.evaluate_locs(
        sim_locs_pred_unet,
        sim_locs_gt,
        distance_th=particle_radius,
    )

    # Estimate sub-pixel positions using the predicted regression map.
    sim_locs_pred_unet_ref = utils.mask_to_positions(
        sim_image_pred_mask_unet,
        sim_image_pred_map,
    )

    # Evaluate the refined positions.
    TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx = utils.evaluate_locs(
        sim_locs_pred_unet_ref,
        sim_locs_gt,
        distance_th=particle_radius,
    )

    return (
        TP, FP, FN, F1, RMSE,
        TP_subpx, FP_subpx, FN_subpx, F1_subpx, RMSE_subpx,
    )

# %%
results = []

regressor_unet.eval()

for i in range(len(sim_image_array)):
    results.append(
        run_unet_regression_detection(
            sim_image_array[i],
            sim_locs_gt_array[i],
        )
    )

results = np.asarray(results)

# Standard localization.
TP_array_UNet   = results[:, 0]
FP_array_UNet   = results[:, 1]
FN_array_UNet   = results[:, 2]
F1_array_UNet   = results[:, 3]
RMSE_array_UNet = results[:, 4]

# Sub-pixel refined localization.
TP_subpx_array_UNet   = results[:, 5]
FP_subpx_array_UNet   = results[:, 6]
FN_subpx_array_UNet   = results[:, 7]
F1_subpx_array_UNet   = results[:, 8]
RMSE_subpx_array_UNet = results[:, 9]

print("U-Net method")
print("----------------")

print(f"TP:          {TP_array_UNet.mean():.2f} ± {TP_array_UNet.std():.2f}")
print(f"FP:          {FP_array_UNet.mean():.2f} ± {FP_array_UNet.std():.2f}")
print(f"FN:          {FN_array_UNet.mean():.2f} ± {FN_array_UNet.std():.2f}")
print(f"F1:          {F1_array_UNet.mean():.4f} ± {F1_array_UNet.std():.4f}")
print(f"RMSE:        {RMSE_array_UNet.mean():.4f} ± {RMSE_array_UNet.std():.4f}")
# Out:
# True Positives: 329/331
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9955
# RMSE: 0.1555
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5101
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1691
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1486
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1628
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1392
# True Positives: 320/323
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9938
# RMSE: 0.1563
# True Positives: 321/323
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9969
# RMSE: 0.5115
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1755
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1450
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1463
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1174
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1967
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1702
# True Positives: 326/326
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1575
# True Positives: 326/326
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1346
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1630
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1394
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1624
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1334
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1441
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1206
# True Positives: 343/345
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9956
# RMSE: 0.1918
# True Positives: 343/345
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9956
# RMSE: 0.1661
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1560
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1245
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1653
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1406
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1543
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1264
# True Positives: 335/336
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5063
# True Positives: 335/336
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5069
# True Positives: 314/314
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1544
# True Positives: 314/314
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1301
# True Positives: 334/334
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1566
# True Positives: 334/334
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1330
# True Positives: 304/304
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1486
# True Positives: 304/304
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1212
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1576
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1332
# True Positives: 318/318
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1449
# True Positives: 318/318
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1217
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1577
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1269
# True Positives: 317/319
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9969
# RMSE: 0.7326
# True Positives: 316/319
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9937
# RMSE: 0.5157
# True Positives: 315/315
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1664
# True Positives: 315/315
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1418
# True Positives: 320/320
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1684
# True Positives: 320/320
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1475
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1557
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1313
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1603
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1370
# True Positives: 329/330
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5200
# True Positives: 329/330
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5103
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1576
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1337
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1751
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1523
# True Positives: 325/326
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5138
# True Positives: 325/326
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5110
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.1566
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.1297
# True Positives: 309/309
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1634
# True Positives: 309/309
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1326
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1580
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1297
# True Positives: 324/325
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.1582
# True Positives: 324/325
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.1330
# True Positives: 316/317
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.1739
# True Positives: 316/317
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.1497
# True Positives: 311/311
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1468
# True Positives: 311/311
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1225
# True Positives: 328/329
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.1585
# True Positives: 328/329
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.1271
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1496
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1264
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1451
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1143
# True Positives: 314/314
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1512
# True Positives: 314/314
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1204
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1652
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1378
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1546
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1259
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1634
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1379
# True Positives: 332/332
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1584
# True Positives: 332/332
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1332
# True Positives: 318/318
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1501
# True Positives: 318/318
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1189
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1768
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1510
# True Positives: 315/315
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1587
# True Positives: 315/315
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1347
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1498
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1219
# True Positives: 332/333
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5030
# True Positives: 332/333
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4966
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1668
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1437
# True Positives: 337/337
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1521
# True Positives: 337/337
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1277
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1579
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1309
# True Positives: 320/322
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9953
# RMSE: 0.1443
# True Positives: 320/322
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9953
# RMSE: 0.1180
# True Positives: 323/324
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5270
# True Positives: 323/324
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5206
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5162
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5069
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1488
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1234
# True Positives: 336/337
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5065
# True Positives: 336/337
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4940
# True Positives: 320/320
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1646
# True Positives: 320/320
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1392
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1472
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1224
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1484
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1229
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1463
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1199
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4966
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4655
# True Positives: 319/322
# False Positives: 1
# False Negatives: 3
# F1 Score: 0.9938
# RMSE: 0.5261
# True Positives: 320/322
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9969
# RMSE: 0.7223
# True Positives: 322/323
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5159
# True Positives: 322/323
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5112
# True Positives: 316/316
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1542
# True Positives: 316/316
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1306
# True Positives: 329/330
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5203
# True Positives: 329/330
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5054
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1595
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1315
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1710
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1425
# True Positives: 328/329
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5181
# True Positives: 327/329
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9954
# RMSE: 0.1478
# True Positives: 335/335
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1571
# True Positives: 335/335
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1354
# True Positives: 329/331
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9955
# RMSE: 0.1661
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5121
# True Positives: 328/332
# False Positives: 1
# False Negatives: 4
# F1 Score: 0.9924
# RMSE: 0.7107
# True Positives: 329/332
# False Positives: 0
# False Negatives: 3
# F1 Score: 0.9955
# RMSE: 0.8570
# True Positives: 315/317
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9953
# RMSE: 0.1565
# True Positives: 316/317
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5159
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1485
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1225
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1473
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1186
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1425
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1116
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1513
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1197
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1476
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1232
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.1748
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.1495
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1578
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1316
# True Positives: 313/313
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1549
# True Positives: 313/313
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1233
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1711
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1438
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1822
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1545
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1476
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1241
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5170
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5056
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1602
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1363
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1616
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1376
# True Positives: 340/340
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1532
# True Positives: 340/340
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1266
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4950
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.4687
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1471
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1218
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1759
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1506
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1457
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1165
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1462
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1206
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1772
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1517
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1499
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1242
# True Positives: 327/328
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5266
# True Positives: 326/328
# False Positives: 1
# False Negatives: 2
# F1 Score: 0.9954
# RMSE: 0.1590
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1475
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1219
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1553
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1302
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1556
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.1293
# U-Net method
# ----------------
# TP:          324.33 ± 6.40
# FP:          0.08 ± 0.27
# FN:          0.41 ± 0.78
# F1:          0.9993 ± 0.0015
# RMSE:        0.2229 ± 0.1458

# %% [markdown]
# LodeSTAR detection

# %%
def run_lodestar_detection(sim_image, sim_locs_gt):

    # Convert the image to analyze into a PyTorch tensor.
    formatted_sim_image = utils.format_image(sim_image).to(device)

    # Parameters for inference.
    alpha = 0.99
    beta = 1 - alpha
    cutoff = 0.8

    # Extract predictions.
    with torch.inference_mode():
        sim_image_pred_lodestar = \
            lodestar(formatted_sim_image.to(device)).squeeze().detach()

    # Extract the mass feature from the prediction.
    sim_image_mass_feature = sim_image_pred_lodestar[2].cpu()

    # Infer on the pytorch image.
    with torch.inference_mode():
        sim_locs_pred_method4 = lodestar.detect(
            formatted_sim_image,
            alpha=alpha,
            beta=beta,
            mode="quantile",
            cutoff=cutoff,
        )[0]

    # Convert predicted locations to NumPy.
    sim_locs_pred_method4 = (
        sim_locs_pred_method4
    )

    # Evaluate the performance.
    TP, FP, FN, F1, RMSE = utils.evaluate_locs(
        sim_locs_pred_method4,
        sim_locs_gt,
        distance_th=particle_radius,
    )

    return TP, FP, FN, F1, RMSE

# %%
results = []

lodestar.eval()

for i in range(len(sim_image_array)):
    results.append(
        run_lodestar_detection(
            sim_image_array[i],
            sim_locs_gt_array[i],
        )
    )

results = np.asarray(results)

TP_array_LodeSTAR   = results[:, 0]
FP_array_LodeSTAR   = results[:, 1]
FN_array_LodeSTAR   = results[:, 2]
F1_array_LodeSTAR   = results[:, 3]
RMSE_array_LodeSTAR = results[:, 4]

print("LodeSTAR method")
print("----------------")

print(f"TP:          {TP_array_LodeSTAR.mean():.2f} ± {TP_array_LodeSTAR.std():.2f}")
print(f"FP:          {FP_array_LodeSTAR.mean():.2f} ± {FP_array_LodeSTAR.std():.2f}")
print(f"FN:          {FN_array_LodeSTAR.mean():.2f} ± {FN_array_LodeSTAR.std():.2f}")
print(f"F1:          {F1_array_LodeSTAR.mean():.4f} ± {F1_array_LodeSTAR.std():.4f}")
print(f"RMSE:        {RMSE_array_LodeSTAR.mean():.4f} ± {RMSE_array_LodeSTAR.std():.4f}")
# Out:
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5319
# True Positives: 322/323
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5421
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5358
# True Positives: 321/323
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9969
# RMSE: 0.5340
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5392
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5194
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5881
# True Positives: 326/326
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5760
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5504
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5443
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5173
# True Positives: 344/345
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5762
# True Positives: 327/328
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5154
# True Positives: 323/324
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5308
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5316
# True Positives: 336/336
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9985
# RMSE: 0.5231
# True Positives: 314/314
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5552
# True Positives: 334/334
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5513
# True Positives: 304/304
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5421
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5432
# True Positives: 318/318
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5485
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5337
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5620
# True Positives: 315/315
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5272
# True Positives: 319/320
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5560
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5288
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5318
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5347
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5255
# True Positives: 322/323
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5470
# True Positives: 326/326
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5569
# True Positives: 325/327
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9969
# RMSE: 0.5491
# True Positives: 309/309
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5271
# True Positives: 328/328
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5537
# True Positives: 323/325
# False Positives: 0
# False Negatives: 2
# F1 Score: 0.9969
# RMSE: 0.5359
# True Positives: 314/317
# False Positives: 0
# False Negatives: 3
# F1 Score: 0.9952
# RMSE: 0.5444
# True Positives: 311/311
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5280
# True Positives: 328/329
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5342
# True Positives: 329/329
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5188
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5200
# True Positives: 314/314
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5210
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5200
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5382
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5368
# True Positives: 332/332
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5290
# True Positives: 318/318
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5226
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5534
# True Positives: 315/315
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5456
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5442
# True Positives: 333/333
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5325
# True Positives: 325/325
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9985
# RMSE: 0.5445
# True Positives: 337/337
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5450
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5340
# True Positives: 318/322
# False Positives: 3
# False Negatives: 4
# F1 Score: 0.9891
# RMSE: 0.5437
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5556
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5263
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5358
# True Positives: 337/337
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5357
# True Positives: 319/320
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5645
# True Positives: 320/321
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5499
# True Positives: 319/319
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5402
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5372
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5394
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5392
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5801
# True Positives: 315/316
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5352
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5326
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5539
# True Positives: 330/331
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5499
# True Positives: 328/329
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5643
# True Positives: 335/335
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5455
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5327
# True Positives: 332/332
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5513
# True Positives: 317/317
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5686
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5422
# True Positives: 318/319
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5380
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5374
# True Positives: 321/321
# False Positives: 1
# False Negatives: 0
# F1 Score: 0.9984
# RMSE: 0.5205
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5251
# True Positives: 326/327
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5671
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5404
# True Positives: 313/313
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5124
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5404
# True Positives: 324/324
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5795
# True Positives: 322/322
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5244
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5581
# True Positives: 320/321
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9984
# RMSE: 0.5337
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5765
# True Positives: 340/340
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5233
# True Positives: 327/327
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5754
# True Positives: 325/325
# False Positives: 2
# False Negatives: 0
# F1 Score: 0.9969
# RMSE: 0.5382
# True Positives: 329/330
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5371
# True Positives: 323/323
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5382
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5321
# True Positives: 331/331
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5537
# True Positives: 325/325
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5519
# True Positives: 327/328
# False Positives: 0
# False Negatives: 1
# F1 Score: 0.9985
# RMSE: 0.5652
# True Positives: 330/330
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5214
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5270
# True Positives: 321/321
# False Positives: 0
# False Negatives: 0
# F1 Score: 1.0000
# RMSE: 0.5216
# LodeSTAR method
# ----------------
# TP:          324.43 ± 6.60
# FP:          0.08 ± 0.39
# FN:          0.31 ± 0.67
# F1:          0.9994 ± 0.0014
# RMSE:        0.5414 ± 0.0161

# %%
import matplotlib.pyplot as plt
import numpy as np

# Method names.
method_names = [
    "Threshold",
    "Crocker-Grier",
    "U-Net",
    "LodeSTAR",
]

# F1 arrays for each method.
F1_arrays = [
    F1_array_threshold,
    F1_array_CG,
    F1_subpx_array_UNet,
    F1_array_LodeSTAR,
]

# RMSE arrays for each method.
RMSE_arrays = [
    RMSE_array_threshold,
    RMSE_array_CG,
    RMSE_subpx_array_UNet,
    RMSE_array_LodeSTAR,
]

# Calculate means.
F1_means = np.array([np.mean(x) for x in F1_arrays])
RMSE_means = np.array([np.mean(x) for x in RMSE_arrays])

# Calculate standard deviations.
F1_stds = np.array([np.std(x) for x in F1_arrays])
RMSE_stds = np.array([np.std(x) for x in RMSE_arrays])

# Plot.
fig, ax = plt.subplots(figsize=(4, 3))

for i, method in enumerate(method_names):
    ax.errorbar(
        F1_means[i],
        RMSE_means[i],
        xerr=F1_stds[i],
        yerr=RMSE_stds[i],
        fmt="o",
        capsize=4,
        label=method,
    )

ax.set_xlabel("F1 score (higher is better)")
ax.set_ylabel("RMSE [px] (Lower is better)")
ax.set_xlim(0.9, 1.01)
ax.set_ylim(0.0, 1.0)
ax.legend(loc="lower left")
plt.savefig("spheres_detection_statistics.svg")
# ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
print("Threshold method")
print("----------------")

print(f"TP:          {TP_array_threshold.mean():.2f} ± {TP_array_threshold.std():.2f}")
print(f"FP:          {FP_array_threshold.mean():.2f} ± {FP_array_threshold.std():.2f}")
print(f"FN:          {FN_array_threshold.mean():.2f} ± {FN_array_threshold.std():.2f}")
print(f"F1:          {F1_array_threshold.mean():.4f} ± {F1_array_threshold.std():.4f}")
print(f"RMSE:        {RMSE_array_threshold.mean():.4f} ± {RMSE_array_threshold.std():.4f}")

print("\nSub-pixel refined")
print("-----------------")

print(f"TP:          {TP_subpx_array_threshold.mean():.2f} ± {TP_subpx_array_threshold.std():.2f}")
print(f"FP:          {FP_subpx_array_threshold.mean():.2f} ± {FP_subpx_array_threshold.std():.2f}")
print(f"FN:          {FN_subpx_array_threshold.mean():.2f} ± {FN_subpx_array_threshold.std():.2f}")
print(f"F1:          {F1_subpx_array_threshold.mean():.4f} ± {F1_subpx_array_threshold.std():.4f}")
print(f"RMSE:        {RMSE_subpx_array_threshold.mean():.4f} ± {RMSE_subpx_array_threshold.std():.4f}")
print()

print("Crocker-Grier method")
print("----------------")

print(f"TP:          {TP_array_CG.mean():.2f} ± {TP_array_CG.std():.2f}")
print(f"FP:          {FP_array_CG.mean():.2f} ± {FP_array_CG.std():.2f}")
print(f"FN:          {FN_array_CG.mean():.2f} ± {FN_array_CG.std():.2f}")
print(f"F1:          {F1_array_CG.mean():.4f} ± {F1_array_CG.std():.4f}")
print(f"RMSE:        {RMSE_array_CG.mean():.4f} ± {RMSE_array_CG.std():.4f}")
print()

print("U-Net method")
print("----------------")

print(f"TP:          {TP_array_UNet.mean():.2f} ± {TP_array_UNet.std():.2f}")
print(f"FP:          {FP_array_UNet.mean():.2f} ± {FP_array_UNet.std():.2f}")
print(f"FN:          {FN_array_UNet.mean():.2f} ± {FN_array_UNet.std():.2f}")
print(f"F1:          {F1_array_UNet.mean():.4f} ± {F1_array_UNet.std():.4f}")
print(f"RMSE:        {RMSE_array_UNet.mean():.4f} ± {RMSE_array_UNet.std():.4f}")
print()

print("LodeSTAR method")
print("----------------")

print(f"TP:          {TP_array_LodeSTAR.mean():.2f} ± {TP_array_LodeSTAR.std():.2f}")
print(f"FP:          {FP_array_LodeSTAR.mean():.2f} ± {FP_array_LodeSTAR.std():.2f}")
print(f"FN:          {FN_array_LodeSTAR.mean():.2f} ± {FN_array_LodeSTAR.std():.2f}")
print(f"F1:          {F1_array_LodeSTAR.mean():.4f} ± {F1_array_LodeSTAR.std():.4f}")
print(f"RMSE:        {RMSE_array_LodeSTAR.mean():.4f} ± {RMSE_array_LodeSTAR.std():.4f}")
# Out:
# Threshold method
# ----------------
# TP:          310.97 ± 5.97
# FP:          0.05 ± 0.22
# FN:          13.77 ± 3.82
# F1:          0.9783 ± 0.0061
# RMSE:        0.3221 ± 0.2019
#
# Sub-pixel refined
# -----------------
# TP:          310.99 ± 5.96
# FP:          0.03 ± 0.17
# FN:          13.75 ± 3.79
# F1:          0.9783 ± 0.0059
# RMSE:        0.3146 ± 0.2038
#
# Crocker-Grier method
# ----------------
# TP:          324.62 ± 6.56
# FP:          0.00 ± 0.00
# FN:          0.12 ± 0.35
# F1:          0.9998 ± 0.0006
# RMSE:        0.4421 ± 0.0195
#
# U-Net method
# ----------------
# TP:          324.33 ± 6.40
# FP:          0.08 ± 0.27
# FN:          0.41 ± 0.78
# F1:          0.9993 ± 0.0015
# RMSE:        0.2229 ± 0.1458
#
# LodeSTAR method
# ----------------
# TP:          324.43 ± 6.60
# FP:          0.08 ± 0.39
# FN:          0.31 ± 0.67
# F1:          0.9994 ± 0.0014
# RMSE:        0.5414 ± 0.0161

# %%
fig = plt.figure(figsize=(4, 8))

# ------------------------------------------------------------------
# Define common width for both axes.
# ------------------------------------------------------------------

left = 0.15
width = 0.80

# Since the figure is 6 x 10 inches, make the top axes physically square.
# Physical width = 0.80 * 6 = 4.8 inches
# Therefore physical height must also be 4.8 inches:
# 4.8 / 10 = 0.48 of the figure height.

ax_img = fig.add_axes([
    left,    # left
    0.50,    # bottom
    width,   # width
    0.48,    # height
])

ax_stats = fig.add_axes([
    left,    # left
    0.08,    # bottom
    width,   # SAME width
    0.32,    # height
])

# ------------------------------------------------------------------
# Top panel: simulated image.
# ------------------------------------------------------------------

ax_img.imshow(
    sim_image_array[-1],
    cmap="gray",
    origin="upper",
)

ax_img.set_xlabel("x [px]")
ax_img.set_ylabel("y [px]")

# ------------------------------------------------------------------
# Bottom panel: detection statistics.
# ------------------------------------------------------------------

for i, method in enumerate(method_names):
    ax_stats.errorbar(
        F1_means[i],
        RMSE_means[i],
        xerr=F1_stds[i],
        yerr=RMSE_stds[i],
        fmt="o",
        capsize=4,
        label=method,
    )
    
# ax_img.set_title("Simulated ellipses")
ax_stats.set_title("Spheres")

ax_stats.set_xlabel("F1 score (higher is better)")
ax_stats.set_ylabel("RMSE [px] (lower is better)")
ax_stats.set_xlim(0.9, 1.01)
ax_stats.set_ylim(0.0, 1.01)
ax_stats.legend(loc="lower left")

# ------------------------------------------------------------------
# Save.
# ------------------------------------------------------------------

plt.savefig(
    "spheres_statistics.svg",
    bbox_inches="tight",
)

plt.show()
